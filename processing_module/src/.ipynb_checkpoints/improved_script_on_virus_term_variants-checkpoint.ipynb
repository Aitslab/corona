# %% [markdown]
# # This initial script is written by salma to create virus term variants out of curated dictionaries. This was further improved
#
# ### Pointers:
# * Adding '2019', '2019novel', '2019new', '2019 novel', '2019 new' as prefixes or 2019 as suffix (only if '19' was not in the virus name)
# * interchanging corona virus and coronavirus
# * removing virus names containing the same word twice or containing both 'new' and 'novel'
# * interchange "wuhan" and "hubei"
#
# Also lowercase terms and remove hyphens

# %%
import pandas as pd
import re

# %%
infile_virus = "../data/processed_terms/ncbi_termsmerged_virus_sars_grm_lex.xlsx"
df_virus = pd.read_excel(infile_virus)
df_virus
# Out:
#                                                   TERM INCLUDE
# 0    new severe acute respiratory syndrome coronavi...       y
# 1                                            China COV       y
# 2                                        coronaviruses       y
# 3    severe acute respiratory syndrome coronavirus ...       y
# 4                              SARS-CoV-2 infected COV       n
# ..                                                 ...     ...
# 161  2019-novel coronavirus (2019-nCoV) related cor...       n
# 162  SARS-CoV-2 (Severe acute respiratory syndrome ...       y
# 163                 Novel Coronavirus causing COVID-19       y
# 164                                       COVID-19 cov       y
# 165  novel coronavirus (severe acute respiratory sy...       y
#
# [166 rows x 2 columns]

# %%
df_virus = df_virus[df_virus["INCLUDE"]=="y"]
df_virus
# Out:
#                                                   TERM INCLUDE
# 0    new severe acute respiratory syndrome coronavi...       y
# 1                                            China COV       y
# 2                                        coronaviruses       y
# 3    severe acute respiratory syndrome coronavirus ...       y
# 5                                                 ncov       y
# ..                                                 ...     ...
# 160                       novel SARS-CoV-2 coronavirus       y
# 162  SARS-CoV-2 (Severe acute respiratory syndrome ...       y
# 163                 Novel Coronavirus causing COVID-19       y
# 164                                       COVID-19 cov       y
# 165  novel coronavirus (severe acute respiratory sy...       y
#
# [139 rows x 2 columns]

# %%
virus_terms = df_virus["TERM"].tolist()
virus_terms
# Out:
# ['new severe acute respiratory syndrome coronavirus 2',
#  'China COV',
#  'coronaviruses',
#  'severe acute respiratory syndrome coronavirus (CoV)-2',
#  'ncov',
#  'new SARS-CoV-2 coronavirus',
#  'COVID-19 viruses',
#  'coronavirus responsible for COVID-19',
#  'SARS (severe acute respiratory syndrome)-CoV-2 virus',
#  'novel coronavirus Syndrome-Coronavirus',
#  'Wuhan COV',
#  'Wuhan pneumonia virus',
#  'SARS-CoV-2 (CoV-2) coronavirus',
#  'new SARS-CoV-2 virus',
#  'SARS-CoV2 (CoV2) virus',
#  'virus causing 2019 coronavirus disease',
#  'virus causing COVID-19',
#  'novel coronavirus that causes COVID-19 disease',
#  'SARS-CoV-2 coronaviruses',
#  '2019 COV',
#  'novel coronavirus 2019 (COVID-19) virus',
#  'virus that causes coronavirus disease',
#  'CoV2',
#  'new coronavirus disease COV',
#  'Chinese coronavirus',
#  'novel severe acute respiratory syndrome (SARS)-coronavirus (CoV)2',
#  'coronavirus that causes COVID-19',
#  'virus that causes COVID-19 infection',
#  'new coronavirus COV',
#  'novel coronavirus responsible for COVID-19 illness',
#  'Coronavirus disease 2019 (SARS-CoV-2) virus',
#  'SARS-CoV-19 virus',
#  'virus which causes coronavirus disease 2019',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2, or SARS-CoV-2) that causes coronavirus disease 2019',
#  '19 Coronavirus',
#  'coronavirus disease COV',
#  'human coronaviruses (hCoVs)-2',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'SARS-CoV-2 coronavirus',
#  '2019-new coronavirus',
#  'severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) virus',
#  'coronavirus (SARS-CoV-2) responsible for coronavirus disease',
#  'severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) COV',
#  'SARS-CoV-2 (2019-nCoV, COVID-19) coronavirus',
#  'severe acute respiratory syndrome (SARS)-CoV2 (also referred to as COVID-19) coronavirus',
#  'pneumonia-causing COVID-19',
#  'virus that causes COVID-19 acute respiratory syndrome',
#  'SARS-CoV-2 (COVID-19) virus',
#  'coronavirus (SARS-CoV-2) causing COVID-19',
#  'CoV2 coronavirus',
#  'novel Coronavirus 2',
#  'novel SARS-CoV-2 virus',
#  'SARS-CoV-2019 virus',
#  'new coronavirus pneumonia COV',
#  'SARS-CoV-2 (COVID-19) coronavirus',
#  'virus responsible for coronavirus disease 2019',
#  'SARS-CoV-2019',
#  'nCoV-2',
#  'SARS-CoV-2 novel coronavirus',
#  'new COV',
#  'new coronavirus that causes COVID-19',
#  'novel coronavirus (2019-nCoV) associated disease COV',
#  '2019-nCoV, 2019 novel coronavirus',
#  'coronavirus responsible for coronavirus disease 2019',
#  'infectious coronavirus that causes COVID-19',
#  'Coronavirus Disease 2019 COV',
#  'novel SARS-CoV-2',
#  'acute respiratory syndrome coronavirus 2',
#  'novel SARS-coronavirus 2',
#  'virus responsible for COVID-19 disease',
#  'novel coronavirus COV',
#  'SARS-CoV-2 new corona virus',
#  'SARS-CoV-2 (severe acute respiratory syndrome coronavirus 2) coronavirus',
#  'acute respiratory syndrome coronavirus causing coronavirus disease 2019',
#  'coronavirus causing coronavirus disease-2019',
#  'Wuhan virus',
#  'SARS-CoV-19',
#  'SARS-CoV-2 virus',
#  'virus that causes COVID-19',
#  'Virus Causing COVID-19 Disease',
#  'SARS-CoV-2 associated COV',
#  'virus that causes coronavirus disease 2019 (COVID-19) pneumonia',
#  'SARS (Severe acute respiratory syndrome)-CoV-2',
#  'SARS-CoV-2 viruses',
#  'virus causing coronavirus disease 2019',
#  'Wuhan seafood market pneumonia virus',
#  'new SARS-CoV-2',
#  'COVID-19 novel coronavirus',
#  'Wuhan novel coronavirus',
#  'virus responsible for COVID-19',
#  'coronavirus',
#  'China virus',
#  'novel SARS-coronavirus 2019',
#  'new coronavirus infection COV',
#  'novel coronavirus pneumonia COV',
#  'SARS-CoV-2 COV',
#  'SARS-CoV-2 (SC2) virus',
#  'virus that causes COVID-19 disease',
#  'novel coronavirus-related pneumonia COV',
#  'CoV-19 virus',
#  'coronavirus that causes coronavirus disease 2019',
#  'new severe acute respiratory syndrome (SARS) coronavirus 2',
#  'new coronavirus infections COV',
#  'new SARS coronavirus 2',
#  '2019 novel coronavirus disease COV',
#  'virus that causes coronavirus disease 2019',
#  'coronavirus infectious disease COV',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) virus',
#  'novel coronavirus that causes novel coronavirus disease 2019',
#  'novel severe acute respiratory syndrome (SARS)-CoV-2',
#  'human coronavirus 2',
#  'SARS-CoV-2 disease COV',
#  'virus causing coronavirus disease',
#  'novel coronavirus that causes COVID-19',
#  'novel coronavirus (SARS-CoV-2) that causes COVID-19',
#  'Severe Acute Respiratory Syndrome Virus 2',
#  'CoV-2 virus',
#  'severe acute respiratory syndrome coronavirus (SARS-CoV)-2 virus',
#  '2019-nCoV virus',
#  'novel coronavirus disease COV',
#  'HCoV-2',
#  'Severe acute respiratory syndrome (SARS) coronavirus (CoV)-2',
#  'novel COV',
#  'novel coronavirus (SARS-CoV-2) that causes novel coronavirus pneumonia',
#  'novel coronavirus causing coronavirus disease 2019',
#  'novel severe acute respiratory syndrome (SARS) coronavirus 2',
#  'coronaviruses that causes coronavirus disease 2019',
#  'novel coronavirus that causes coronavirus disease 2019',
#  '19 COV',
#  'virus that causes coronavirus-19 disease',
#  'novel coronavirus infection COV',
#  '19-nCoV',
#  'novel SARS-CoV-2 coronavirus',
#  'SARS-CoV-2 (Severe acute respiratory syndrome - coronavirus 2) virus',
#  'Novel Coronavirus causing COVID-19',
#  'COVID-19 cov',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019']

# %%
def remove_hyphens_lowercase(list_):
    new_set = set()
    for term in list_:
        new_set.update([term.lower().replace("-"," ")])
    return sorted(list(new_set))


def _2019_var(list_):
    '''
    create variants with 2019 and new/novel
    '''
    variants_prefix = ['2019novel', '2019new', '2019 novel', '2019 new']
    
    new_set = set()
    
    for term in list_:
        new_set.update([term])
        if "2019" not in term and "19" not in term:
            # add 2019 as prefix and suffix
            new_set.update([term + " 2019"])
            new_set.update(["2019 " + term])            
            
            for var in variants_prefix:
                new_set.update([var + " " + term])

        
    new_set_2 = set()
    #check for duplicates
    for term in new_set:
        if check_duplicate_words_from_single_term(term):
            continue
        elif check_if_both_new_novel(term):
            continue
        elif re.compile(r'\b2019new\b').search(term) and re.compile(r'\bnew\b').search(term):
            continue
        elif re.compile(r'\b2019novel\b').search(term) and re.compile(r'\bnovel\b').search(term):
            continue
        else:
            new_set_2.update([term])
        
    return sorted(new_set_2)
            
    
def check_duplicate_words_from_single_term(term):
    words = term.split()
    return len(words) > len(set(words))

def check_if_both_new_novel(term):
    return "new" in term and "novel" in term

def remove_duplicates(list_):
    '''
    remove duplicate terms and remove "new"/"novel" multiple occurances
    '''
    new_set = set()
    
    for term in list_:
        if check_duplicate_words_from_single_term(term):
            print("duplicate: ", term)
            continue
        elif check_if_both_new_novel(term):
            print("new/novel: ",term)
            continue
        else:
            new_set.update([term])
    
    return sorted(new_set) 
            
def interchance_wuhan_hubei(list_):
    '''
    interchanging wuhan and hubei
    '''
    new_set = set()
    
    for term in list_:
        term = term.lower()
        
        new_set.update([term])
        
        if "wuhan" in term:
            new_set.update([term.replace("wuhan", "hubei")])
        elif "hubei" in term:
            new_set.update([term.replace("hubei", "wuhan")])
            
    return sorted(new_set)

def interchange_corona(list_):
    '''
    interchange corona and coronavirus terms 
    '''
    new_set = set()
    for term in list_:
        term = term.lower()
        new_set.update([term])
        if "corona virus" in term:
            continue
        elif "coronavirus" in term:
            if not "acute respiratory syndrome coronavirus" in term:
                new_set.update([term.replace("coronavirus", "corona")])
        else:
            new_set.update([re.sub("\bcorona\b", "coronavirus", term)])
            
    return sorted(new_set)

# %%
list_lowercase = remove_hyphens_lowercase(virus_terms)
list_lowercase
# Out:
# ['19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 cov',
#  '2019 ncov virus',
#  '2019 ncov, 2019 novel coronavirus',
#  '2019 new coronavirus',
#  '2019 novel coronavirus disease cov',
#  'acute respiratory syndrome coronavirus 2',
#  'acute respiratory syndrome coronavirus causing coronavirus disease 2019',
#  'china cov',
#  'china virus',
#  'chinese coronavirus',
#  'coronavirus',
#  'coronavirus (sars cov 2) causing covid 19',
#  'coronavirus (sars cov 2) responsible for coronavirus disease',
#  'coronavirus causing coronavirus disease 2019',
#  'coronavirus disease 2019 (sars cov 2) virus',
#  'coronavirus disease 2019 cov',
#  'coronavirus disease cov',
#  'coronavirus infectious disease cov',
#  'coronavirus responsible for coronavirus disease 2019',
#  'coronavirus responsible for covid 19',
#  'coronavirus that causes coronavirus disease 2019',
#  'coronavirus that causes covid 19',
#  'coronaviruses',
#  'coronaviruses that causes coronavirus disease 2019',
#  'cov 19 virus',
#  'cov 2 virus',
#  'cov2',
#  'cov2 coronavirus',
#  'covid 19 cov',
#  'covid 19 novel coronavirus',
#  'covid 19 viruses',
#  'hcov 2',
#  'human coronavirus 2',
#  'human coronaviruses (hcovs) 2',
#  'infectious coronavirus that causes covid 19',
#  'ncov',
#  'ncov 2',
#  'new coronavirus cov',
#  'new coronavirus disease cov',
#  'new coronavirus infection cov',
#  'new coronavirus infections cov',
#  'new coronavirus pneumonia cov',
#  'new coronavirus that causes covid 19',
#  'new cov',
#  'new sars coronavirus 2',
#  'new sars cov 2',
#  'new sars cov 2 coronavirus',
#  'new sars cov 2 virus',
#  'new severe acute respiratory syndrome (sars) coronavirus 2',
#  'new severe acute respiratory syndrome coronavirus 2',
#  'novel coronavirus (2019 ncov) associated disease cov',
#  'novel coronavirus (sars cov 2) that causes covid 19',
#  'novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2, or sars cov 2) that causes coronavirus disease 2019',
#  'novel coronavirus 2',
#  'novel coronavirus 2019 (covid 19) virus',
#  'novel coronavirus causing coronavirus disease 2019',
#  'novel coronavirus causing covid 19',
#  'novel coronavirus cov',
#  'novel coronavirus disease cov',
#  'novel coronavirus infection cov',
#  'novel coronavirus pneumonia cov',
#  'novel coronavirus related pneumonia cov',
#  'novel coronavirus responsible for covid 19 illness',
#  'novel coronavirus syndrome coronavirus',
#  'novel coronavirus that causes coronavirus disease 2019',
#  'novel coronavirus that causes covid 19',
#  'novel coronavirus that causes covid 19 disease',
#  'novel coronavirus that causes novel coronavirus disease 2019',
#  'novel cov',
#  'novel sars coronavirus 2',
#  'novel sars coronavirus 2019',
#  'novel sars cov 2',
#  'novel sars cov 2 coronavirus',
#  'novel sars cov 2 virus',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2',
#  'novel severe acute respiratory syndrome (sars) cov 2',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'pneumonia causing covid 19',
#  'sars (severe acute respiratory syndrome) cov 2',
#  'sars (severe acute respiratory syndrome) cov 2 virus',
#  'sars cov 19',
#  'sars cov 19 virus',
#  'sars cov 2 (2019 ncov, covid 19) coronavirus',
#  'sars cov 2 (cov 2) coronavirus',
#  'sars cov 2 (covid 19) coronavirus',
#  'sars cov 2 (covid 19) virus',
#  'sars cov 2 (sc2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus',
#  'sars cov 2 associated cov',
#  'sars cov 2 coronavirus',
#  'sars cov 2 coronaviruses',
#  'sars cov 2 cov',
#  'sars cov 2 disease cov',
#  'sars cov 2 new corona virus',
#  'sars cov 2 novel coronavirus',
#  'sars cov 2 virus',
#  'sars cov 2 viruses',
#  'sars cov 2019',
#  'sars cov 2019 virus',
#  'sars cov2 (cov2) virus',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#  'severe acute respiratory syndrome coronavirus (cov) 2',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'severe acute respiratory syndrome virus 2',
#  'virus causing 2019 coronavirus disease',
#  'virus causing coronavirus disease',
#  'virus causing coronavirus disease 2019',
#  'virus causing covid 19',
#  'virus causing covid 19 disease',
#  'virus responsible for coronavirus disease 2019',
#  'virus responsible for covid 19',
#  'virus responsible for covid 19 disease',
#  'virus that causes coronavirus 19 disease',
#  'virus that causes coronavirus disease',
#  'virus that causes coronavirus disease 2019',
#  'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#  'virus that causes covid 19',
#  'virus that causes covid 19 acute respiratory syndrome',
#  'virus that causes covid 19 disease',
#  'virus that causes covid 19 infection',
#  'virus which causes coronavirus disease 2019',
#  'wuhan cov',
#  'wuhan novel coronavirus',
#  'wuhan pneumonia virus',
#  'wuhan seafood market pneumonia virus',
#  'wuhan virus']

# %%
list_lowercase_2019 = _2019_var(list_lowercase)
list_lowercase_2019
# Out:
# ['19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 acute respiratory syndrome coronavirus 2',
#  '2019 china cov',
#  '2019 china virus',
#  '2019 chinese coronavirus',
#  '2019 coronavirus',
#  '2019 coronavirus disease cov',
#  '2019 coronavirus infectious disease cov',
#  '2019 coronaviruses',
#  '2019 cov',
#  '2019 cov 2 virus',
#  '2019 cov2',
#  '2019 cov2 coronavirus',
#  '2019 hcov 2',
#  '2019 human coronavirus 2',
#  '2019 human coronaviruses (hcovs) 2',
#  '2019 ncov',
#  '2019 ncov 2',
#  '2019 ncov virus',
#  '2019 new acute respiratory syndrome coronavirus 2',
#  '2019 new china cov',
#  '2019 new china virus',
#  '2019 new chinese coronavirus',
#  '2019 new coronavirus',
#  '2019 new coronavirus cov',
#  '2019 new coronavirus disease cov',
#  '2019 new coronavirus infection cov',
#  '2019 new coronavirus infections cov',
#  '2019 new coronavirus infectious disease cov',
#  '2019 new coronavirus pneumonia cov',
#  '2019 new coronaviruses',
#  '2019 new cov',
#  '2019 new cov 2 virus',
#  '2019 new cov2',
#  '2019 new cov2 coronavirus',
#  '2019 new hcov 2',
#  '2019 new human coronavirus 2',
#  '2019 new human coronaviruses (hcovs) 2',
#  '2019 new ncov',
#  '2019 new ncov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 new sars coronavirus 2',
#  '2019 new sars cov 2',
#  '2019 new sars cov 2 (cov 2) coronavirus',
#  '2019 new sars cov 2 (sc2) virus',
#  '2019 new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 new sars cov 2 coronavirus',
#  '2019 new sars cov 2 coronaviruses',
#  '2019 new sars cov 2 virus',
#  '2019 new sars cov 2 viruses',
#  '2019 new sars cov2 (cov2) virus',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2',
#  '2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 new severe acute respiratory syndrome virus 2',
#  '2019 new virus causing coronavirus disease',
#  '2019 new virus that causes coronavirus disease',
#  '2019 new wuhan cov',
#  '2019 new wuhan pneumonia virus',
#  '2019 new wuhan seafood market pneumonia virus',
#  '2019 new wuhan virus',
#  '2019 novel acute respiratory syndrome coronavirus 2',
#  '2019 novel china cov',
#  '2019 novel china virus',
#  '2019 novel chinese coronavirus',
#  '2019 novel coronavirus',
#  '2019 novel coronavirus 2',
#  '2019 novel coronavirus cov',
#  '2019 novel coronavirus disease cov',
#  '2019 novel coronavirus infection cov',
#  '2019 novel coronavirus infectious disease cov',
#  '2019 novel coronavirus pneumonia cov',
#  '2019 novel coronavirus related pneumonia cov',
#  '2019 novel coronaviruses',
#  '2019 novel cov',
#  '2019 novel cov 2 virus',
#  '2019 novel cov2',
#  '2019 novel cov2 coronavirus',
#  '2019 novel hcov 2',
#  '2019 novel human coronavirus 2',
#  '2019 novel human coronaviruses (hcovs) 2',
#  '2019 novel ncov',
#  '2019 novel ncov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 novel sars coronavirus 2',
#  '2019 novel sars cov 2',
#  '2019 novel sars cov 2 (cov 2) coronavirus',
#  '2019 novel sars cov 2 (sc2) virus',
#  '2019 novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 novel sars cov 2 coronavirus',
#  '2019 novel sars cov 2 coronaviruses',
#  '2019 novel sars cov 2 virus',
#  '2019 novel sars cov 2 viruses',
#  '2019 novel sars cov2 (cov2) virus',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 novel severe acute respiratory syndrome (sars) cov 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 novel severe acute respiratory syndrome virus 2',
#  '2019 novel virus causing coronavirus disease',
#  '2019 novel virus that causes coronavirus disease',
#  '2019 novel wuhan cov',
#  '2019 novel wuhan pneumonia virus',
#  '2019 novel wuhan seafood market pneumonia virus',
#  '2019 novel wuhan virus',
#  '2019 sars (severe acute respiratory syndrome) cov 2',
#  '2019 sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 sars cov 2 (cov 2) coronavirus',
#  '2019 sars cov 2 (sc2) virus',
#  '2019 sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 sars cov 2 coronavirus',
#  '2019 sars cov 2 coronaviruses',
#  '2019 sars cov 2 new corona virus',
#  '2019 sars cov 2 novel coronavirus',
#  '2019 sars cov 2 virus',
#  '2019 sars cov 2 viruses',
#  '2019 sars cov2 (cov2) virus',
#  '2019 severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 severe acute respiratory syndrome virus 2',
#  '2019 virus causing coronavirus disease',
#  '2019 virus that causes coronavirus disease',
#  '2019 wuhan cov',
#  '2019 wuhan novel coronavirus',
#  '2019 wuhan pneumonia virus',
#  '2019 wuhan seafood market pneumonia virus',
#  '2019 wuhan virus',
#  '2019new acute respiratory syndrome coronavirus 2',
#  '2019new china cov',
#  '2019new china virus',
#  '2019new chinese coronavirus',
#  '2019new coronavirus',
#  '2019new coronavirus disease cov',
#  '2019new coronavirus infectious disease cov',
#  '2019new coronaviruses',
#  '2019new cov 2 virus',
#  '2019new cov2',
#  '2019new cov2 coronavirus',
#  '2019new hcov 2',
#  '2019new human coronavirus 2',
#  '2019new human coronaviruses (hcovs) 2',
#  '2019new ncov',
#  '2019new ncov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019new sars cov 2 (cov 2) coronavirus',
#  '2019new sars cov 2 (sc2) virus',
#  '2019new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019new sars cov 2 coronavirus',
#  '2019new sars cov 2 coronaviruses',
#  '2019new sars cov 2 virus',
#  '2019new sars cov 2 viruses',
#  '2019new sars cov2 (cov2) virus',
#  '2019new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019new severe acute respiratory syndrome virus 2',
#  '2019new virus causing coronavirus disease',
#  '2019new virus that causes coronavirus disease',
#  '2019new wuhan cov',
#  '2019new wuhan pneumonia virus',
#  '2019new wuhan seafood market pneumonia virus',
#  '2019new wuhan virus',
#  '2019novel acute respiratory syndrome coronavirus 2',
#  '2019novel china cov',
#  '2019novel china virus',
#  '2019novel chinese coronavirus',
#  '2019novel coronavirus',
#  '2019novel coronavirus disease cov',
#  '2019novel coronavirus infectious disease cov',
#  '2019novel coronaviruses',
#  '2019novel cov 2 virus',
#  '2019novel cov2',
#  '2019novel cov2 coronavirus',
#  '2019novel hcov 2',
#  '2019novel human coronavirus 2',
#  '2019novel human coronaviruses (hcovs) 2',
#  '2019novel ncov',
#  '2019novel ncov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019novel sars cov 2 (cov 2) coronavirus',
#  '2019novel sars cov 2 (sc2) virus',
#  '2019novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019novel sars cov 2 coronavirus',
#  '2019novel sars cov 2 coronaviruses',
#  '2019novel sars cov 2 virus',
#  '2019novel sars cov 2 viruses',
#  '2019novel sars cov2 (cov2) virus',
#  '2019novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019novel severe acute respiratory syndrome virus 2',
#  '2019novel virus causing coronavirus disease',
#  '2019novel virus that causes coronavirus disease',
#  '2019novel wuhan cov',
#  '2019novel wuhan pneumonia virus',
#  '2019novel wuhan seafood market pneumonia virus',
#  '2019novel wuhan virus',
#  'acute respiratory syndrome coronavirus 2',
#  'acute respiratory syndrome coronavirus 2 2019',
#  'china cov',
#  'china cov 2019',
#  'china virus',
#  'china virus 2019',
#  'chinese coronavirus',
#  'chinese coronavirus 2019',
#  'coronavirus',
#  'coronavirus (sars cov 2) causing covid 19',
#  'coronavirus 2019',
#  'coronavirus disease 2019 (sars cov 2) virus',
#  'coronavirus disease 2019 cov',
#  'coronavirus disease cov',
#  'coronavirus disease cov 2019',
#  'coronavirus infectious disease cov',
#  'coronavirus infectious disease cov 2019',
#  'coronavirus responsible for covid 19',
#  'coronavirus that causes covid 19',
#  'coronaviruses',
#  'coronaviruses 2019',
#  'coronaviruses that causes coronavirus disease 2019',
#  'cov 19 virus',
#  'cov 2 virus',
#  'cov 2 virus 2019',
#  'cov2',
#  'cov2 2019',
#  'cov2 coronavirus',
#  'cov2 coronavirus 2019',
#  'covid 19 cov',
#  'covid 19 novel coronavirus',
#  'covid 19 viruses',
#  'hcov 2',
#  'hcov 2 2019',
#  'human coronavirus 2',
#  'human coronavirus 2 2019',
#  'human coronaviruses (hcovs) 2',
#  'human coronaviruses (hcovs) 2 2019',
#  'infectious coronavirus that causes covid 19',
#  'ncov',
#  'ncov 2',
#  'ncov 2 2019',
#  'ncov 2019',
#  'new coronavirus cov',
#  'new coronavirus cov 2019',
#  'new coronavirus disease cov',
#  'new coronavirus disease cov 2019',
#  'new coronavirus infection cov',
#  'new coronavirus infection cov 2019',
#  'new coronavirus infections cov',
#  'new coronavirus infections cov 2019',
#  'new coronavirus pneumonia cov',
#  'new coronavirus pneumonia cov 2019',
#  'new coronavirus that causes covid 19',
#  'new cov',
#  'new cov 2019',
#  'new sars coronavirus 2',
#  'new sars coronavirus 2 2019',
#  'new sars cov 2',
#  'new sars cov 2 2019',
#  'new sars cov 2 coronavirus',
#  'new sars cov 2 coronavirus 2019',
#  'new sars cov 2 virus',
#  'new sars cov 2 virus 2019',
#  'new severe acute respiratory syndrome (sars) coronavirus 2',
#  'new severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'new severe acute respiratory syndrome coronavirus 2',
#  'new severe acute respiratory syndrome coronavirus 2 2019',
#  'novel coronavirus (2019 ncov) associated disease cov',
#  'novel coronavirus (sars cov 2) that causes covid 19',
#  'novel coronavirus 2',
#  'novel coronavirus 2 2019',
#  'novel coronavirus 2019 (covid 19) virus',
#  'novel coronavirus causing covid 19',
#  'novel coronavirus cov',
#  'novel coronavirus cov 2019',
#  'novel coronavirus disease cov',
#  'novel coronavirus disease cov 2019',
#  'novel coronavirus infection cov',
#  'novel coronavirus infection cov 2019',
#  'novel coronavirus pneumonia cov',
#  'novel coronavirus pneumonia cov 2019',
#  'novel coronavirus related pneumonia cov',
#  'novel coronavirus related pneumonia cov 2019',
#  'novel coronavirus responsible for covid 19 illness',
#  'novel coronavirus that causes covid 19',
#  'novel coronavirus that causes covid 19 disease',
#  'novel cov',
#  'novel cov 2019',
#  'novel sars coronavirus 2',
#  'novel sars coronavirus 2 2019',
#  'novel sars coronavirus 2019',
#  'novel sars cov 2',
#  'novel sars cov 2 2019',
#  'novel sars cov 2 coronavirus',
#  'novel sars cov 2 coronavirus 2019',
#  'novel sars cov 2 virus',
#  'novel sars cov 2 virus 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'novel severe acute respiratory syndrome (sars) cov 2',
#  'novel severe acute respiratory syndrome (sars) cov 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'pneumonia causing covid 19',
#  'sars (severe acute respiratory syndrome) cov 2',
#  'sars (severe acute respiratory syndrome) cov 2 2019',
#  'sars (severe acute respiratory syndrome) cov 2 virus',
#  'sars (severe acute respiratory syndrome) cov 2 virus 2019',
#  'sars cov 19',
#  'sars cov 19 virus',
#  'sars cov 2 (2019 ncov, covid 19) coronavirus',
#  'sars cov 2 (cov 2) coronavirus',
#  'sars cov 2 (cov 2) coronavirus 2019',
#  'sars cov 2 (covid 19) coronavirus',
#  'sars cov 2 (covid 19) virus',
#  'sars cov 2 (sc2) virus',
#  'sars cov 2 (sc2) virus 2019',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus 2019',
#  'sars cov 2 coronavirus',
#  'sars cov 2 coronavirus 2019',
#  'sars cov 2 coronaviruses',
#  'sars cov 2 coronaviruses 2019',
#  'sars cov 2 new corona virus',
#  'sars cov 2 new corona virus 2019',
#  'sars cov 2 novel coronavirus',
#  'sars cov 2 novel coronavirus 2019',
#  'sars cov 2 virus',
#  'sars cov 2 virus 2019',
#  'sars cov 2 viruses',
#  'sars cov 2 viruses 2019',
#  'sars cov 2019',
#  'sars cov 2019 virus',
#  'sars cov2 (cov2) virus',
#  'sars cov2 (cov2) virus 2019',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#  'severe acute respiratory syndrome coronavirus (cov) 2',
#  'severe acute respiratory syndrome coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'severe acute respiratory syndrome virus 2',
#  'severe acute respiratory syndrome virus 2 2019',
#  'virus causing 2019 coronavirus disease',
#  'virus causing coronavirus disease',
#  'virus causing coronavirus disease 2019',
#  'virus causing covid 19',
#  'virus causing covid 19 disease',
#  'virus responsible for coronavirus disease 2019',
#  'virus responsible for covid 19',
#  'virus responsible for covid 19 disease',
#  'virus that causes coronavirus 19 disease',
#  'virus that causes coronavirus disease',
#  'virus that causes coronavirus disease 2019',
#  'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#  'virus that causes covid 19',
#  'virus that causes covid 19 acute respiratory syndrome',
#  'virus that causes covid 19 disease',
#  'virus that causes covid 19 infection',
#  'virus which causes coronavirus disease 2019',
#  'wuhan cov',
#  'wuhan cov 2019',
#  'wuhan novel coronavirus',
#  'wuhan novel coronavirus 2019',
#  'wuhan pneumonia virus',
#  'wuhan pneumonia virus 2019',
#  'wuhan seafood market pneumonia virus',
#  'wuhan seafood market pneumonia virus 2019',
#  'wuhan virus',
#  'wuhan virus 2019']

# %%
list_lowercase_2019_corona = interchange_corona(list_lowercase_2019)
list_lowercase_2019_corona
# Out:
# ['19 corona',
#  '19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 acute respiratory syndrome coronavirus 2',
#  '2019 china cov',
#  '2019 china virus',
#  '2019 chinese corona',
#  '2019 chinese coronavirus',
#  '2019 corona',
#  '2019 corona disease cov',
#  '2019 corona infectious disease cov',
#  '2019 coronaes',
#  '2019 coronavirus',
#  '2019 coronavirus disease cov',
#  '2019 coronavirus infectious disease cov',
#  '2019 coronaviruses',
#  '2019 cov',
#  '2019 cov 2 virus',
#  '2019 cov2',
#  '2019 cov2 corona',
#  '2019 cov2 coronavirus',
#  '2019 hcov 2',
#  '2019 human corona 2',
#  '2019 human coronaes (hcovs) 2',
#  '2019 human coronavirus 2',
#  '2019 human coronaviruses (hcovs) 2',
#  '2019 ncov',
#  '2019 ncov 2',
#  '2019 ncov virus',
#  '2019 new acute respiratory syndrome coronavirus 2',
#  '2019 new china cov',
#  '2019 new china virus',
#  '2019 new chinese corona',
#  '2019 new chinese coronavirus',
#  '2019 new corona',
#  '2019 new corona cov',
#  '2019 new corona disease cov',
#  '2019 new corona infection cov',
#  '2019 new corona infections cov',
#  '2019 new corona infectious disease cov',
#  '2019 new corona pneumonia cov',
#  '2019 new coronaes',
#  '2019 new coronavirus',
#  '2019 new coronavirus cov',
#  '2019 new coronavirus disease cov',
#  '2019 new coronavirus infection cov',
#  '2019 new coronavirus infections cov',
#  '2019 new coronavirus infectious disease cov',
#  '2019 new coronavirus pneumonia cov',
#  '2019 new coronaviruses',
#  '2019 new cov',
#  '2019 new cov 2 virus',
#  '2019 new cov2',
#  '2019 new cov2 corona',
#  '2019 new cov2 coronavirus',
#  '2019 new hcov 2',
#  '2019 new human corona 2',
#  '2019 new human coronaes (hcovs) 2',
#  '2019 new human coronavirus 2',
#  '2019 new human coronaviruses (hcovs) 2',
#  '2019 new ncov',
#  '2019 new ncov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 new sars corona 2',
#  '2019 new sars coronavirus 2',
#  '2019 new sars cov 2',
#  '2019 new sars cov 2 (cov 2) corona',
#  '2019 new sars cov 2 (cov 2) coronavirus',
#  '2019 new sars cov 2 (sc2) virus',
#  '2019 new sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 new sars cov 2 corona',
#  '2019 new sars cov 2 coronaes',
#  '2019 new sars cov 2 coronavirus',
#  '2019 new sars cov 2 coronaviruses',
#  '2019 new sars cov 2 virus',
#  '2019 new sars cov 2 viruses',
#  '2019 new sars cov2 (cov2) virus',
#  '2019 new severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 new severe acute respiratory syndrome (sars) corona 2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2',
#  '2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 new severe acute respiratory syndrome virus 2',
#  '2019 new virus causing corona disease',
#  '2019 new virus causing coronavirus disease',
#  '2019 new virus that causes corona disease',
#  '2019 new virus that causes coronavirus disease',
#  '2019 new wuhan cov',
#  '2019 new wuhan pneumonia virus',
#  '2019 new wuhan seafood market pneumonia virus',
#  '2019 new wuhan virus',
#  '2019 novel acute respiratory syndrome coronavirus 2',
#  '2019 novel china cov',
#  '2019 novel china virus',
#  '2019 novel chinese corona',
#  '2019 novel chinese coronavirus',
#  '2019 novel corona',
#  '2019 novel corona 2',
#  '2019 novel corona cov',
#  '2019 novel corona disease cov',
#  '2019 novel corona infection cov',
#  '2019 novel corona infectious disease cov',
#  '2019 novel corona pneumonia cov',
#  '2019 novel corona related pneumonia cov',
#  '2019 novel coronaes',
#  '2019 novel coronavirus',
#  '2019 novel coronavirus 2',
#  '2019 novel coronavirus cov',
#  '2019 novel coronavirus disease cov',
#  '2019 novel coronavirus infection cov',
#  '2019 novel coronavirus infectious disease cov',
#  '2019 novel coronavirus pneumonia cov',
#  '2019 novel coronavirus related pneumonia cov',
#  '2019 novel coronaviruses',
#  '2019 novel cov',
#  '2019 novel cov 2 virus',
#  '2019 novel cov2',
#  '2019 novel cov2 corona',
#  '2019 novel cov2 coronavirus',
#  '2019 novel hcov 2',
#  '2019 novel human corona 2',
#  '2019 novel human coronaes (hcovs) 2',
#  '2019 novel human coronavirus 2',
#  '2019 novel human coronaviruses (hcovs) 2',
#  '2019 novel ncov',
#  '2019 novel ncov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 novel sars corona 2',
#  '2019 novel sars coronavirus 2',
#  '2019 novel sars cov 2',
#  '2019 novel sars cov 2 (cov 2) corona',
#  '2019 novel sars cov 2 (cov 2) coronavirus',
#  '2019 novel sars cov 2 (sc2) virus',
#  '2019 novel sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 novel sars cov 2 corona',
#  '2019 novel sars cov 2 coronaes',
#  '2019 novel sars cov 2 coronavirus',
#  '2019 novel sars cov 2 coronaviruses',
#  '2019 novel sars cov 2 virus',
#  '2019 novel sars cov 2 viruses',
#  '2019 novel sars cov2 (cov2) virus',
#  '2019 novel severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 novel severe acute respiratory syndrome (sars) corona (cov)2',
#  '2019 novel severe acute respiratory syndrome (sars) corona 2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 novel severe acute respiratory syndrome (sars) cov 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 novel severe acute respiratory syndrome virus 2',
#  '2019 novel virus causing corona disease',
#  '2019 novel virus causing coronavirus disease',
#  '2019 novel virus that causes corona disease',
#  '2019 novel virus that causes coronavirus disease',
#  '2019 novel wuhan cov',
#  '2019 novel wuhan pneumonia virus',
#  '2019 novel wuhan seafood market pneumonia virus',
#  '2019 novel wuhan virus',
#  '2019 sars (severe acute respiratory syndrome) cov 2',
#  '2019 sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 sars cov 2 (cov 2) corona',
#  '2019 sars cov 2 (cov 2) coronavirus',
#  '2019 sars cov 2 (sc2) virus',
#  '2019 sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 sars cov 2 corona',
#  '2019 sars cov 2 coronaes',
#  '2019 sars cov 2 coronavirus',
#  '2019 sars cov 2 coronaviruses',
#  '2019 sars cov 2 new corona virus',
#  '2019 sars cov 2 novel corona',
#  '2019 sars cov 2 novel coronavirus',
#  '2019 sars cov 2 virus',
#  '2019 sars cov 2 viruses',
#  '2019 sars cov2 (cov2) virus',
#  '2019 severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 severe acute respiratory syndrome virus 2',
#  '2019 virus causing corona disease',
#  '2019 virus causing coronavirus disease',
#  '2019 virus that causes corona disease',
#  '2019 virus that causes coronavirus disease',
#  '2019 wuhan cov',
#  '2019 wuhan novel corona',
#  '2019 wuhan novel coronavirus',
#  '2019 wuhan pneumonia virus',
#  '2019 wuhan seafood market pneumonia virus',
#  '2019 wuhan virus',
#  '2019new acute respiratory syndrome coronavirus 2',
#  '2019new china cov',
#  '2019new china virus',
#  '2019new chinese corona',
#  '2019new chinese coronavirus',
#  '2019new corona',
#  '2019new corona disease cov',
#  '2019new corona infectious disease cov',
#  '2019new coronaes',
#  '2019new coronavirus',
#  '2019new coronavirus disease cov',
#  '2019new coronavirus infectious disease cov',
#  '2019new coronaviruses',
#  '2019new cov 2 virus',
#  '2019new cov2',
#  '2019new cov2 corona',
#  '2019new cov2 coronavirus',
#  '2019new hcov 2',
#  '2019new human corona 2',
#  '2019new human coronaes (hcovs) 2',
#  '2019new human coronavirus 2',
#  '2019new human coronaviruses (hcovs) 2',
#  '2019new ncov',
#  '2019new ncov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019new sars cov 2 (cov 2) corona',
#  '2019new sars cov 2 (cov 2) coronavirus',
#  '2019new sars cov 2 (sc2) virus',
#  '2019new sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019new sars cov 2 corona',
#  '2019new sars cov 2 coronaes',
#  '2019new sars cov 2 coronavirus',
#  '2019new sars cov 2 coronaviruses',
#  '2019new sars cov 2 virus',
#  '2019new sars cov 2 viruses',
#  '2019new sars cov2 (cov2) virus',
#  '2019new severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019new severe acute respiratory syndrome virus 2',
#  '2019new virus causing corona disease',
#  '2019new virus causing coronavirus disease',
#  '2019new virus that causes corona disease',
#  '2019new virus that causes coronavirus disease',
#  '2019new wuhan cov',
#  '2019new wuhan pneumonia virus',
#  '2019new wuhan seafood market pneumonia virus',
#  '2019new wuhan virus',
#  '2019novel acute respiratory syndrome coronavirus 2',
#  '2019novel china cov',
#  '2019novel china virus',
#  '2019novel chinese corona',
#  '2019novel chinese coronavirus',
#  '2019novel corona',
#  '2019novel corona disease cov',
#  '2019novel corona infectious disease cov',
#  '2019novel coronaes',
#  '2019novel coronavirus',
#  '2019novel coronavirus disease cov',
#  '2019novel coronavirus infectious disease cov',
#  '2019novel coronaviruses',
#  '2019novel cov 2 virus',
#  '2019novel cov2',
#  '2019novel cov2 corona',
#  '2019novel cov2 coronavirus',
#  '2019novel hcov 2',
#  '2019novel human corona 2',
#  '2019novel human coronaes (hcovs) 2',
#  '2019novel human coronavirus 2',
#  '2019novel human coronaviruses (hcovs) 2',
#  '2019novel ncov',
#  '2019novel ncov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019novel sars cov 2 (cov 2) corona',
#  '2019novel sars cov 2 (cov 2) coronavirus',
#  '2019novel sars cov 2 (sc2) virus',
#  '2019novel sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019novel sars cov 2 corona',
#  '2019novel sars cov 2 coronaes',
#  '2019novel sars cov 2 coronavirus',
#  '2019novel sars cov 2 coronaviruses',
#  '2019novel sars cov 2 virus',
#  '2019novel sars cov 2 viruses',
#  '2019novel sars cov2 (cov2) virus',
#  '2019novel severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019novel severe acute respiratory syndrome virus 2',
#  '2019novel virus causing corona disease',
#  '2019novel virus causing coronavirus disease',
#  '2019novel virus that causes corona disease',
#  '2019novel virus that causes coronavirus disease',
#  '2019novel wuhan cov',
#  '2019novel wuhan pneumonia virus',
#  '2019novel wuhan seafood market pneumonia virus',
#  '2019novel wuhan virus',
#  'acute respiratory syndrome coronavirus 2',
#  'acute respiratory syndrome coronavirus 2 2019',
#  'china cov',
#  'china cov 2019',
#  'china virus',
#  'china virus 2019',
#  'chinese corona',
#  'chinese corona 2019',
#  'chinese coronavirus',
#  'chinese coronavirus 2019',
#  'corona',
#  'corona (sars cov 2) causing covid 19',
#  'corona 2019',
#  'corona disease 2019 (sars cov 2) virus',
#  'corona disease 2019 cov',
#  'corona disease cov',
#  'corona disease cov 2019',
#  'corona infectious disease cov',
#  'corona infectious disease cov 2019',
#  'corona responsible for covid 19',
#  'corona that causes covid 19',
#  'coronaes',
#  'coronaes 2019',
#  'coronaes that causes corona disease 2019',
#  'coronavirus',
#  'coronavirus (sars cov 2) causing covid 19',
#  'coronavirus 2019',
#  'coronavirus disease 2019 (sars cov 2) virus',
#  'coronavirus disease 2019 cov',
#  'coronavirus disease cov',
#  'coronavirus disease cov 2019',
#  'coronavirus infectious disease cov',
#  'coronavirus infectious disease cov 2019',
#  'coronavirus responsible for covid 19',
#  'coronavirus that causes covid 19',
#  'coronaviruses',
#  'coronaviruses 2019',
#  'coronaviruses that causes coronavirus disease 2019',
#  'cov 19 virus',
#  'cov 2 virus',
#  'cov 2 virus 2019',
#  'cov2',
#  'cov2 2019',
#  'cov2 corona',
#  'cov2 corona 2019',
#  'cov2 coronavirus',
#  'cov2 coronavirus 2019',
#  'covid 19 cov',
#  'covid 19 novel corona',
#  'covid 19 novel coronavirus',
#  'covid 19 viruses',
#  'hcov 2',
#  'hcov 2 2019',
#  'human corona 2',
#  'human corona 2 2019',
#  'human coronaes (hcovs) 2',
#  'human coronaes (hcovs) 2 2019',
#  'human coronavirus 2',
#  'human coronavirus 2 2019',
#  'human coronaviruses (hcovs) 2',
#  'human coronaviruses (hcovs) 2 2019',
#  'infectious corona that causes covid 19',
#  'infectious coronavirus that causes covid 19',
#  'ncov',
#  'ncov 2',
#  'ncov 2 2019',
#  'ncov 2019',
#  'new corona cov',
#  'new corona cov 2019',
#  'new corona disease cov',
#  'new corona disease cov 2019',
#  'new corona infection cov',
#  'new corona infection cov 2019',
#  'new corona infections cov',
#  'new corona infections cov 2019',
#  'new corona pneumonia cov',
#  'new corona pneumonia cov 2019',
#  'new corona that causes covid 19',
#  'new coronavirus cov',
#  'new coronavirus cov 2019',
#  'new coronavirus disease cov',
#  'new coronavirus disease cov 2019',
#  'new coronavirus infection cov',
#  'new coronavirus infection cov 2019',
#  'new coronavirus infections cov',
#  'new coronavirus infections cov 2019',
#  'new coronavirus pneumonia cov',
#  'new coronavirus pneumonia cov 2019',
#  'new coronavirus that causes covid 19',
#  'new cov',
#  'new cov 2019',
#  'new sars corona 2',
#  'new sars corona 2 2019',
#  'new sars coronavirus 2',
#  'new sars coronavirus 2 2019',
#  'new sars cov 2',
#  'new sars cov 2 2019',
#  'new sars cov 2 corona',
#  'new sars cov 2 corona 2019',
#  'new sars cov 2 coronavirus',
#  'new sars cov 2 coronavirus 2019',
#  'new sars cov 2 virus',
#  'new sars cov 2 virus 2019',
#  'new severe acute respiratory syndrome (sars) corona 2',
#  'new severe acute respiratory syndrome (sars) corona 2 2019',
#  'new severe acute respiratory syndrome (sars) coronavirus 2',
#  'new severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'new severe acute respiratory syndrome coronavirus 2',
#  'new severe acute respiratory syndrome coronavirus 2 2019',
#  'novel corona (2019 ncov) associated disease cov',
#  'novel corona (sars cov 2) that causes covid 19',
#  'novel corona 2',
#  'novel corona 2 2019',
#  'novel corona 2019 (covid 19) virus',
#  'novel corona causing covid 19',
#  'novel corona cov',
#  'novel corona cov 2019',
#  'novel corona disease cov',
#  'novel corona disease cov 2019',
#  'novel corona infection cov',
#  'novel corona infection cov 2019',
#  'novel corona pneumonia cov',
#  'novel corona pneumonia cov 2019',
#  'novel corona related pneumonia cov',
#  'novel corona related pneumonia cov 2019',
#  'novel corona responsible for covid 19 illness',
#  'novel corona that causes covid 19',
#  'novel corona that causes covid 19 disease',
#  'novel coronavirus (2019 ncov) associated disease cov',
#  'novel coronavirus (sars cov 2) that causes covid 19',
#  'novel coronavirus 2',
#  'novel coronavirus 2 2019',
#  'novel coronavirus 2019 (covid 19) virus',
#  'novel coronavirus causing covid 19',
#  'novel coronavirus cov',
#  'novel coronavirus cov 2019',
#  'novel coronavirus disease cov',
#  'novel coronavirus disease cov 2019',
#  'novel coronavirus infection cov',
#  'novel coronavirus infection cov 2019',
#  'novel coronavirus pneumonia cov',
#  'novel coronavirus pneumonia cov 2019',
#  'novel coronavirus related pneumonia cov',
#  'novel coronavirus related pneumonia cov 2019',
#  'novel coronavirus responsible for covid 19 illness',
#  'novel coronavirus that causes covid 19',
#  'novel coronavirus that causes covid 19 disease',
#  'novel cov',
#  'novel cov 2019',
#  'novel sars corona 2',
#  'novel sars corona 2 2019',
#  'novel sars corona 2019',
#  'novel sars coronavirus 2',
#  'novel sars coronavirus 2 2019',
#  'novel sars coronavirus 2019',
#  'novel sars cov 2',
#  'novel sars cov 2 2019',
#  'novel sars cov 2 corona',
#  'novel sars cov 2 corona 2019',
#  'novel sars cov 2 coronavirus',
#  'novel sars cov 2 coronavirus 2019',
#  'novel sars cov 2 virus',
#  'novel sars cov 2 virus 2019',
#  'novel severe acute respiratory syndrome (sars) corona (cov)2',
#  'novel severe acute respiratory syndrome (sars) corona (cov)2 2019',
#  'novel severe acute respiratory syndrome (sars) corona 2',
#  'novel severe acute respiratory syndrome (sars) corona 2 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'novel severe acute respiratory syndrome (sars) cov 2',
#  'novel severe acute respiratory syndrome (sars) cov 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'pneumonia causing covid 19',
#  'sars (severe acute respiratory syndrome) cov 2',
#  'sars (severe acute respiratory syndrome) cov 2 2019',
#  'sars (severe acute respiratory syndrome) cov 2 virus',
#  'sars (severe acute respiratory syndrome) cov 2 virus 2019',
#  'sars cov 19',
#  'sars cov 19 virus',
#  'sars cov 2 (2019 ncov, covid 19) corona',
#  'sars cov 2 (2019 ncov, covid 19) coronavirus',
#  'sars cov 2 (cov 2) corona',
#  'sars cov 2 (cov 2) corona 2019',
#  'sars cov 2 (cov 2) coronavirus',
#  'sars cov 2 (cov 2) coronavirus 2019',
#  'sars cov 2 (covid 19) corona',
#  'sars cov 2 (covid 19) coronavirus',
#  'sars cov 2 (covid 19) virus',
#  'sars cov 2 (sc2) virus',
#  'sars cov 2 (sc2) virus 2019',
#  'sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   corona 2) virus 2019',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus 2019',
#  'sars cov 2 corona',
#  'sars cov 2 corona 2019',
#  'sars cov 2 coronaes',
#  'sars cov 2 coronaes 2019',
#  'sars cov 2 coronavirus',
#  'sars cov 2 coronavirus 2019',
#  'sars cov 2 coronaviruses',
#  'sars cov 2 coronaviruses 2019',
#  'sars cov 2 new corona virus',
#  'sars cov 2 new corona virus 2019',
#  'sars cov 2 novel corona',
#  'sars cov 2 novel corona 2019',
#  'sars cov 2 novel coronavirus',
#  'sars cov 2 novel coronavirus 2019',
#  'sars cov 2 virus',
#  'sars cov 2 virus 2019',
#  'sars cov 2 viruses',
#  'sars cov 2 viruses 2019',
#  'sars cov 2019',
#  'sars cov 2019 virus',
#  'sars cov2 (cov2) virus',
#  'sars cov2 (cov2) virus 2019',
#  'severe acute respiratory syndrome (sars) corona (cov) 2',
#  'severe acute respiratory syndrome (sars) corona (cov) 2 2019',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) corona',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#  'severe acute respiratory syndrome coronavirus (cov) 2',
#  'severe acute respiratory syndrome coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'severe acute respiratory syndrome virus 2',
#  'severe acute respiratory syndrome virus 2 2019',
#  'virus causing 2019 corona disease',
#  'virus causing 2019 coronavirus disease',
#  'virus causing corona disease',
#  'virus causing corona disease 2019',
#  'virus causing coronavirus disease',
#  'virus causing coronavirus disease 2019',
#  'virus causing covid 19',
#  'virus causing covid 19 disease',
#  'virus responsible for corona disease 2019',
#  'virus responsible for coronavirus disease 2019',
#  'virus responsible for covid 19',
#  'virus responsible for covid 19 disease',
#  'virus that causes corona 19 disease',
#  'virus that causes corona disease',
#  'virus that causes corona disease 2019',
#  'virus that causes corona disease 2019 (covid 19) pneumonia',
#  'virus that causes coronavirus 19 disease',
#  'virus that causes coronavirus disease',
#  'virus that causes coronavirus disease 2019',
#  'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#  'virus that causes covid 19',
#  'virus that causes covid 19 acute respiratory syndrome',
#  'virus that causes covid 19 disease',
#  'virus that causes covid 19 infection',
#  'virus which causes corona disease 2019',
#  'virus which causes coronavirus disease 2019',
#  'wuhan cov',
#  'wuhan cov 2019',
#  'wuhan novel corona',
#  'wuhan novel corona 2019',
#  'wuhan novel coronavirus',
#  'wuhan novel coronavirus 2019',
#  'wuhan pneumonia virus',
#  'wuhan pneumonia virus 2019',
#  'wuhan seafood market pneumonia virus',
#  'wuhan seafood market pneumonia virus 2019',
#  'wuhan virus',
#  'wuhan virus 2019']

# %%
len(list_lowercase), len(list_lowercase_2019), len(list_lowercase_2019_corona)
# Out:
# (139, 401, 588)

# %%
list_final = remove_duplicates(list_lowercase_2019_corona)
list_final
# Out:
# duplicate:  2019 corona (sars cov 2) responsible for corona disease
# duplicate:  2019 coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  2019 ncov, 2019 novel corona
# duplicate:  2019 ncov, 2019 novel coronavirus
# duplicate:  2019 new corona (sars cov 2) responsible for corona disease
# duplicate:  2019 new corona (sars cov 2) that causes 2019 new corona pneumonia
# duplicate:  2019 new coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  2019 new coronavirus (sars cov 2) that causes 2019 new coronavirus pneumonia
# duplicate:  2019 new coronavirus syndrome coronavirus
# duplicate:  2019 new sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  2019 new sars cov 2 associated cov
# duplicate:  2019 new sars cov 2 cov
# duplicate:  2019 new sars cov 2 disease cov
# duplicate:  2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  2019 novel corona (sars cov 2) responsible for corona disease
# duplicate:  2019 novel corona (sars cov 2) that causes novel corona pneumonia
# duplicate:  2019 novel coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  2019 novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# duplicate:  2019 novel coronavirus syndrome coronavirus
# duplicate:  2019 novel sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  2019 novel sars cov 2 associated cov
# duplicate:  2019 novel sars cov 2 cov
# duplicate:  2019 novel sars cov 2 disease cov
# duplicate:  2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  2019 sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  2019 sars cov 2 associated cov
# duplicate:  2019 sars cov 2 cov
# duplicate:  2019 sars cov 2 disease cov
# duplicate:  2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  2019new corona (sars cov 2) responsible for corona disease
# duplicate:  2019new corona (sars cov 2) that causes 2019new corona pneumonia
# duplicate:  2019new coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  2019new coronavirus (sars cov 2) that causes 2019new coronavirus pneumonia
# duplicate:  2019new coronavirus syndrome coronavirus
# duplicate:  2019new sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  2019new sars cov 2 associated cov
# duplicate:  2019new sars cov 2 cov
# duplicate:  2019new sars cov 2 disease cov
# duplicate:  2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  2019novel corona (sars cov 2) responsible for corona disease
# duplicate:  2019novel coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  2019novel sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  2019novel sars cov 2 associated cov
# duplicate:  2019novel sars cov 2 cov
# duplicate:  2019novel sars cov 2 disease cov
# duplicate:  2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  acute respiratory syndrome coronavirus causing coronavirus disease 2019
# duplicate:  corona (sars cov 2) responsible for corona disease
# duplicate:  corona (sars cov 2) responsible for corona disease 2019
# duplicate:  corona causing corona disease 2019
# duplicate:  corona responsible for corona disease 2019
# duplicate:  corona that causes corona disease 2019
# duplicate:  coronavirus (sars cov 2) responsible for coronavirus disease
# duplicate:  coronavirus (sars cov 2) responsible for coronavirus disease 2019
# duplicate:  coronavirus causing coronavirus disease 2019
# duplicate:  coronavirus responsible for coronavirus disease 2019
# duplicate:  coronavirus that causes coronavirus disease 2019
# duplicate:  new corona (sars cov 2) that causes new corona pneumonia
# duplicate:  new coronavirus (sars cov 2) that causes new coronavirus pneumonia
# duplicate:  new coronavirus syndrome coronavirus
# duplicate:  novel corona (sars cov 2) that causes novel corona pneumonia
# duplicate:  novel corona (sars cov 2) that causes novel corona pneumonia 2019
# duplicate:  novel corona causing corona disease 2019
# duplicate:  novel corona that causes corona disease 2019
# duplicate:  novel corona that causes novel corona disease 2019
# duplicate:  novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# duplicate:  novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia 2019
# duplicate:  novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019
# duplicate:  novel coronavirus (severe acute respiratory syndrome coronavirus 2, or sars cov 2) that causes coronavirus disease 2019
# duplicate:  novel coronavirus causing coronavirus disease 2019
# duplicate:  novel coronavirus syndrome coronavirus
# duplicate:  novel coronavirus syndrome coronavirus 2019
# duplicate:  novel coronavirus that causes coronavirus disease 2019
# duplicate:  novel coronavirus that causes novel coronavirus disease 2019
# duplicate:  sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# duplicate:  sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus 2019
# duplicate:  sars cov 2 associated cov
# duplicate:  sars cov 2 associated cov 2019
# duplicate:  sars cov 2 cov
# duplicate:  sars cov 2 cov 2019
# duplicate:  sars cov 2 disease cov
# duplicate:  sars cov 2 disease cov 2019
# duplicate:  severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# duplicate:  severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov 2019
# ['19 corona',
#  '19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 acute respiratory syndrome coronavirus 2',
#  '2019 china cov',
#  '2019 china virus',
#  '2019 chinese corona',
#  '2019 chinese coronavirus',
#  '2019 corona',
#  '2019 corona disease cov',
#  '2019 corona infectious disease cov',
#  '2019 coronaes',
#  '2019 coronavirus',
#  '2019 coronavirus disease cov',
#  '2019 coronavirus infectious disease cov',
#  '2019 coronaviruses',
#  '2019 cov',
#  '2019 cov 2 virus',
#  '2019 cov2',
#  '2019 cov2 corona',
#  '2019 cov2 coronavirus',
#  '2019 hcov 2',
#  '2019 human corona 2',
#  '2019 human coronaes (hcovs) 2',
#  '2019 human coronavirus 2',
#  '2019 human coronaviruses (hcovs) 2',
#  '2019 ncov',
#  '2019 ncov 2',
#  '2019 ncov virus',
#  '2019 new acute respiratory syndrome coronavirus 2',
#  '2019 new china cov',
#  '2019 new china virus',
#  '2019 new chinese corona',
#  '2019 new chinese coronavirus',
#  '2019 new corona',
#  '2019 new corona 2',
#  '2019 new corona cov',
#  '2019 new corona disease cov',
#  '2019 new corona infection cov',
#  '2019 new corona infections cov',
#  '2019 new corona infectious disease cov',
#  '2019 new corona pneumonia cov',
#  '2019 new corona related pneumonia cov',
#  '2019 new coronaes',
#  '2019 new coronavirus',
#  '2019 new coronavirus 2',
#  '2019 new coronavirus cov',
#  '2019 new coronavirus disease cov',
#  '2019 new coronavirus infection cov',
#  '2019 new coronavirus infections cov',
#  '2019 new coronavirus infectious disease cov',
#  '2019 new coronavirus pneumonia cov',
#  '2019 new coronavirus related pneumonia cov',
#  '2019 new coronaviruses',
#  '2019 new cov',
#  '2019 new cov 2 virus',
#  '2019 new cov2',
#  '2019 new cov2 corona',
#  '2019 new cov2 coronavirus',
#  '2019 new hcov 2',
#  '2019 new human corona 2',
#  '2019 new human coronaes (hcovs) 2',
#  '2019 new human coronavirus 2',
#  '2019 new human coronaviruses (hcovs) 2',
#  '2019 new ncov',
#  '2019 new ncov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2',
#  '2019 new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 new sars corona 2',
#  '2019 new sars coronavirus 2',
#  '2019 new sars cov 2',
#  '2019 new sars cov 2 (cov 2) corona',
#  '2019 new sars cov 2 (cov 2) coronavirus',
#  '2019 new sars cov 2 (sc2) virus',
#  '2019 new sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 new sars cov 2 corona',
#  '2019 new sars cov 2 coronaes',
#  '2019 new sars cov 2 coronavirus',
#  '2019 new sars cov 2 coronaviruses',
#  '2019 new sars cov 2 virus',
#  '2019 new sars cov 2 viruses',
#  '2019 new sars cov2 (cov2) virus',
#  '2019 new severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 new severe acute respiratory syndrome (sars) corona (cov)2',
#  '2019 new severe acute respiratory syndrome (sars) corona 2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  '2019 new severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 new severe acute respiratory syndrome (sars) cov 2',
#  '2019 new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2',
#  '2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 new severe acute respiratory syndrome virus 2',
#  '2019 new virus causing corona disease',
#  '2019 new virus causing coronavirus disease',
#  '2019 new virus that causes corona disease',
#  '2019 new virus that causes coronavirus disease',
#  '2019 new wuhan cov',
#  '2019 new wuhan pneumonia virus',
#  '2019 new wuhan seafood market pneumonia virus',
#  '2019 new wuhan virus',
#  '2019 novel acute respiratory syndrome coronavirus 2',
#  '2019 novel china cov',
#  '2019 novel china virus',
#  '2019 novel chinese corona',
#  '2019 novel chinese coronavirus',
#  '2019 novel corona',
#  '2019 novel corona 2',
#  '2019 novel corona cov',
#  '2019 novel corona disease cov',
#  '2019 novel corona infection cov',
#  '2019 novel corona infections cov',
#  '2019 novel corona infectious disease cov',
#  '2019 novel corona pneumonia cov',
#  '2019 novel corona related pneumonia cov',
#  '2019 novel coronaes',
#  '2019 novel coronavirus',
#  '2019 novel coronavirus 2',
#  '2019 novel coronavirus cov',
#  '2019 novel coronavirus disease cov',
#  '2019 novel coronavirus infection cov',
#  '2019 novel coronavirus infections cov',
#  '2019 novel coronavirus infectious disease cov',
#  '2019 novel coronavirus pneumonia cov',
#  '2019 novel coronavirus related pneumonia cov',
#  '2019 novel coronaviruses',
#  '2019 novel cov',
#  '2019 novel cov 2 virus',
#  '2019 novel cov2',
#  '2019 novel cov2 corona',
#  '2019 novel cov2 coronavirus',
#  '2019 novel hcov 2',
#  '2019 novel human corona 2',
#  '2019 novel human coronaes (hcovs) 2',
#  '2019 novel human coronavirus 2',
#  '2019 novel human coronaviruses (hcovs) 2',
#  '2019 novel ncov',
#  '2019 novel ncov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2',
#  '2019 novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 novel sars corona 2',
#  '2019 novel sars coronavirus 2',
#  '2019 novel sars cov 2',
#  '2019 novel sars cov 2 (cov 2) corona',
#  '2019 novel sars cov 2 (cov 2) coronavirus',
#  '2019 novel sars cov 2 (sc2) virus',
#  '2019 novel sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 novel sars cov 2 corona',
#  '2019 novel sars cov 2 coronaes',
#  '2019 novel sars cov 2 coronavirus',
#  '2019 novel sars cov 2 coronaviruses',
#  '2019 novel sars cov 2 virus',
#  '2019 novel sars cov 2 viruses',
#  '2019 novel sars cov2 (cov2) virus',
#  '2019 novel severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 novel severe acute respiratory syndrome (sars) corona (cov)2',
#  '2019 novel severe acute respiratory syndrome (sars) corona 2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  '2019 novel severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019 novel severe acute respiratory syndrome (sars) cov 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 novel severe acute respiratory syndrome virus 2',
#  '2019 novel virus causing corona disease',
#  '2019 novel virus causing coronavirus disease',
#  '2019 novel virus that causes corona disease',
#  '2019 novel virus that causes coronavirus disease',
#  '2019 novel wuhan cov',
#  '2019 novel wuhan pneumonia virus',
#  '2019 novel wuhan seafood market pneumonia virus',
#  '2019 novel wuhan virus',
#  '2019 sars (severe acute respiratory syndrome) cov 2',
#  '2019 sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019 sars cov 2 (cov 2) corona',
#  '2019 sars cov 2 (cov 2) coronavirus',
#  '2019 sars cov 2 (sc2) virus',
#  '2019 sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019 sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019 sars cov 2 corona',
#  '2019 sars cov 2 coronaes',
#  '2019 sars cov 2 coronavirus',
#  '2019 sars cov 2 coronaviruses',
#  '2019 sars cov 2 new corona virus',
#  '2019 sars cov 2 novel corona',
#  '2019 sars cov 2 novel coronavirus',
#  '2019 sars cov 2 virus',
#  '2019 sars cov 2 viruses',
#  '2019 sars cov2 (cov2) virus',
#  '2019 severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019 severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019 severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019 severe acute respiratory syndrome coronavirus 2 virus',
#  '2019 severe acute respiratory syndrome virus 2',
#  '2019 virus causing corona disease',
#  '2019 virus causing coronavirus disease',
#  '2019 virus that causes corona disease',
#  '2019 virus that causes coronavirus disease',
#  '2019 wuhan cov',
#  '2019 wuhan novel corona',
#  '2019 wuhan novel coronavirus',
#  '2019 wuhan pneumonia virus',
#  '2019 wuhan seafood market pneumonia virus',
#  '2019 wuhan virus',
#  '2019new acute respiratory syndrome coronavirus 2',
#  '2019new china cov',
#  '2019new china virus',
#  '2019new chinese corona',
#  '2019new chinese coronavirus',
#  '2019new corona',
#  '2019new corona 2',
#  '2019new corona cov',
#  '2019new corona disease cov',
#  '2019new corona infection cov',
#  '2019new corona infectious disease cov',
#  '2019new corona pneumonia cov',
#  '2019new corona related pneumonia cov',
#  '2019new coronaes',
#  '2019new coronavirus',
#  '2019new coronavirus 2',
#  '2019new coronavirus cov',
#  '2019new coronavirus disease cov',
#  '2019new coronavirus infection cov',
#  '2019new coronavirus infectious disease cov',
#  '2019new coronavirus pneumonia cov',
#  '2019new coronavirus related pneumonia cov',
#  '2019new coronaviruses',
#  '2019new cov',
#  '2019new cov 2 virus',
#  '2019new cov2',
#  '2019new cov2 corona',
#  '2019new cov2 coronavirus',
#  '2019new hcov 2',
#  '2019new human corona 2',
#  '2019new human coronaes (hcovs) 2',
#  '2019new human coronavirus 2',
#  '2019new human coronaviruses (hcovs) 2',
#  '2019new ncov',
#  '2019new ncov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2',
#  '2019new sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019new sars corona 2',
#  '2019new sars coronavirus 2',
#  '2019new sars cov 2',
#  '2019new sars cov 2 (cov 2) corona',
#  '2019new sars cov 2 (cov 2) coronavirus',
#  '2019new sars cov 2 (sc2) virus',
#  '2019new sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019new sars cov 2 corona',
#  '2019new sars cov 2 coronaes',
#  '2019new sars cov 2 coronavirus',
#  '2019new sars cov 2 coronaviruses',
#  '2019new sars cov 2 virus',
#  '2019new sars cov 2 viruses',
#  '2019new sars cov2 (cov2) virus',
#  '2019new severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019new severe acute respiratory syndrome (sars) corona (cov)2',
#  '2019new severe acute respiratory syndrome (sars) corona 2',
#  '2019new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  '2019new severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019new severe acute respiratory syndrome (sars) cov 2',
#  '2019new severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019new severe acute respiratory syndrome coronavirus 2',
#  '2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019new severe acute respiratory syndrome coronavirus 2 virus',
#  '2019new severe acute respiratory syndrome virus 2',
#  '2019new virus causing corona disease',
#  '2019new virus causing coronavirus disease',
#  '2019new virus that causes corona disease',
#  '2019new virus that causes coronavirus disease',
#  '2019new wuhan cov',
#  '2019new wuhan pneumonia virus',
#  '2019new wuhan seafood market pneumonia virus',
#  '2019new wuhan virus',
#  '2019novel acute respiratory syndrome coronavirus 2',
#  '2019novel china cov',
#  '2019novel china virus',
#  '2019novel chinese corona',
#  '2019novel chinese coronavirus',
#  '2019novel corona',
#  '2019novel corona cov',
#  '2019novel corona disease cov',
#  '2019novel corona infection cov',
#  '2019novel corona infections cov',
#  '2019novel corona infectious disease cov',
#  '2019novel corona pneumonia cov',
#  '2019novel coronaes',
#  '2019novel coronavirus',
#  '2019novel coronavirus cov',
#  '2019novel coronavirus disease cov',
#  '2019novel coronavirus infection cov',
#  '2019novel coronavirus infections cov',
#  '2019novel coronavirus infectious disease cov',
#  '2019novel coronavirus pneumonia cov',
#  '2019novel coronaviruses',
#  '2019novel cov',
#  '2019novel cov 2 virus',
#  '2019novel cov2',
#  '2019novel cov2 corona',
#  '2019novel cov2 coronavirus',
#  '2019novel hcov 2',
#  '2019novel human corona 2',
#  '2019novel human coronaes (hcovs) 2',
#  '2019novel human coronavirus 2',
#  '2019novel human coronaviruses (hcovs) 2',
#  '2019novel ncov',
#  '2019novel ncov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2',
#  '2019novel sars (severe acute respiratory syndrome) cov 2 virus',
#  '2019novel sars corona 2',
#  '2019novel sars coronavirus 2',
#  '2019novel sars cov 2',
#  '2019novel sars cov 2 (cov 2) corona',
#  '2019novel sars cov 2 (cov 2) coronavirus',
#  '2019novel sars cov 2 (sc2) virus',
#  '2019novel sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  '2019novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  '2019novel sars cov 2 corona',
#  '2019novel sars cov 2 coronaes',
#  '2019novel sars cov 2 coronavirus',
#  '2019novel sars cov 2 coronaviruses',
#  '2019novel sars cov 2 virus',
#  '2019novel sars cov 2 viruses',
#  '2019novel sars cov2 (cov2) virus',
#  '2019novel severe acute respiratory syndrome (sars) corona (cov) 2',
#  '2019novel severe acute respiratory syndrome (sars) corona 2',
#  '2019novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome (sars) coronavirus 2',
#  '2019novel severe acute respiratory syndrome coronavirus (cov) 2',
#  '2019novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2',
#  '2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  '2019novel severe acute respiratory syndrome coronavirus 2 virus',
#  '2019novel severe acute respiratory syndrome virus 2',
#  '2019novel virus causing corona disease',
#  '2019novel virus causing coronavirus disease',
#  '2019novel virus that causes corona disease',
#  '2019novel virus that causes coronavirus disease',
#  '2019novel wuhan cov',
#  '2019novel wuhan pneumonia virus',
#  '2019novel wuhan seafood market pneumonia virus',
#  '2019novel wuhan virus',
#  'acute respiratory syndrome coronavirus 2',
#  'acute respiratory syndrome coronavirus 2 2019',
#  'china cov',
#  'china cov 2019',
#  'china virus',
#  'china virus 2019',
#  'chinese corona',
#  'chinese corona 2019',
#  'chinese coronavirus',
#  'chinese coronavirus 2019',
#  'corona',
#  'corona (sars cov 2) causing covid 19',
#  'corona 2019',
#  'corona disease 2019 (sars cov 2) virus',
#  'corona disease 2019 cov',
#  'corona disease cov',
#  'corona disease cov 2019',
#  'corona infectious disease cov',
#  'corona infectious disease cov 2019',
#  'corona responsible for covid 19',
#  'corona that causes covid 19',
#  'coronaes',
#  'coronaes 2019',
#  'coronaes that causes corona disease 2019',
#  'coronavirus',
#  'coronavirus (sars cov 2) causing covid 19',
#  'coronavirus 2019',
#  'coronavirus disease 2019 (sars cov 2) virus',
#  'coronavirus disease 2019 cov',
#  'coronavirus disease cov',
#  'coronavirus disease cov 2019',
#  'coronavirus infectious disease cov',
#  'coronavirus infectious disease cov 2019',
#  'coronavirus responsible for covid 19',
#  'coronavirus that causes covid 19',
#  'coronaviruses',
#  'coronaviruses 2019',
#  'coronaviruses that causes coronavirus disease 2019',
#  'cov 19 virus',
#  'cov 2 virus',
#  'cov 2 virus 2019',
#  'cov2',
#  'cov2 2019',
#  'cov2 corona',
#  'cov2 corona 2019',
#  'cov2 coronavirus',
#  'cov2 coronavirus 2019',
#  'covid 19 cov',
#  'covid 19 novel corona',
#  'covid 19 novel coronavirus',
#  'covid 19 viruses',
#  'hcov 2',
#  'hcov 2 2019',
#  'human corona 2',
#  'human corona 2 2019',
#  'human coronaes (hcovs) 2',
#  'human coronaes (hcovs) 2 2019',
#  'human coronavirus 2',
#  'human coronavirus 2 2019',
#  'human coronaviruses (hcovs) 2',
#  'human coronaviruses (hcovs) 2 2019',
#  'infectious corona that causes covid 19',
#  'infectious coronavirus that causes covid 19',
#  'ncov',
#  'ncov 2',
#  'ncov 2 2019',
#  'ncov 2019',
#  'new corona 2',
#  'new corona cov',
#  'new corona cov 2019',
#  'new corona disease cov',
#  'new corona disease cov 2019',
#  'new corona infection cov',
#  'new corona infection cov 2019',
#  'new corona infections cov',
#  'new corona infections cov 2019',
#  'new corona pneumonia cov',
#  'new corona pneumonia cov 2019',
#  'new corona related pneumonia cov',
#  'new corona that causes covid 19',
#  'new coronavirus 2',
#  'new coronavirus cov',
#  'new coronavirus cov 2019',
#  'new coronavirus disease cov',
#  'new coronavirus disease cov 2019',
#  'new coronavirus infection cov',
#  'new coronavirus infection cov 2019',
#  'new coronavirus infections cov',
#  'new coronavirus infections cov 2019',
#  'new coronavirus pneumonia cov',
#  'new coronavirus pneumonia cov 2019',
#  'new coronavirus related pneumonia cov',
#  'new coronavirus that causes covid 19',
#  'new cov',
#  'new cov 2019',
#  'new sars corona 2',
#  'new sars corona 2 2019',
#  'new sars coronavirus 2',
#  'new sars coronavirus 2 2019',
#  'new sars cov 2',
#  'new sars cov 2 2019',
#  'new sars cov 2 corona',
#  'new sars cov 2 corona 2019',
#  'new sars cov 2 coronavirus',
#  'new sars cov 2 coronavirus 2019',
#  'new sars cov 2 virus',
#  'new sars cov 2 virus 2019',
#  'new severe acute respiratory syndrome (sars) corona (cov)2',
#  'new severe acute respiratory syndrome (sars) corona 2',
#  'new severe acute respiratory syndrome (sars) corona 2 2019',
#  'new severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'new severe acute respiratory syndrome (sars) coronavirus 2',
#  'new severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'new severe acute respiratory syndrome (sars) cov 2',
#  'new severe acute respiratory syndrome coronavirus 2',
#  'new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'new severe acute respiratory syndrome coronavirus 2 2019',
#  'new severe acute respiratory syndrome coronavirus 2 virus',
#  'novel corona (2019 ncov) associated disease cov',
#  'novel corona (sars cov 2) that causes covid 19',
#  'novel corona 2',
#  'novel corona 2 2019',
#  'novel corona 2019 (covid 19) virus',
#  'novel corona causing covid 19',
#  'novel corona cov',
#  'novel corona cov 2019',
#  'novel corona disease cov',
#  'novel corona disease cov 2019',
#  'novel corona infection cov',
#  'novel corona infection cov 2019',
#  'novel corona infections cov',
#  'novel corona pneumonia cov',
#  'novel corona pneumonia cov 2019',
#  'novel corona related pneumonia cov',
#  'novel corona related pneumonia cov 2019',
#  'novel corona responsible for covid 19 illness',
#  'novel corona that causes covid 19',
#  'novel corona that causes covid 19 disease',
#  'novel coronavirus (2019 ncov) associated disease cov',
#  'novel coronavirus (sars cov 2) that causes covid 19',
#  'novel coronavirus 2',
#  'novel coronavirus 2 2019',
#  'novel coronavirus 2019 (covid 19) virus',
#  'novel coronavirus causing covid 19',
#  'novel coronavirus cov',
#  'novel coronavirus cov 2019',
#  'novel coronavirus disease cov',
#  'novel coronavirus disease cov 2019',
#  'novel coronavirus infection cov',
#  'novel coronavirus infection cov 2019',
#  'novel coronavirus infections cov',
#  'novel coronavirus pneumonia cov',
#  'novel coronavirus pneumonia cov 2019',
#  'novel coronavirus related pneumonia cov',
#  'novel coronavirus related pneumonia cov 2019',
#  'novel coronavirus responsible for covid 19 illness',
#  'novel coronavirus that causes covid 19',
#  'novel coronavirus that causes covid 19 disease',
#  'novel cov',
#  'novel cov 2019',
#  'novel sars corona 2',
#  'novel sars corona 2 2019',
#  'novel sars corona 2019',
#  'novel sars coronavirus 2',
#  'novel sars coronavirus 2 2019',
#  'novel sars coronavirus 2019',
#  'novel sars cov 2',
#  'novel sars cov 2 2019',
#  'novel sars cov 2 corona',
#  'novel sars cov 2 corona 2019',
#  'novel sars cov 2 coronavirus',
#  'novel sars cov 2 coronavirus 2019',
#  'novel sars cov 2 virus',
#  'novel sars cov 2 virus 2019',
#  'novel severe acute respiratory syndrome (sars) corona (cov)2',
#  'novel severe acute respiratory syndrome (sars) corona (cov)2 2019',
#  'novel severe acute respiratory syndrome (sars) corona 2',
#  'novel severe acute respiratory syndrome (sars) corona 2 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2 2019',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2 2019',
#  'novel severe acute respiratory syndrome (sars) cov 2',
#  'novel severe acute respiratory syndrome (sars) cov 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 2019',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'pneumonia causing covid 19',
#  'sars (severe acute respiratory syndrome) cov 2',
#  'sars (severe acute respiratory syndrome) cov 2 2019',
#  'sars (severe acute respiratory syndrome) cov 2 virus',
#  'sars (severe acute respiratory syndrome) cov 2 virus 2019',
#  'sars cov 19',
#  'sars cov 19 virus',
#  'sars cov 2 (2019 ncov, covid 19) corona',
#  'sars cov 2 (2019 ncov, covid 19) coronavirus',
#  'sars cov 2 (cov 2) corona',
#  'sars cov 2 (cov 2) corona 2019',
#  'sars cov 2 (cov 2) coronavirus',
#  'sars cov 2 (cov 2) coronavirus 2019',
#  'sars cov 2 (covid 19) corona',
#  'sars cov 2 (covid 19) coronavirus',
#  'sars cov 2 (covid 19) virus',
#  'sars cov 2 (sc2) virus',
#  'sars cov 2 (sc2) virus 2019',
#  'sars cov 2 (severe acute respiratory syndrome   corona 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   corona 2) virus 2019',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus 2019',
#  'sars cov 2 corona',
#  'sars cov 2 corona 2019',
#  'sars cov 2 coronaes',
#  'sars cov 2 coronaes 2019',
#  'sars cov 2 coronavirus',
#  'sars cov 2 coronavirus 2019',
#  'sars cov 2 coronaviruses',
#  'sars cov 2 coronaviruses 2019',
#  'sars cov 2 new corona',
#  'sars cov 2 new corona virus',
#  'sars cov 2 new corona virus 2019',
#  'sars cov 2 new coronavirus',
#  'sars cov 2 novel corona',
#  'sars cov 2 novel corona 2019',
#  'sars cov 2 novel corona virus',
#  'sars cov 2 novel coronavirus',
#  'sars cov 2 novel coronavirus 2019',
#  'sars cov 2 virus',
#  'sars cov 2 virus 2019',
#  'sars cov 2 viruses',
#  'sars cov 2 viruses 2019',
#  'sars cov 2019',
#  'sars cov 2019 virus',
#  'sars cov2 (cov2) virus',
#  'sars cov2 (cov2) virus 2019',
#  'severe acute respiratory syndrome (sars) corona (cov) 2',
#  'severe acute respiratory syndrome (sars) corona (cov) 2 2019',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) corona',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#  'severe acute respiratory syndrome coronavirus (cov) 2',
#  'severe acute respiratory syndrome coronavirus (cov) 2 2019',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'severe acute respiratory syndrome coronavirus 2 virus 2019',
#  'severe acute respiratory syndrome virus 2',
#  'severe acute respiratory syndrome virus 2 2019',
#  'virus causing 2019 corona disease',
#  'virus causing 2019 coronavirus disease',
#  'virus causing corona disease',
#  'virus causing corona disease 2019',
#  'virus causing coronavirus disease',
#  'virus causing coronavirus disease 2019',
#  'virus causing covid 19',
#  'virus causing covid 19 disease',
#  'virus responsible for corona disease 2019',
#  'virus responsible for coronavirus disease 2019',
#  'virus responsible for covid 19',
#  'virus responsible for covid 19 disease',
#  'virus that causes corona 19 disease',
#  'virus that causes corona disease',
#  'virus that causes corona disease 2019',
#  'virus that causes corona disease 2019 (covid 19) pneumonia',
#  'virus that causes coronavirus 19 disease',
#  'virus that causes coronavirus disease',
#  'virus that causes coronavirus disease 2019',
#  'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#  'virus that causes covid 19',
#  'virus that causes covid 19 acute respiratory syndrome',
#  'virus that causes covid 19 disease',
#  'virus that causes covid 19 infection',
#  'virus which causes corona disease 2019',
#  'virus which causes coronavirus disease 2019',
#  'wuhan cov',
#  'wuhan cov 2019',
#  'wuhan new corona',
#  'wuhan new coronavirus',
#  'wuhan novel corona',
#  'wuhan novel corona 2019',
#  'wuhan novel coronavirus',
#  'wuhan novel coronavirus 2019',
#  'wuhan pneumonia virus',
#  'wuhan pneumonia virus 2019',
#  'wuhan seafood market pneumonia virus',
#  'wuhan seafood market pneumonia virus 2019',
#  'wuhan virus',
#  'wuhan virus 2019']

# %%
len(list_lowercase), len(list_lowercase_2019), len(list_lowercase_2019_corona), len(list_final)
# Out:
# (139, 501, 732, 648)

# %%
txt = ["gg-sSSD disease", "coronavirus pneumonia infection", "2019 sars cov 2 infection", "corona virus"]

interchange_corona(txt)
# Out:
# ['2019 sars cov 2 infection',
#  'corona pneumonia infection',
#  'corona virus',
#  'coronavirus pneumonia infection',
#  'gg-sssd disease']

# %%
_2019_var(txt)
# Out:
# ['2019 corona virus',
#  '2019 coronavirus pneumonia infection',
#  '2019 gg-sSSD disease',
#  '2019 new corona virus',
#  '2019 new coronavirus pneumonia infection',
#  '2019 new gg-sSSD disease',
#  '2019 novel corona virus',
#  '2019 novel coronavirus pneumonia infection',
#  '2019 novel gg-sSSD disease',
#  '2019 sars cov 2 infection',
#  '2019new corona virus',
#  '2019new coronavirus pneumonia infection',
#  '2019new gg-sSSD disease',
#  '2019novel corona virus',
#  '2019novel coronavirus pneumonia infection',
#  '2019novel gg-sSSD disease',
#  'corona virus',
#  'corona virus 2019',
#  'coronavirus pneumonia infection',
#  'coronavirus pneumonia infection 2019',
#  'gg-sSSD disease',
#  'gg-sSSD disease 2019']

# %%
for term in list1:
    
    if check_duplicate_words_from_single_term(term):
        print(term)
# Out:
# 2019 ncov, 2019 novel coronavirus
# acute respiratory syndrome coronavirus causing coronavirus disease 2019
# coronavirus (sars cov 2) responsible for coronavirus disease
# coronavirus causing coronavirus disease 2019
# coronavirus responsible for coronavirus disease 2019
# coronavirus that causes coronavirus disease 2019
# novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019
# novel coronavirus (severe acute respiratory syndrome coronavirus 2, or sars cov 2) that causes coronavirus disease 2019
# novel coronavirus causing coronavirus disease 2019
# novel coronavirus syndrome coronavirus
# novel coronavirus that causes coronavirus disease 2019
# novel coronavirus that causes novel coronavirus disease 2019
# sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# sars cov 2 associated cov
# sars cov 2 cov
# sars cov 2 disease cov
# severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov

# %%
for term in list_lowercase:
    if check_if_both_new_novel(term):
        print(term)

# %%
txt2 = ["new coronavirus", "novel sars cov 2", "new novel coronavirus"]
for term in txt2:
    if check_if_both_new_novel(term):
        print(term)
# Out:
# new novel coronavirus

# %%
for term in txt2:
    if term.startswith("new"):
        print(term)
# Out:
# new coronavirus
# new novel coronavirus

# %%
interchance_wuhan_hubei(list_lowercase)
# Out:
# wuhan cov
# wuhan novel coronavirus
# wuhan pneumonia virus
# wuhan seafood market pneumonia virus
# wuhan virus
# ['19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 cov',
#  '2019 ncov virus',
#  '2019 ncov, 2019 novel coronavirus',
#  '2019 new coronavirus',
#  '2019 novel coronavirus disease cov',
#  'acute respiratory syndrome coronavirus 2',
#  'acute respiratory syndrome coronavirus causing coronavirus disease 2019',
#  'china cov',
#  'china virus',
#  'chinese coronavirus',
#  'coronavirus',
#  'coronavirus (sars cov 2) causing covid 19',
#  'coronavirus (sars cov 2) responsible for coronavirus disease',
#  'coronavirus causing coronavirus disease 2019',
#  'coronavirus disease 2019 (sars cov 2) virus',
#  'coronavirus disease 2019 cov',
#  'coronavirus disease cov',
#  'coronavirus infectious disease cov',
#  'coronavirus responsible for coronavirus disease 2019',
#  'coronavirus responsible for covid 19',
#  'coronavirus that causes coronavirus disease 2019',
#  'coronavirus that causes covid 19',
#  'coronaviruses',
#  'coronaviruses that causes coronavirus disease 2019',
#  'cov 19 virus',
#  'cov 2 virus',
#  'cov2',
#  'cov2 coronavirus',
#  'covid 19 cov',
#  'covid 19 novel coronavirus',
#  'covid 19 viruses',
#  'hcov 2',
#  'hubei cov',
#  'hubei novel coronavirus',
#  'hubei pneumonia virus',
#  'hubei seafood market pneumonia virus',
#  'hubei virus',
#  'human coronavirus 2',
#  'human coronaviruses (hcovs) 2',
#  'infectious coronavirus that causes covid 19',
#  'ncov',
#  'ncov 2',
#  'new coronavirus cov',
#  'new coronavirus disease cov',
#  'new coronavirus infection cov',
#  'new coronavirus infections cov',
#  'new coronavirus pneumonia cov',
#  'new coronavirus that causes covid 19',
#  'new cov',
#  'new sars coronavirus 2',
#  'new sars cov 2',
#  'new sars cov 2 coronavirus',
#  'new sars cov 2 virus',
#  'new severe acute respiratory syndrome (sars) coronavirus 2',
#  'new severe acute respiratory syndrome coronavirus 2',
#  'novel coronavirus (2019 ncov) associated disease cov',
#  'novel coronavirus (sars cov 2) that causes covid 19',
#  'novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019',
#  'novel coronavirus (severe acute respiratory syndrome coronavirus 2, or sars cov 2) that causes coronavirus disease 2019',
#  'novel coronavirus 2',
#  'novel coronavirus 2019 (covid 19) virus',
#  'novel coronavirus causing coronavirus disease 2019',
#  'novel coronavirus causing covid 19',
#  'novel coronavirus cov',
#  'novel coronavirus disease cov',
#  'novel coronavirus infection cov',
#  'novel coronavirus pneumonia cov',
#  'novel coronavirus related pneumonia cov',
#  'novel coronavirus responsible for covid 19 illness',
#  'novel coronavirus syndrome coronavirus',
#  'novel coronavirus that causes coronavirus disease 2019',
#  'novel coronavirus that causes covid 19',
#  'novel coronavirus that causes covid 19 disease',
#  'novel coronavirus that causes novel coronavirus disease 2019',
#  'novel cov',
#  'novel sars coronavirus 2',
#  'novel sars coronavirus 2019',
#  'novel sars cov 2',
#  'novel sars cov 2 coronavirus',
#  'novel sars cov 2 virus',
#  'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#  'novel severe acute respiratory syndrome (sars) coronavirus 2',
#  'novel severe acute respiratory syndrome (sars) cov 2',
#  'novel severe acute respiratory syndrome coronavirus 2',
#  'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'novel severe acute respiratory syndrome coronavirus 2 virus',
#  'pneumonia causing covid 19',
#  'sars (severe acute respiratory syndrome) cov 2',
#  'sars (severe acute respiratory syndrome) cov 2 virus',
#  'sars cov 19',
#  'sars cov 19 virus',
#  'sars cov 2 (2019 ncov, covid 19) coronavirus',
#  'sars cov 2 (cov 2) coronavirus',
#  'sars cov 2 (covid 19) coronavirus',
#  'sars cov 2 (covid 19) virus',
#  'sars cov 2 (sc2) virus',
#  'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#  'sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus',
#  'sars cov 2 associated cov',
#  'sars cov 2 coronavirus',
#  'sars cov 2 coronaviruses',
#  'sars cov 2 cov',
#  'sars cov 2 disease cov',
#  'sars cov 2 new corona virus',
#  'sars cov 2 novel coronavirus',
#  'sars cov 2 virus',
#  'sars cov 2 viruses',
#  'sars cov 2019',
#  'sars cov 2019 virus',
#  'sars cov2 (cov2) virus',
#  'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#  'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#  'severe acute respiratory syndrome coronavirus (cov) 2',
#  'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov',
#  'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#  'severe acute respiratory syndrome coronavirus 2 virus',
#  'severe acute respiratory syndrome virus 2',
#  'virus causing 2019 coronavirus disease',
#  'virus causing coronavirus disease',
#  'virus causing coronavirus disease 2019',
#  'virus causing covid 19',
#  'virus causing covid 19 disease',
#  'virus responsible for coronavirus disease 2019',
#  'virus responsible for covid 19',
#  'virus responsible for covid 19 disease',
#  'virus that causes coronavirus 19 disease',
#  'virus that causes coronavirus disease',
#  'virus that causes coronavirus disease 2019',
#  'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#  'virus that causes covid 19',
#  'virus that causes covid 19 acute respiratory syndrome',
#  'virus that causes covid 19 disease',
#  'virus that causes covid 19 infection',
#  'virus which causes coronavirus disease 2019',
#  'wuhan cov',
#  'wuhan novel coronavirus',
#  'wuhan pneumonia virus',
#  'wuhan seafood market pneumonia virus',
#  'wuhan virus']

# %%
_2019_var(list_lowercase), len(_2019_var(list_lowercase)), len(list_lowercase)
# Out:
# (['19 coronavirus',
#   '19 cov',
#   '19 ncov',
#   '2019 acute respiratory syndrome coronavirus 2',
#   '2019 china cov',
#   '2019 china virus',
#   '2019 chinese coronavirus',
#   '2019 coronavirus',
#   '2019 coronavirus disease cov',
#   '2019 coronavirus infectious disease cov',
#   '2019 coronaviruses',
#   '2019 cov',
#   '2019 cov 2 virus',
#   '2019 cov2',
#   '2019 cov2 coronavirus',
#   '2019 hcov 2',
#   '2019 human coronavirus 2',
#   '2019 human coronaviruses (hcovs) 2',
#   '2019 ncov',
#   '2019 ncov 2',
#   '2019 ncov virus',
#   '2019 new acute respiratory syndrome coronavirus 2',
#   '2019 new china cov',
#   '2019 new china virus',
#   '2019 new chinese coronavirus',
#   '2019 new coronavirus',
#   '2019 new coronavirus cov',
#   '2019 new coronavirus disease cov',
#   '2019 new coronavirus infection cov',
#   '2019 new coronavirus infections cov',
#   '2019 new coronavirus infectious disease cov',
#   '2019 new coronavirus pneumonia cov',
#   '2019 new coronaviruses',
#   '2019 new cov',
#   '2019 new cov 2 virus',
#   '2019 new cov2',
#   '2019 new cov2 coronavirus',
#   '2019 new hcov 2',
#   '2019 new human coronavirus 2',
#   '2019 new human coronaviruses (hcovs) 2',
#   '2019 new ncov',
#   '2019 new ncov 2',
#   '2019 new sars (severe acute respiratory syndrome) cov 2',
#   '2019 new sars (severe acute respiratory syndrome) cov 2 virus',
#   '2019 new sars coronavirus 2',
#   '2019 new sars cov 2',
#   '2019 new sars cov 2 (cov 2) coronavirus',
#   '2019 new sars cov 2 (sc2) virus',
#   '2019 new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   '2019 new sars cov 2 coronavirus',
#   '2019 new sars cov 2 coronaviruses',
#   '2019 new sars cov 2 virus',
#   '2019 new sars cov 2 viruses',
#   '2019 new sars cov2 (cov2) virus',
#   '2019 new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   '2019 new severe acute respiratory syndrome (sars) coronavirus 2',
#   '2019 new severe acute respiratory syndrome coronavirus (cov) 2',
#   '2019 new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   '2019 new severe acute respiratory syndrome coronavirus 2',
#   '2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   '2019 new severe acute respiratory syndrome coronavirus 2 virus',
#   '2019 new severe acute respiratory syndrome virus 2',
#   '2019 new virus causing coronavirus disease',
#   '2019 new virus that causes coronavirus disease',
#   '2019 new wuhan cov',
#   '2019 new wuhan pneumonia virus',
#   '2019 new wuhan seafood market pneumonia virus',
#   '2019 new wuhan virus',
#   '2019 novel acute respiratory syndrome coronavirus 2',
#   '2019 novel china cov',
#   '2019 novel china virus',
#   '2019 novel chinese coronavirus',
#   '2019 novel coronavirus',
#   '2019 novel coronavirus 2',
#   '2019 novel coronavirus cov',
#   '2019 novel coronavirus disease cov',
#   '2019 novel coronavirus infection cov',
#   '2019 novel coronavirus infectious disease cov',
#   '2019 novel coronavirus pneumonia cov',
#   '2019 novel coronavirus related pneumonia cov',
#   '2019 novel coronaviruses',
#   '2019 novel cov',
#   '2019 novel cov 2 virus',
#   '2019 novel cov2',
#   '2019 novel cov2 coronavirus',
#   '2019 novel hcov 2',
#   '2019 novel human coronavirus 2',
#   '2019 novel human coronaviruses (hcovs) 2',
#   '2019 novel ncov',
#   '2019 novel ncov 2',
#   '2019 novel sars (severe acute respiratory syndrome) cov 2',
#   '2019 novel sars (severe acute respiratory syndrome) cov 2 virus',
#   '2019 novel sars coronavirus 2',
#   '2019 novel sars cov 2',
#   '2019 novel sars cov 2 (cov 2) coronavirus',
#   '2019 novel sars cov 2 (sc2) virus',
#   '2019 novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   '2019 novel sars cov 2 coronavirus',
#   '2019 novel sars cov 2 coronaviruses',
#   '2019 novel sars cov 2 virus',
#   '2019 novel sars cov 2 viruses',
#   '2019 novel sars cov2 (cov2) virus',
#   '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   '2019 novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#   '2019 novel severe acute respiratory syndrome (sars) coronavirus 2',
#   '2019 novel severe acute respiratory syndrome (sars) cov 2',
#   '2019 novel severe acute respiratory syndrome coronavirus (cov) 2',
#   '2019 novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   '2019 novel severe acute respiratory syndrome coronavirus 2',
#   '2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   '2019 novel severe acute respiratory syndrome coronavirus 2 virus',
#   '2019 novel severe acute respiratory syndrome virus 2',
#   '2019 novel virus causing coronavirus disease',
#   '2019 novel virus that causes coronavirus disease',
#   '2019 novel wuhan cov',
#   '2019 novel wuhan pneumonia virus',
#   '2019 novel wuhan seafood market pneumonia virus',
#   '2019 novel wuhan virus',
#   '2019 sars (severe acute respiratory syndrome) cov 2',
#   '2019 sars (severe acute respiratory syndrome) cov 2 virus',
#   '2019 sars cov 2 (cov 2) coronavirus',
#   '2019 sars cov 2 (sc2) virus',
#   '2019 sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   '2019 sars cov 2 coronavirus',
#   '2019 sars cov 2 coronaviruses',
#   '2019 sars cov 2 new corona virus',
#   '2019 sars cov 2 novel coronavirus',
#   '2019 sars cov 2 virus',
#   '2019 sars cov 2 viruses',
#   '2019 sars cov2 (cov2) virus',
#   '2019 severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   '2019 severe acute respiratory syndrome coronavirus (cov) 2',
#   '2019 severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   '2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   '2019 severe acute respiratory syndrome coronavirus 2 virus',
#   '2019 severe acute respiratory syndrome virus 2',
#   '2019 virus causing coronavirus disease',
#   '2019 virus that causes coronavirus disease',
#   '2019 wuhan cov',
#   '2019 wuhan novel coronavirus',
#   '2019 wuhan pneumonia virus',
#   '2019 wuhan seafood market pneumonia virus',
#   '2019 wuhan virus',
#   '2019new acute respiratory syndrome coronavirus 2',
#   '2019new china cov',
#   '2019new china virus',
#   '2019new chinese coronavirus',
#   '2019new coronavirus',
#   '2019new coronavirus disease cov',
#   '2019new coronavirus infectious disease cov',
#   '2019new coronaviruses',
#   '2019new cov 2 virus',
#   '2019new cov2',
#   '2019new cov2 coronavirus',
#   '2019new hcov 2',
#   '2019new human coronavirus 2',
#   '2019new human coronaviruses (hcovs) 2',
#   '2019new ncov',
#   '2019new ncov 2',
#   '2019new sars (severe acute respiratory syndrome) cov 2',
#   '2019new sars (severe acute respiratory syndrome) cov 2 virus',
#   '2019new sars cov 2 (cov 2) coronavirus',
#   '2019new sars cov 2 (sc2) virus',
#   '2019new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   '2019new sars cov 2 coronavirus',
#   '2019new sars cov 2 coronaviruses',
#   '2019new sars cov 2 virus',
#   '2019new sars cov 2 viruses',
#   '2019new sars cov2 (cov2) virus',
#   '2019new severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   '2019new severe acute respiratory syndrome coronavirus (cov) 2',
#   '2019new severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   '2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   '2019new severe acute respiratory syndrome coronavirus 2 virus',
#   '2019new severe acute respiratory syndrome virus 2',
#   '2019new virus causing coronavirus disease',
#   '2019new virus that causes coronavirus disease',
#   '2019new wuhan cov',
#   '2019new wuhan pneumonia virus',
#   '2019new wuhan seafood market pneumonia virus',
#   '2019new wuhan virus',
#   '2019novel acute respiratory syndrome coronavirus 2',
#   '2019novel china cov',
#   '2019novel china virus',
#   '2019novel chinese coronavirus',
#   '2019novel coronavirus',
#   '2019novel coronavirus disease cov',
#   '2019novel coronavirus infectious disease cov',
#   '2019novel coronaviruses',
#   '2019novel cov 2 virus',
#   '2019novel cov2',
#   '2019novel cov2 coronavirus',
#   '2019novel hcov 2',
#   '2019novel human coronavirus 2',
#   '2019novel human coronaviruses (hcovs) 2',
#   '2019novel ncov',
#   '2019novel ncov 2',
#   '2019novel sars (severe acute respiratory syndrome) cov 2',
#   '2019novel sars (severe acute respiratory syndrome) cov 2 virus',
#   '2019novel sars cov 2 (cov 2) coronavirus',
#   '2019novel sars cov 2 (sc2) virus',
#   '2019novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   '2019novel sars cov 2 coronavirus',
#   '2019novel sars cov 2 coronaviruses',
#   '2019novel sars cov 2 virus',
#   '2019novel sars cov 2 viruses',
#   '2019novel sars cov2 (cov2) virus',
#   '2019novel severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   '2019novel severe acute respiratory syndrome coronavirus (cov) 2',
#   '2019novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   '2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   '2019novel severe acute respiratory syndrome coronavirus 2 virus',
#   '2019novel severe acute respiratory syndrome virus 2',
#   '2019novel virus causing coronavirus disease',
#   '2019novel virus that causes coronavirus disease',
#   '2019novel wuhan cov',
#   '2019novel wuhan pneumonia virus',
#   '2019novel wuhan seafood market pneumonia virus',
#   '2019novel wuhan virus',
#   'acute respiratory syndrome coronavirus 2',
#   'acute respiratory syndrome coronavirus 2 2019',
#   'china cov',
#   'china cov 2019',
#   'china virus',
#   'china virus 2019',
#   'chinese coronavirus',
#   'chinese coronavirus 2019',
#   'coronavirus',
#   'coronavirus (sars cov 2) causing covid 19',
#   'coronavirus 2019',
#   'coronavirus disease 2019 (sars cov 2) virus',
#   'coronavirus disease 2019 cov',
#   'coronavirus disease cov',
#   'coronavirus disease cov 2019',
#   'coronavirus infectious disease cov',
#   'coronavirus infectious disease cov 2019',
#   'coronavirus responsible for covid 19',
#   'coronavirus that causes covid 19',
#   'coronaviruses',
#   'coronaviruses 2019',
#   'coronaviruses that causes coronavirus disease 2019',
#   'cov 19 virus',
#   'cov 2 virus',
#   'cov 2 virus 2019',
#   'cov2',
#   'cov2 2019',
#   'cov2 coronavirus',
#   'cov2 coronavirus 2019',
#   'covid 19 cov',
#   'covid 19 novel coronavirus',
#   'covid 19 viruses',
#   'hcov 2',
#   'hcov 2 2019',
#   'human coronavirus 2',
#   'human coronavirus 2 2019',
#   'human coronaviruses (hcovs) 2',
#   'human coronaviruses (hcovs) 2 2019',
#   'infectious coronavirus that causes covid 19',
#   'ncov',
#   'ncov 2',
#   'ncov 2 2019',
#   'ncov 2019',
#   'new coronavirus cov',
#   'new coronavirus cov 2019',
#   'new coronavirus disease cov',
#   'new coronavirus disease cov 2019',
#   'new coronavirus infection cov',
#   'new coronavirus infection cov 2019',
#   'new coronavirus infections cov',
#   'new coronavirus infections cov 2019',
#   'new coronavirus pneumonia cov',
#   'new coronavirus pneumonia cov 2019',
#   'new coronavirus that causes covid 19',
#   'new cov',
#   'new cov 2019',
#   'new sars coronavirus 2',
#   'new sars coronavirus 2 2019',
#   'new sars cov 2',
#   'new sars cov 2 2019',
#   'new sars cov 2 coronavirus',
#   'new sars cov 2 coronavirus 2019',
#   'new sars cov 2 virus',
#   'new sars cov 2 virus 2019',
#   'new severe acute respiratory syndrome (sars) coronavirus 2',
#   'new severe acute respiratory syndrome (sars) coronavirus 2 2019',
#   'new severe acute respiratory syndrome coronavirus 2',
#   'new severe acute respiratory syndrome coronavirus 2 2019',
#   'novel coronavirus (2019 ncov) associated disease cov',
#   'novel coronavirus (sars cov 2) that causes covid 19',
#   'novel coronavirus 2',
#   'novel coronavirus 2 2019',
#   'novel coronavirus 2019 (covid 19) virus',
#   'novel coronavirus causing covid 19',
#   'novel coronavirus cov',
#   'novel coronavirus cov 2019',
#   'novel coronavirus disease cov',
#   'novel coronavirus disease cov 2019',
#   'novel coronavirus infection cov',
#   'novel coronavirus infection cov 2019',
#   'novel coronavirus pneumonia cov',
#   'novel coronavirus pneumonia cov 2019',
#   'novel coronavirus related pneumonia cov',
#   'novel coronavirus related pneumonia cov 2019',
#   'novel coronavirus responsible for covid 19 illness',
#   'novel coronavirus that causes covid 19',
#   'novel coronavirus that causes covid 19 disease',
#   'novel cov',
#   'novel cov 2019',
#   'novel sars coronavirus 2',
#   'novel sars coronavirus 2 2019',
#   'novel sars coronavirus 2019',
#   'novel sars cov 2',
#   'novel sars cov 2 2019',
#   'novel sars cov 2 coronavirus',
#   'novel sars cov 2 coronavirus 2019',
#   'novel sars cov 2 virus',
#   'novel sars cov 2 virus 2019',
#   'novel severe acute respiratory syndrome (sars) coronavirus (cov)2',
#   'novel severe acute respiratory syndrome (sars) coronavirus (cov)2 2019',
#   'novel severe acute respiratory syndrome (sars) coronavirus 2',
#   'novel severe acute respiratory syndrome (sars) coronavirus 2 2019',
#   'novel severe acute respiratory syndrome (sars) cov 2',
#   'novel severe acute respiratory syndrome (sars) cov 2 2019',
#   'novel severe acute respiratory syndrome coronavirus 2',
#   'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   'novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#   'novel severe acute respiratory syndrome coronavirus 2 2019',
#   'novel severe acute respiratory syndrome coronavirus 2 virus',
#   'novel severe acute respiratory syndrome coronavirus 2 virus 2019',
#   'pneumonia causing covid 19',
#   'sars (severe acute respiratory syndrome) cov 2',
#   'sars (severe acute respiratory syndrome) cov 2 2019',
#   'sars (severe acute respiratory syndrome) cov 2 virus',
#   'sars (severe acute respiratory syndrome) cov 2 virus 2019',
#   'sars cov 19',
#   'sars cov 19 virus',
#   'sars cov 2 (2019 ncov, covid 19) coronavirus',
#   'sars cov 2 (cov 2) coronavirus',
#   'sars cov 2 (cov 2) coronavirus 2019',
#   'sars cov 2 (covid 19) coronavirus',
#   'sars cov 2 (covid 19) virus',
#   'sars cov 2 (sc2) virus',
#   'sars cov 2 (sc2) virus 2019',
#   'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus',
#   'sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus 2019',
#   'sars cov 2 coronavirus',
#   'sars cov 2 coronavirus 2019',
#   'sars cov 2 coronaviruses',
#   'sars cov 2 coronaviruses 2019',
#   'sars cov 2 new corona virus',
#   'sars cov 2 new corona virus 2019',
#   'sars cov 2 novel coronavirus',
#   'sars cov 2 novel coronavirus 2019',
#   'sars cov 2 virus',
#   'sars cov 2 virus 2019',
#   'sars cov 2 viruses',
#   'sars cov 2 viruses 2019',
#   'sars cov 2019',
#   'sars cov 2019 virus',
#   'sars cov2 (cov2) virus',
#   'sars cov2 (cov2) virus 2019',
#   'severe acute respiratory syndrome (sars) coronavirus (cov) 2',
#   'severe acute respiratory syndrome (sars) coronavirus (cov) 2 2019',
#   'severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus',
#   'severe acute respiratory syndrome coronavirus (cov) 2',
#   'severe acute respiratory syndrome coronavirus (cov) 2 2019',
#   'severe acute respiratory syndrome coronavirus (sars cov) 2 virus',
#   'severe acute respiratory syndrome coronavirus (sars cov) 2 virus 2019',
#   'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus',
#   'severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019',
#   'severe acute respiratory syndrome coronavirus 2 virus',
#   'severe acute respiratory syndrome coronavirus 2 virus 2019',
#   'severe acute respiratory syndrome virus 2',
#   'severe acute respiratory syndrome virus 2 2019',
#   'virus causing 2019 coronavirus disease',
#   'virus causing coronavirus disease',
#   'virus causing coronavirus disease 2019',
#   'virus causing covid 19',
#   'virus causing covid 19 disease',
#   'virus responsible for coronavirus disease 2019',
#   'virus responsible for covid 19',
#   'virus responsible for covid 19 disease',
#   'virus that causes coronavirus 19 disease',
#   'virus that causes coronavirus disease',
#   'virus that causes coronavirus disease 2019',
#   'virus that causes coronavirus disease 2019 (covid 19) pneumonia',
#   'virus that causes covid 19',
#   'virus that causes covid 19 acute respiratory syndrome',
#   'virus that causes covid 19 disease',
#   'virus that causes covid 19 infection',
#   'virus which causes coronavirus disease 2019',
#   'wuhan cov',
#   'wuhan cov 2019',
#   'wuhan novel coronavirus',
#   'wuhan novel coronavirus 2019',
#   'wuhan pneumonia virus',
#   'wuhan pneumonia virus 2019',
#   'wuhan seafood market pneumonia virus',
#   'wuhan seafood market pneumonia virus 2019',
#   'wuhan virus',
#   'wuhan virus 2019'],
#  401,
#  139)

# %%
for term in _2019_var(list_lowercase):
    if check_duplicate_words_from_single_term(term):
        print(term)
# Out:
# 2019new new sars cov 2
# 2019 new coronavirus pneumonia cov
# 2019novel new sars cov 2 virus
# 2019 novel new sars cov 2 virus
# 2019novel china virus
# 2019 new wuhan seafood market pneumonia virus
# 2019 novel severe acute respiratory syndrome coronavirus 2
# 2019 novel novel coronavirus pneumonia cov
# 2019new new coronavirus disease cov
# 2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# 2019novel cov2
# 2019 novel ncov 2
# 2019 novel chinese coronavirus
# wuhan novel coronavirus
# 2019 sars (severe acute respiratory syndrome) cov 2
# 2019 novel new coronavirus cov
# 2019new wuhan novel coronavirus
# 2019novel sars cov 2 disease cov
# china virus
# 2019 sars cov 2 (sc2) virus
# 2019novel human coronavirus 2
# 2019 novel sars (severe acute respiratory syndrome) cov 2 virus
# 2019 new sars coronavirus 2
# 2019 sars cov2 (cov2) virus
# 2019 novel novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# new coronavirus disease cov 2019
# 2019novel sars cov 2 (cov 2) coronavirus
# 2019new novel severe acute respiratory syndrome (sars) cov 2
# ncov 2 2019
# 2019 novel sars cov 2 disease cov
# severe acute respiratory syndrome coronavirus (cov) 2 2019
# 2019new human coronaviruses (hcovs) 2
# 2019novel acute respiratory syndrome coronavirus 2
# 2019 new novel severe acute respiratory syndrome coronavirus 2 virus
# new coronavirus cov
# sars cov 2 (sc2) virus 2019
# sars cov 2 coronavirus 2019
# 2019 chinese coronavirus
# 2019novel cov 2 virus
# 2019novel novel sars cov 2 virus
# severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# virus that causes covid 19 acute respiratory syndrome
# 2019new sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# 2019 novel novel coronavirus disease cov
# 2019novel novel coronavirus disease cov
# 2019novel novel coronavirus related pneumonia cov
# 2019new new severe acute respiratory syndrome coronavirus 2
# 2019 new cov
# 2019new virus causing coronavirus disease
# 2019 novel sars cov 2 coronaviruses
# new sars cov 2 virus
# 2019 sars cov 2 virus
# 2019 novel novel severe acute respiratory syndrome (sars) cov 2
# novel coronavirus 2
# coronavirus disease 2019 (sars cov 2) virus
# ncov 2
# 2019new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# 2019 novel novel coronavirus 2
# 2019 new new coronavirus pneumonia cov
# 2019new cov 2 virus
# novel coronavirus pneumonia cov 2019
# novel sars cov 2 coronavirus
# sars cov 2 (covid 19) coronavirus
# virus that causes covid 19 infection
# 2019novel sars cov 2 coronaviruses
# 2019novel severe acute respiratory syndrome coronavirus (cov) 2
# virus that causes coronavirus disease 2019
# novel coronavirus (2019 ncov) associated disease cov
# 2019 novel coronavirus pneumonia cov
# hcov 2 2019
# novel coronavirus related pneumonia cov 2019
# 2019novel novel sars cov 2
# coronavirus
# 2019novel coronavirus
# 2019 coronavirus disease cov
# 2019new novel coronavirus 2
# severe acute respiratory syndrome virus 2 2019
# 2019new wuhan pneumonia virus
# wuhan seafood market pneumonia virus 2019
# 2019 sars cov 2 (cov 2) coronavirus
# novel coronavirus causing coronavirus disease 2019
# 2019 novel cov
# novel coronavirus (sars cov 2) that causes covid 19
# new severe acute respiratory syndrome (sars) coronavirus 2 2019
# 2019new novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# sars cov 2 associated cov
# 2019 novel severe acute respiratory syndrome coronavirus (cov) 2
# 2019 new novel sars cov 2 coronavirus
# 2019 new novel sars cov 2 virus
# 2019novel new coronavirus cov
# new coronavirus disease cov
# novel coronavirus syndrome coronavirus 2019
# 2019novel wuhan pneumonia virus
# 2019 new new sars cov 2
# 2019new ncov 2
# 2019novel novel sars cov 2 coronavirus
# 2019 new sars cov 2 (cov 2) coronavirus
# 2019new sars cov 2 (sc2) virus
# 2019new novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# severe acute respiratory syndrome (sars) coronavirus (cov) 2 2019
# 2019novel new severe acute respiratory syndrome (sars) coronavirus 2
# 2019 wuhan pneumonia virus
# covid 19 cov
# 2019 novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# coronavirus that causes coronavirus disease 2019
# severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019 novel sars cov 2 associated cov
# 2019 new sars cov 2 viruses
# 2019novel novel cov
# acute respiratory syndrome coronavirus 2 2019
# 2019new coronavirus disease cov
# 2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# 2019 novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# 2019new sars cov 2 coronavirus
# 2019 ncov, 2019 novel coronavirus
# 2019new sars cov 2 coronaviruses
# 2019 sars (severe acute respiratory syndrome) cov 2 virus
# 2019novel china cov
# novel severe acute respiratory syndrome (sars) cov 2
# 2019new new coronavirus infection cov
# 2019novel cov2 coronavirus
# 2019 novel wuhan cov
# novel coronavirus that causes novel coronavirus disease 2019
# 2019novel new severe acute respiratory syndrome coronavirus 2
# 2019 new wuhan novel coronavirus
# 2019 novel wuhan virus
# 2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# severe acute respiratory syndrome virus 2
# 2019 wuhan cov
# 2019 novel novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019 cov2
# covid 19 novel coronavirus
# 2019 new novel coronavirus infection cov
# 2019new acute respiratory syndrome coronavirus 2
# 2019new severe acute respiratory syndrome coronavirus 2 virus
# novel severe acute respiratory syndrome coronavirus 2
# 2019 new china virus
# novel coronavirus causing covid 19
# 2019 sars cov 2 disease cov
# 2019new novel sars cov 2 virus
# 2019 novel novel severe acute respiratory syndrome (sars) coronavirus 2
# virus that causes covid 19 disease
# 2019novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# wuhan virus 2019
# cov 2 virus
# 2019new new sars cov 2 coronavirus
# 2019new sars cov 2 virus
# acute respiratory syndrome coronavirus 2
# 2019 novel china cov
# acute respiratory syndrome coronavirus causing coronavirus disease 2019
# novel coronavirus (severe acute respiratory syndrome coronavirus 2) that causes coronavirus disease 2019
# 2019 new coronavirus infectious disease cov
# sars cov 2 (cov 2) coronavirus 2019
# 2019 new cov 2 virus
# 2019 new new severe acute respiratory syndrome (sars) coronavirus 2
# 2019 novel cov2
# new coronavirus pneumonia cov
# novel sars coronavirus 2 2019
# 2019novel coronavirus (sars cov 2) responsible for coronavirus disease
# 2019 new novel coronavirus related pneumonia cov
# 2019novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# 2019new novel severe acute respiratory syndrome (sars) coronavirus 2
# 2019novel novel coronavirus syndrome coronavirus
# 2019novel ncov 2
# 2019 cov
# novel coronavirus (severe acute respiratory syndrome coronavirus 2, or sars cov 2) that causes coronavirus disease 2019
# novel sars cov 2 virus
# 2019new chinese coronavirus
# 2019new new coronavirus pneumonia cov
# 2019 new new coronavirus cov
# human coronaviruses (hcovs) 2 2019
# 2019 novel new coronavirus disease cov
# wuhan seafood market pneumonia virus
# 2019new novel severe acute respiratory syndrome coronavirus 2 virus
# novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019
# 2019new novel coronavirus related pneumonia cov
# 2019 severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019 hcov 2
# severe acute respiratory syndrome coronavirus (cov) 2
# 2019 ncov
# 2019 novel novel sars cov 2
# sars cov 2 novel coronavirus 2019
# cov 19 virus
# 2019novel new sars cov 2
# 2019new coronavirus infectious disease cov
# 2019new new coronavirus infections cov
# novel coronavirus that causes covid 19
# 2019new severe acute respiratory syndrome coronavirus (cov) 2
# 2019new ncov
# 2019 wuhan seafood market pneumonia virus
# 2019 novel sars cov 2 coronavirus
# 2019 new novel severe acute respiratory syndrome coronavirus 2
# new sars cov 2 coronavirus 2019
# 2019new novel sars cov 2
# 2019new new severe acute respiratory syndrome (sars) coronavirus 2
# 2019new novel coronavirus syndrome coronavirus
# 2019 new sars cov 2 new corona virus
# sars cov 2 (2019 ncov, covid 19) coronavirus
# 2019novel novel severe acute respiratory syndrome coronavirus 2 virus
# 2019 sars cov 2 coronaviruses
# 2019 human coronavirus 2
# novel severe acute respiratory syndrome coronavirus 2 virus 2019
# novel severe acute respiratory syndrome coronavirus 2 2019
# 2019 new sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# 2019 novel coronavirus related pneumonia cov
# new coronavirus that causes covid 19
# 2019new sars cov 2 disease cov
# sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus 2019
# 2019new sars (severe acute respiratory syndrome) cov 2
# novel cov 2019
# 2019 new new sars coronavirus 2
# coronavirus responsible for coronavirus disease 2019
# wuhan novel coronavirus 2019
# novel coronavirus cov 2019
# 2019 new wuhan virus
# novel sars cov 2 virus 2019
# coronavirus (sars cov 2) responsible for coronavirus disease 2019
# 2019 virus that causes coronavirus disease
# 2019 new coronavirus infections cov
# chinese coronavirus
# 2019 novel coronavirus infection cov
# 2019 new new coronavirus infection cov
# 2019 new chinese coronavirus
# 2019 new virus that causes coronavirus disease
# 2019novel severe acute respiratory syndrome coronavirus 2 virus
# 2019 novel new coronavirus pneumonia cov
# 2019 new sars cov 2
# novel severe acute respiratory syndrome (sars) cov 2 2019
# 2019 novel sars cov 2
# 2019 sars cov 2 novel coronavirus
# severe acute respiratory syndrome coronavirus 2 virus
# 2019 new human coronaviruses (hcovs) 2
# human coronavirus 2
# 2019novel severe acute respiratory syndrome virus 2
# 2019 novel hcov 2
# 2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019 new novel coronavirus disease cov
# 2019 coronavirus
# 2019 novel novel severe acute respiratory syndrome coronavirus 2
# 2019 new coronavirus cov
# 2019 new sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# severe acute respiratory syndrome (sars) cov2 (also referred to as covid 19) coronavirus
# sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# 2019novel sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# wuhan pneumonia virus
# 2019new sars cov 2 new corona virus
# novel coronavirus syndrome coronavirus
# novel severe acute respiratory syndrome (sars) coronavirus (cov)2 2019
# coronavirus causing coronavirus disease 2019
# 2019 new sars cov 2 associated cov
# 2019 novel novel severe acute respiratory syndrome coronavirus 2 virus
# 2019 novel ncov
# ncov
# china virus 2019
# 2019 novel severe acute respiratory syndrome virus 2
# 2019novel novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# 2019 new coronavirus disease cov
# 2019novel novel severe acute respiratory syndrome (sars) cov 2
# 2019new new coronavirus cov
# 2019 new novel sars cov 2
# 2019 novel new sars coronavirus 2
# sars cov 2 (covid 19) virus
# 2019 new sars cov 2 coronaviruses
# 2019 wuhan virus
# 2019 new sars cov 2 (sc2) virus
# 2019 novel new cov
# new sars cov 2 2019
# 2019 novel novel sars coronavirus 2
# new coronavirus infection cov 2019
# 2019novel novel severe acute respiratory syndrome (sars) coronavirus 2
# 2019 cov2 coronavirus
# 2019 coronaviruses
# novel coronavirus disease cov 2019
# sars cov 2 new corona virus
# 2019new novel coronavirus disease cov
# 2019 novel severe acute respiratory syndrome (sars) cov 2
# virus that causes coronavirus 19 disease
# 2019 novel sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# virus which causes coronavirus disease 2019
# 2019new novel sars cov 2 coronavirus
# 2019 novel sars (severe acute respiratory syndrome) cov 2
# sars cov 19 virus
# 2019 new coronavirus (sars cov 2) responsible for coronavirus disease
# novel cov
# 2019novel sars cov 2 cov
# 2019novel novel coronavirus pneumonia cov
# 2019 new novel coronavirus syndrome coronavirus
# virus that causes coronavirus disease
# 2019 ncov virus
# 2019 novel coronavirus
# 2019 novel novel coronavirus related pneumonia cov
# wuhan pneumonia virus 2019
# 2019novel chinese coronavirus
# sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus 2019
# 2019novel novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019new novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019 virus causing coronavirus disease
# 2019new severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019 new coronaviruses
# 2019 new novel coronavirus pneumonia cov
# novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019novel coronavirus disease cov
# novel coronavirus pneumonia cov
# 2019 new novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019new sars cov 2 associated cov
# 2019 new sars cov 2 novel coronavirus
# china cov 2019
# 2019 novel sars cov 2 cov
# novel sars coronavirus 2019
# 2019 novel cov 2 virus
# 2019 sars cov 2 associated cov
# 2019 severe acute respiratory syndrome coronavirus (cov) 2
# sars (severe acute respiratory syndrome) cov 2
# new severe acute respiratory syndrome (sars) coronavirus 2
# virus causing covid 19
# 2019 new wuhan cov
# novel coronavirus infection cov
# 2019 novel coronavirus (sars cov 2) responsible for coronavirus disease
# 2019 novel sars cov 2 viruses
# new cov 2019
# 2019 new new sars cov 2 virus
# coronaviruses
# novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# 2019 new new cov
# 2019 novel sars coronavirus 2
# 2019 new new coronavirus infections cov
# sars cov 2 coronavirus
# novel coronavirus 2019 (covid 19) virus
# novel severe acute respiratory syndrome coronavirus 2 virus
# virus that causes covid 19
# sars cov 2 viruses 2019
# sars cov 2 viruses
# coronavirus (sars cov 2) responsible for coronavirus disease
# new sars coronavirus 2
# 2019 new new coronavirus disease cov
# 2019 novel coronaviruses
# sars cov 2 new corona virus 2019
# 2019 ncov 2
# 2019novel novel coronavirus 2
# 2019novel virus causing coronavirus disease
# virus causing coronavirus disease
# 2019new sars cov 2 cov
# new severe acute respiratory syndrome coronavirus 2 2019
# 2019 new severe acute respiratory syndrome coronavirus (cov) 2
# novel sars coronavirus 2
# 2019novel new cov
# sars cov 2019 virus
# 2019 novel sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# cov2 coronavirus 2019
# novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia 2019
# new coronavirus infections cov 2019
# 2019 new novel coronavirus cov
# 2019 novel sars cov 2 virus
# 2019 acute respiratory syndrome coronavirus 2
# 2019 new ncov
# 2019 new severe acute respiratory syndrome virus 2
# sars cov 2 novel coronavirus
# 2019new virus that causes coronavirus disease
# 2019 new wuhan pneumonia virus
# 2019 novel wuhan novel coronavirus
# virus causing coronavirus disease 2019
# 2019new severe acute respiratory syndrome (sars) coronavirus (cov) 2
# 2019novel new sars cov 2 coronavirus
# novel coronavirus 2 2019
# severe acute respiratory syndrome (sars) coronavirus (cov) 2
# virus responsible for coronavirus disease 2019
# 2019 new new severe acute respiratory syndrome coronavirus 2
# 2019novel sars cov 2 (sc2) virus
# 2019 new novel coronavirus 2
# 2019 novel wuhan pneumonia virus
# 2019 new sars cov 2 disease cov
# 2019 new novel severe acute respiratory syndrome (sars) coronavirus 2
# 2019 new sars cov 2 coronavirus
# 2019novel wuhan novel coronavirus
# 2019novel novel severe acute respiratory syndrome coronavirus 2
# 2019 novel novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# 2019 novel virus that causes coronavirus disease
# 2019 new severe acute respiratory syndrome coronavirus 2
# 2019 novel cov2 coronavirus
# 2019new wuhan cov
# 2019 novel coronavirus infectious disease cov
# novel sars cov 2 2019
# 2019 new sars (severe acute respiratory syndrome) cov 2
# 2019novel wuhan cov
# 2019new sars cov 2 (cov 2) coronavirus
# sars cov2 (cov2) virus
# 2019 novel sars cov 2 novel coronavirus
# 2019 human coronaviruses (hcovs) 2
# severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov 2019
# new sars cov 2
# 2019 new cov2
# 2019new novel coronavirus infection cov
# 2019 novel new coronavirus infections cov
# coronavirus that causes covid 19
# 2019 novel human coronaviruses (hcovs) 2
# 2019novel severe acute respiratory syndrome (sars) coronavirus (cov) 2
# 19 coronavirus
# 2019 new severe acute respiratory syndrome (sars) coronavirus (cov) 2
# 2019 new novel sars coronavirus 2
# 2019 new novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# 2019 novel sars cov2 (cov2) virus
# sars (severe acute respiratory syndrome) cov 2 2019
# 2019 new ncov 2
# 2019 novel virus causing coronavirus disease
# 19 ncov
# 2019new novel coronavirus cov
# 2019new novel severe acute respiratory syndrome coronavirus 2
# 2019 novel new sars cov 2
# 2019 sars cov 2 new corona virus
# coronavirus infectious disease cov 2019
# severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus 2019
# coronavirus (sars cov 2) causing covid 19
# 2019 new hcov 2
# 2019new novel cov
# 2019 new novel severe acute respiratory syndrome (sars) cov 2
# 2019 novel severe acute respiratory syndrome (sars) coronavirus (cov) 2
# human coronaviruses (hcovs) 2
# 2019novel ncov
# 2019 novel coronavirus syndrome coronavirus
# 2019 sars cov 2 (severe acute respiratory syndrome coronavirus 2) coronavirus
# china cov
# coronavirus responsible for covid 19
# 2019new novel coronavirus pneumonia cov
# 2019 novel novel coronavirus syndrome coronavirus
# cov2 2019
# new sars cov 2 coronavirus
# sars (severe acute respiratory syndrome) cov 2 virus 2019
# novel coronavirus responsible for covid 19 illness
# sars cov 2 disease cov
# 2019new coronaviruses
# 2019novel new sars coronavirus 2
# 2019 novel novel coronavirus infection cov
# 2019 wuhan novel coronavirus
# 2019novel sars cov 2 novel coronavirus
# 2019 severe acute respiratory syndrome (sars) coronavirus (cov) 2
# new coronavirus infections cov
# 2019 new sars cov 2 virus
# 2019 new coronavirus infection cov
# 2019 novel novel cov
# 2019new china cov
# 2019 novel wuhan seafood market pneumonia virus
# 2019new cov2
# sars cov 2 cov
# 2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# 2019 sars cov 2 coronavirus
# virus causing covid 19 disease
# virus causing 2019 coronavirus disease
# novel coronavirus related pneumonia cov
# 2019novel new coronavirus disease cov
# sars cov 2 (sc2) virus
# 2019 new acute respiratory syndrome coronavirus 2
# new coronavirus pneumonia cov 2019
# 2019new wuhan seafood market pneumonia virus
# novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# 2019 new severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019new wuhan virus
# 19 cov
# infectious coronavirus that causes covid 19
# 2019 new new sars cov 2 coronavirus
# 2019 novel sars cov 2 (sc2) virus
# new sars coronavirus 2 2019
# sars (severe acute respiratory syndrome) cov 2 virus
# coronavirus disease cov 2019
# novel sars cov 2 coronavirus 2019
# 2019new sars cov 2 novel coronavirus
# severe acute respiratory syndrome coronavirus 2 virus 2019
# 2019novel wuhan seafood market pneumonia virus
# 2019 new human coronavirus 2
# wuhan cov
# 2019 coronavirus (sars cov 2) responsible for coronavirus disease
# sars cov 2 (cov 2) coronavirus
# sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# 2019 novel severe acute respiratory syndrome coronavirus 2 (sars cov 2) cov
# 2019novel novel coronavirus (sars cov 2) that causes novel coronavirus pneumonia
# 2019novel sars cov 2 coronavirus
# 2019 severe acute respiratory syndrome coronavirus 2 virus
# coronavirus infectious disease cov
# sars cov 2 coronaviruses 2019
# 2019 new sars cov 2 cov
# novel coronavirus disease cov
# severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019novel sars cov 2 new corona virus
# virus that causes coronavirus disease 2019 (covid 19) pneumonia
# 2019new novel sars coronavirus 2
# 2019 novel severe acute respiratory syndrome coronavirus 2 virus
# 2019 severe acute respiratory syndrome virus 2
# 2019 novel novel sars cov 2 virus
# 2019novel new coronavirus infection cov
# 2019 cov 2 virus
# 2019new new cov
# sars cov 2 associated cov 2019
# 2019new severe acute respiratory syndrome virus 2
# 2019novel novel coronavirus cov
# human coronavirus 2 2019
# 2019novel sars (severe acute respiratory syndrome) cov 2
# 2019novel sars cov 2 virus
# chinese coronavirus 2019
# 2019 new novel cov
# ncov 2019
# 2019 new severe acute respiratory syndrome coronavirus 2 virus
# coronaviruses that causes coronavirus disease 2019
# 2019 novel new sars cov 2 coronavirus
# 2019 novel coronavirus cov
# 2019 novel novel sars cov 2 coronavirus
# 2019novel coronaviruses
# 2019 novel severe acute respiratory syndrome (sars) coronavirus 2
# novel coronavirus infection cov 2019
# 2019novel human coronaviruses (hcovs) 2
# 2019novel new coronavirus pneumonia cov
# sars cov2 (cov2) virus 2019
# 2019 new coronavirus
# 2019 novel china virus
# 2019 sars cov 2 cov
# 2019new china virus
# new cov
# 2019new new sars coronavirus 2
# sars cov 2 cov 2019
# novel coronavirus cov
# 2019 novel new severe acute respiratory syndrome coronavirus 2
# sars cov 2 virus 2019
# 2019 new china cov
# cov2
# pneumonia causing covid 19
# 2019novel novel coronavirus infection cov
# hcov 2
# novel severe acute respiratory syndrome (sars) coronavirus 2
# 2019 severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019novel coronavirus infectious disease cov
# virus responsible for covid 19 disease
# new sars cov 2 virus 2019
# 2019new new sars cov 2 virus
# 2019 novel human coronavirus 2
# 2019 china cov
# sars cov 2 disease cov 2019
# 2019 new severe acute respiratory syndrome (sars) coronavirus 2
# new coronavirus cov 2019
# sars cov 2 coronaviruses
# 2019 new virus causing coronavirus disease
# new severe acute respiratory syndrome coronavirus 2
# 2019 novel novel coronavirus cov
# cov2 coronavirus
# novel sars cov 2
# 2019novel virus that causes coronavirus disease
# 2019 sars cov 2 viruses
# sars cov 19
# 2019new sars cov2 (cov2) virus
# 2019new human coronavirus 2
# wuhan cov 2019
# new coronavirus infection cov
# 2019 coronavirus infectious disease cov
# 2019new cov2 coronavirus
# novel coronavirus that causes covid 19 disease
# 2019novel sars cov 2 associated cov
# novel severe acute respiratory syndrome (sars) coronavirus 2 2019
# severe acute respiratory syndrome coronavirus (sars cov) 2 virus 2019
# 2019 new sars cov2 (cov2) virus
# covid 19 viruses
# 2019 china virus
# virus responsible for covid 19
# 2019new hcov 2
# 2019 sars cov 2 (severe acute respiratory syndrome   coronavirus 2) virus
# 2019new sars (severe acute respiratory syndrome) cov 2 virus
# 2019 new novel severe acute respiratory syndrome (sars) coronavirus (cov)2
# 2019 novel new coronavirus infection cov
# 2019novel novel sars coronavirus 2
# 2019novel sars (severe acute respiratory syndrome) cov 2 virus
# sars cov 2 virus
# 2019new sars cov 2 viruses
# 2019novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019 new sars (severe acute respiratory syndrome) cov 2 virus
# 2019novel hcov 2
# 2019novel sars cov 2 viruses
# novel coronavirus that causes coronavirus disease 2019
# 2019novel wuhan virus
# 2019novel new coronavirus infections cov
# coronavirus disease 2019 cov
# wuhan virus
# coronavirus disease cov
# coronaviruses 2019
# 2019 novel new severe acute respiratory syndrome (sars) coronavirus 2
# sars cov 2019
# 2019new coronavirus (sars cov 2) responsible for coronavirus disease
# 2019novel sars cov2 (cov2) virus
# 2019 novel sars cov 2 (cov 2) coronavirus
# coronavirus 2019
# 2019 novel coronavirus disease cov
# 2019new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# 2019new coronavirus
# 2019 novel severe acute respiratory syndrome coronavirus (sars cov) 2 virus
# 2019 new cov2 coronavirus
# 2019 novel acute respiratory syndrome coronavirus 2
# 2019 novel coronavirus 2
# 2019 new severe acute respiratory syndrome coronavirus 2 (sars cov 2) virus
# cov 2 virus 2019
# 2019 novel sars cov 2 new corona virus

# %%
txt = "2019new "
if re.compile(r"\b2019new\b").search(txt) and (re.compile(r"\bnew\b").search(txt)):
    print("yep")

# %%
re.compile(r'\b2019new\b').search(txt)
# Out:
# <re.Match object; span=(0, 7), match='2019new'>

# %%
re.compile("\b2019new\b").search(txt)

# %%
txt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17848/424762397.py in <module>
# ----> 1 txt.search()
#
# AttributeError: 'str' object has no attribute 'search'
