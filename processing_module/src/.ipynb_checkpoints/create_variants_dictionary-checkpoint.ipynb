# %% [markdown]
# # This notebook is used to create a variants dictionary for covid 19 variants

# %%
import numpy as np
import pandas as pd
import nltk

# %%
file1 = "../data/cov_variants/Cov-Lineages.html"

# %%
df1 = pd.read_html(file1, header=0)[0]

# %%
df1
# Out:
#          Lineage                              Most common countries  \
# 0              A  United States of America 27.0%, United_Arab_Em...
# 1            A.1  United States of America 81.0%, Australia 9.0%...
# 2            A.2  Spain 70.0%, United Kingdom 6.0%, Panama 5.0%,...
# 3          A.2.2  Australia 92.0%, New_Zealand 3.0%, Canada 2.0%...
# 4          A.2.3  United Kingdom 99.0%, Finland 0.0%, Spain 0.0%...
# ...          ...                                                ...
# 1723   B.1.160.4                                                NaN
# 1724   B.1.160.5                                                NaN
# 1725   B.1.160.6                                                NaN
# 1726   B.1.177.1                                                NaN
# 1727  B.1.177.13                                                NaN
#
#      Earliest date  # designated  # assigned  \
# 0       2019-12-30          1698        2240
# 1       2020-01-01          2699        3033
# 2       2020-02-17          1107        1268
# 3       2020-03-17           473         549
# 4       2020-02-26           167         203
# ...            ...           ...         ...
# 1723           NaN             0           0
# 1724           NaN             0           0
# 1725           NaN             0           0
# 1726           NaN             0           0
# 1727           NaN             0           0
#
#                                             Description  WHO Name
# 0     Root of the pandemic lies within lineage A. Ma...       NaN
# 1                                           USA lineage       NaN
# 2     Mostly Spanish lineage now includes South and ...       NaN
# 3                                    Australian lineage       NaN
# 4                                      Scottish lineage       NaN
# ...                                                 ...       ...
# 1723  Lineage reassigned. Withdrawn: English lineage...       NaN
# 1724      Lineage reassigned. Withdrawn: Danish lineage       NaN
# 1725  Lineage reassigned. Withdrawn: Danish lineage,...       NaN
# 1726             Lineage reassigned. Withdrawn: Denmark       NaN
# 1727  Lineage reassigned. Withdrawn, now part of B.1...       NaN
#
# [1728 rows x 7 columns]

# %%
file2 = "../data/cov_variants/ncov_clades.tsv at master · nextstrain_ncov.htm"

# %%
df2 = pd.read_html(file2)[0]
df2
# Out:
#      Unnamed: 0          clade gene   site alt
# 0           NaN            19A  nuc   8782   C
# 1           NaN            19A  nuc  14408   C
# 2           NaN            19B  nuc   8782   T
# 3           NaN            19B  nuc  28144   C
# 4           NaN            20A  nuc   8782   C
# ..          ...            ...  ...    ...  ..
# 123         NaN  21L (Omicron)  nuc  24424   T
# 124         NaN  21L (Omicron)  nuc  27259   C
# 125         NaN  21M (Omicron)  nuc  23525   T
# 126         NaN  21M (Omicron)  nuc  23599   G
# 127         NaN  21M (Omicron)  nuc  27259   C
#
# [128 rows x 5 columns]

# %%
set1 = set(df1["Lineage"].tolist())
set2 = set(df2["clade"].tolist())

# %%
set1
# Out:
# {'B.1.1.319',
#  'B.1.1.143',
#  'B.1.1.29',
#  'B.1.1.375',
#  'B.1.502',
#  'B.1.13',
#  'AB.1',
#  'B.1.188',
#  'B.1.478',
#  'AY.46.1',
#  'B.1.1.451',
#  'B.1.1.463',
#  'B.1.320',
#  'A.29',
#  'B.1.1.27',
#  'B.1.571',
#  'AV.1',
#  'AY.16',
#  'P.1.3',
#  'B.1.1.272',
#  'B.1.335',
#  'B.1.161',
#  'AK.1',
#  'B.1.95',
#  'B.1.177.89',
#  'B.1.1.289',
#  'AY.116',
#  'B.1.361',
#  'B.1.273',
#  'B.1.231',
#  'B.1.277',
#  'B.1.177.21',
#  'AY.47',
#  'B.1.1.61',
#  'B.1.265',
#  'C.27',
#  'B.1.1.285',
#  'B.1.139',
#  'B.1.348',
#  'C.13',
#  'B.1.1.108',
#  'B.1.1.13',
#  'B.1.1.485',
#  'B.29',
#  'B.1.598',
#  'B.1.459',
#  'A.18',
#  'B.1.107',
#  'C.2',
#  'BA.1.1',
#  'B.51',
#  'P.5',
#  'D.3',
#  'B.1.177.60',
#  'AY.124.1',
#  'K.3',
#  'B.1.326',
#  'A.16',
#  'B.1.358',
#  'B.1.614',
#  'AY.114',
#  'B.1.177.71',
#  'B.1.329',
#  'B.1.12',
#  'B.1.367',
#  'A.7',
#  'B.1.1.47',
#  'B.1.1.410',
#  'B.1.177.48',
#  'B.1.569',
#  'B.1.1.282',
#  'B.1.166',
#  'B.1.549',
#  'AY.43.5',
#  'B.1.36.21',
#  'AY.120.2.1',
#  'AY.7.1',
#  'Q.2',
#  'B.1.1.36',
#  'B.1.509',
#  'B.1.1.179',
#  'B.1.151',
#  'B.1.36.31',
#  'B.1.177.81',
#  'B.1.1.90',
#  'B.1.1.89',
#  'B.1.1.50',
#  'AY.44',
#  'B.1.1.70',
#  'AY.4.3',
#  'B.1.160.6',
#  'B.38',
#  'B.1.1.275',
#  'P.2',
#  'B.1.1.418',
#  'AY.42',
#  'AY.99',
#  'B.1.1.95',
#  'B.1.192',
#  'B.1.177.37',
#  'B.1.1.147',
#  'B.1.362',
#  'B.1.520',
#  'B.1.1.385',
#  'C.3',
#  'AY.94',
#  'B.1.1.269',
#  'AY.29',
#  'B.1.177.86',
#  'N.4',
#  'B.1.205',
#  'B.1.1.528',
#  'AY.119.1',
#  'B.1.36.17',
#  'A.2.3',
#  'B.1.177.46',
#  'XC',
#  'B.1.258.17',
#  'B.39',
#  'B.1.1.401',
#  'B.1.1.449',
#  'AY.43',
#  'A.17',
#  'B.1.1.234',
#  'B.1.1.448',
#  'B.1.566',
#  'B.1.116',
#  'AZ.6',
#  'B.1.576',
#  'B.1.1.204',
#  'B.1.258.15',
#  'B.1.431',
#  'B.1.1.142',
#  'B.13',
#  'B.1.1.25',
#  'B.1.1.444',
#  'BA.3',
#  'B.1.1.220',
#  'P.1.2',
#  'B.1.1.334',
#  'AY.36',
#  'B.1.1.482',
#  'B.1.593',
#  'B',
#  'B.1.1.526',
#  'AY.39.1',
#  'B.1.36.29',
#  'B.1.1.313',
#  'U.2',
#  'B.1.1.200',
#  'B.1.177.69',
#  'B.1.1.216',
#  'AY.23',
#  'B.1.460',
#  'AY.34.1.1',
#  'AY.80',
#  'B.27',
#  'A.27',
#  'B.1.1.309',
#  'B.1.165',
#  'B.1.1.109',
#  'W.4',
#  'B.1.1.357',
#  'B.1.436',
#  'B.1.1.416',
#  'B.1.1.53',
#  'B.1.214',
#  'AY.59',
#  'B.1.1.107',
#  'B.1.433',
#  'B.1.429.1',
#  'C.20',
#  'B.1.1.431',
#  'B.1.577',
#  'B.1.1.39',
#  'B.1.1.97',
#  'B.1.110.1',
#  'U.3',
#  'B.1.212',
#  'B.1.1.371',
#  'B.1.177.66',
#  'B.1.1.278',
#  'B.1.177.39',
#  'B.1.1.51',
#  'AY.42.1',
#  'B.1.621.1',
#  'P.1.10.1',
#  'B.1.1.413',
#  'AY.127.1',
#  'XB',
#  'B.1.1.16',
#  'AY.131',
#  'B.1.1.400',
#  'AY.79',
#  'B.1.1.145',
#  'B.1.1.481',
#  'B.1.160.4',
#  'B.1.1.362',
#  'B.1.258.23',
#  'B.1.521',
#  'B.1.1.41',
#  'B.1.1.346',
#  'A.14',
#  'B.1.258.4',
#  'P.1.12.1',
#  'B.1.1.364',
#  'B.1.36.38',
#  'B.1.473',
#  'B.1.1.527',
#  'B.1.160.10',
#  'W.1',
#  'B.1.395',
#  'B.1.1.224',
#  'B.1.1.113',
#  'B.1.1.340',
#  'B.1.400',
#  'B.1.505',
#  'Q.7',
#  'B.1.70',
#  'B.1.3.1',
#  'AY.23.2',
#  'P.4',
#  'B.1.136',
#  'B.1.1.349',
#  'B.1.344',
#  'B.1.160.2',
#  'B.1.1.1',
#  'B.1.221.3',
#  'B.1.134',
#  'B.1.177.24',
#  'B.1.168',
#  'B.1.554',
#  'B.1.375',
#  'B.1.36.24',
#  'AY.13',
#  'V.1',
#  'AY.75.3',
#  'B.1.3.4',
#  'B.1.1.177',
#  'AA.4',
#  'B.1.97',
#  'B.1.160.20',
#  'B.1.617.1',
#  'B.40',
#  'B.1.258.3',
#  'B.1.22.1',
#  'AY.122',
#  'B.1.6',
#  'AY.18',
#  'B.1.1.374',
#  'AY.4.6',
#  'B.1.89',
#  'AY.9',
#  'B.1.160.29',
#  'B.1.1.325',
#  'B.1.1.186',
#  'B.1.274',
#  'B.1.563',
#  'B.1.5.36',
#  'B.1.1.337',
#  'B.1.492',
#  'B.1.533',
#  'B.1.36.12',
#  'AY.5.3',
#  'B.1.177.19',
#  'B.1.223',
#  'B.1.177.18',
#  'B.1.301',
#  'AY.27',
#  'B.1.1.82',
#  'AY.7',
#  'C.12',
#  'B.1.177.27',
#  'AY.75.2',
#  'B.1.1.251',
#  'AY.74',
#  'B.1.463',
#  'B.1.1.10',
#  'B.1.406',
#  'B.1.639',
#  'B.1.75',
#  'B.1.1.100',
#  'AY.121.1',
#  'C.30.1',
#  'B.1.428.3',
#  'B.1.213',
#  'B.1.1.437',
#  'B.1.1.459',
#  'B.1.1.238',
#  'B.1.177.61',
#  'B.1.36.7',
#  'B.1.264',
#  'C.18',
#  'B.1.1.93',
#  'B.1.1.207',
#  'B.1.1.203',
#  'B.1.1.209',
#  'B.1.620',
#  'B.1.1.218',
#  'B.1.214.3',
#  'AY.4.5',
#  'B.1.1.294',
#  'AY.15',
#  'B.1.1.523',
#  'B.1.281',
#  'C.36.3.1',
#  'B.1.1.118',
#  'B.1.1.63',
#  'B.1.1.378',
#  'B.1.513',
#  'B.1.83',
#  'B.1.1.315',
#  'A.12',
#  'B.1.487',
#  'B.1.504',
#  'B.1.5.27',
#  'B.1.189',
#  'B.1.36.2',
#  'B.1.350.1',
#  'B.1.1.103',
#  'B.1.1.298',
#  'B.1.496',
#  'Q.6',
#  'B.1.1.428',
#  'AY.45',
#  'B.1.418',
#  'B.1.177.73',
#  'AY.99.2',
#  'AY.119.2',
#  'B.1.1.368',
#  'B.1.1.514',
#  'B.1.399',
#  'B.1.276',
#  'B.1.398',
#  'P.1.8',
#  'B.1.39',
#  'AL.1',
#  'B.1.1.255',
#  'B.1.546',
#  'B.1.1.215',
#  'AY.105',
#  'C.37.1',
#  'B.1.1.164',
#  'B.1.465',
#  'V.2',
#  'B.1.38',
#  'B.1.573',
#  'B.1.1.59',
#  'B.1.177.12',
#  'B.1.258.20',
#  'B.1.154',
#  'AZ.2.1',
#  'B.1.589',
#  'B.1.114',
#  'AY.63',
#  'B.1.36.13',
#  'B.1.619.1',
#  'B.1.1.83',
#  'B.1.351.2',
#  'C.35',
#  'B.1.616',
#  'B.1.586',
#  'AY.103',
#  'B.1.408',
#  'B.1.1.386',
#  'Q.8',
#  'B.1.177',
#  'B.1.1.6',
#  'L.2',
#  'AY.64',
#  'B.1.470',
#  'N.8',
#  'B.1.1.290',
#  'B.1.229',
#  'B.1.177.87',
#  'B.1.35',
#  'AY.25.1.1',
#  'B.1.425',
#  'B.1.530',
#  'AY.82',
#  'B.1.1.363',
#  'B.1.1.31',
#  'AY.128',
#  'B.1.1.197',
#  'B.1.160.8',
#  'AY.41',
#  'B.1.1.133',
#  'B.1.310',
#  'B.1.169',
#  'B.52',
#  'B.61',
#  'B.1.1.149',
#  'B.1.5.11',
#  'B.1.1.37',
#  'B.1.1.395',
#  'AZ.2',
#  'AY.33.1',
#  'B.1.640.1',
#  'A.2',
#  'B.1.1.87',
#  'AA.8',
#  'B.1.564.1',
#  'B.1.1.256',
#  'B.1.102',
#  'B.1.88',
#  'B.1.476',
#  'AY.85',
#  'B.1.36.37',
#  'B.1.1.434',
#  'AY.54',
#  'B.1.1.258',
#  'C.1.2',
#  'B.1.1.156',
#  'B.1.1.452',
#  'A.8',
#  'A.4',
#  'AK.2',
#  'AS.2',
#  'B.1.498',
#  'B.1.9.2',
#  'B.1.177.51',
#  'B.1.293',
#  'B.1.1.227',
#  'B.1.258.11',
#  'B.1.555',
#  'B.1.177.47',
#  'B.1.325',
#  'B.1.177.35',
#  'B.1.250',
#  'B.1.160',
#  'B.1.177.53',
#  'AY.66',
#  'AY.35',
#  'A.2.4',
#  'B.1.160.21',
#  'AY.100',
#  'B.1.1.422',
#  'B.1.381',
#  'B.1.1.435',
#  'P.1.11',
#  'B.1.8',
#  'B.1.222',
#  'B.1.108',
#  'B.1.595.4',
#  'B.1.1.77',
#  'B.1.1.380',
#  'B.1.508',
#  'B.4.6',
#  'P.7',
#  'B.1.634',
#  'B.6.1',
#  'B.1.177.76',
#  'B.1.1.365',
#  'AY.26',
#  'B.1.36.23',
#  'AJ.1',
#  'B.1.490',
#  'AY.98.1',
#  'B.1.396',
#  'B.1.1.225',
#  'A.2.5.1',
#  'AY.5.1',
#  'B.1.534',
#  'B.1.9.5',
#  'B.1.160.5',
#  'AY.39.1.1',
#  'B.1.162',
#  'AY.31',
#  'B.1.1.367',
#  'B.1.1.157',
#  'B.1.489',
#  'B.1.160.12',
#  'B.1.1.415',
#  'B.1.402',
#  'B.1.403',
#  'B.1.167',
#  'B.1.1.125',
#  'B.1.562',
#  'B.1.1.436',
#  'A.10',
#  'AY.46.5',
#  'AY.32',
#  'B.1.247',
#  'B.1.1.513',
#  'B.1.149',
#  'B.1.572',
#  'B.1.1.236',
#  'B.1.1.411',
#  'B.1.1.253',
#  'B.47',
#  'B.1.423',
#  'AY.104',
#  'AA.6',
#  'B.1.214.4',
#  'C.38',
#  'B.1.36.26',
#  'B.1.36.28',
#  'B.1.1.152',
#  'B.1.596.1',
#  'AY.132',
#  'B.1.1.153',
#  'B.1.1.308',
#  'B.1.254',
#  'B.1.422',
#  'P.1.17.1',
#  'B.20',
#  'B.49',
#  'A.28',
#  'C.32',
#  'B.1.1.268',
#  'B.1.133',
#  'B.1.36.1',
#  'B.1.1.219',
#  'B.1.1.78',
#  'B.1.1.307',
#  'B.1.1.54',
#  'B.1.491',
#  'B.1.1.158',
#  'B.1.36.33',
#  'B.1.1.206',
#  'U.1',
#  'B.1.456',
#  'AA.3',
#  'B.1.1.250',
#  'B.1.1.65',
#  'B.1.337',
#  'B.1.5.6',
#  'AY.5.2',
#  'B.1.160.17',
#  'B.1.565',
#  'AZ.5',
#  'B.1.159',
#  'P.1.12',
#  'B.1.251',
#  'B.1.1.205',
#  'C.40',
#  'B.1.1.317',
#  'B.1.601',
#  'B.1.258.6',
#  'B.1.323',
#  'B.1.36.9',
#  'AY.16.1',
#  'B.1.258',
#  'B.1.177.56',
#  'B.1.1.248',
#  'AY.69',
#  'B.4.2',
#  'B.1.292',
#  'B.12',
#  'B.1.21',
#  'A.25',
#  'B.1.177.77',
#  'B.1.338',
#  'B.1.177.74',
#  'B.1.11',
#  'B.1.313',
#  'B.1.328',
#  'B.1.617.2',
#  'B.1.1.487',
#  'B.28',
#  'B.1.357',
#  'B.1.1.306',
#  'W.3',
#  'B.1.214.1',
#  'B.1.258.7',
#  'S.1',
#  'XA',
#  'B.1.1.33',
#  'B.1.74',
#  'C.36.1',
#  'B.1.438.4',
#  'AY.87',
#  'B.1.334',
#  'B.1.411',
#  'B.1.160.25',
#  'B.1.1.342',
#  'B.1.14',
#  'B.1.36.5',
#  'AY.4.2.3',
#  'B.1.268',
#  'B.1.258.10',
#  'B.1.5',
#  'B.1.177.31',
#  'B.1.128',
#  'AY.34',
#  'AY.46.6.1',
#  'B.1.351',
#  'B.6.6',
#  'B.1.1.439',
#  'B.1.110.3',
#  'B.1.1.512',
#  'B.1.1.369',
#  'B.1.1.300',
#  'B.1.636',
#  'P.1.16',
#  'B.1.516',
#  'B.1.1.176',
#  'AY.61',
#  'B.1.501',
#  'B.1.1.267',
#  'B.1.177.57',
#  'B.1.1.350',
#  'AY.11',
#  'B.1.177.88',
#  'B.1.316',
#  'B.15',
#  'B.1.621.2',
#  'B.1.1.71',
#  'B.1.497',
#  'B.1.177.32',
#  'B.1.1.399',
#  'B.57',
#  'B.1.590',
#  'AZ.1',
#  'AY.111',
#  'AY.46.2',
#  'B.1.177.59',
#  'K.1',
#  'B.1.177.16',
#  'B.4.7',
#  'B.1.1.398',
#  'B.1.1.424',
#  'AY.81',
#  'B.1.1.456',
#  'C.25',
#  'B.1.177.50',
#  'B.1.499.1',
#  'A',
#  'AY.4.2.1',
#  'B.1.1.201',
#  'B.1.210',
#  'AY.57',
#  'AN.1',
#  'Z.1',
#  'AM.4',
#  'B.1.1.84',
#  'B.1.1.339',
#  'C.14',
#  'B.1.131',
#  'B.1.249',
#  'B.1.177.15',
#  'B.1.531',
#  'B.1.219',
#  'B.1.427',
#  'B.1.1.273',
#  'B.1.1.310',
#  'AY.130',
#  'B.1.3.2',
#  'B.1.595',
#  'B.1.432',
#  'B.1.536',
#  'B.1.393',
#  'B.1.1.293',
#  'B.1.177.42',
#  'B.1.1.241',
#  'B.1.1.388',
#  'B.1.528',
#  'B.1.177.6',
#  'B.1.1.420',
#  'B.1.177.67',
#  'B.1.258.19',
#  'B.1.1.44',
#  'B.1.1.49',
#  'B.1.405',
#  'AY.83',
#  'B.1.1.212',
#  'C.30',
#  'B.1.1.335',
#  'P.1.13',
#  'AY.17',
#  'B.1.1.112',
#  'B.1.177.83',
#  'B.1.184',
#  'B.1.1.131',
#  'B.1.1.396',
#  'B.1.1.292',
#  'B.1.1.262',
#  'B.1.613',
#  'B.1.506',
#  'B.1.579',
#  'AY.46.4',
#  'B.1.1.283',
#  'B.1.1.88',
#  'B.1.1.99',
#  'B.1.1.15',
#  'B.1.1.127',
#  'B.1.1.174',
#  'B.1.575.1',
#  'B.1.36.19',
#  'B.1.349',
#  'B.1.1.233',
#  'B.1.1.192',
#  'B.1.1.392',
#  'B.1.1.184',
#  'AA.1',
#  'AY.106',
#  'B.1.637.1',
#  'B.1.535',
#  'AY.92',
#  'B.1.135',
#  'P.1.1',
#  'B.1.607',
#  'B.1.1.328',
#  'B.1.119',
#  'B.1.1.264',
#  'B.1.424',
#  'B.1.153',
#  'B.1.36.8',
#  'AY.117',
#  'AY.98',
#  'B.1.36.3',
#  'B.1.267',
#  'B.1.517.1',
#  'B.1.1.440',
#  'AF.1',
#  'B.1.409',
#  'AY.77',
#  'AM.2',
#  'B.1.111',
#  'B.1.416.1',
#  'B.1.258.21',
#  'B.1.1.467',
#  'B.1.532',
#  'B.1.78',
#  'B.1.1.281',
#  'AY.4.9',
#  'B.1.1.259',
#  'B.1.177.84',
#  'B.1.1.247',
#  'B.1.179',
#  'AH.2',
#  'B.1.177.8',
#  'B.1.485',
#  'B.1.1.231',
#  'B.1.177.10',
#  'B.1.1.442',
#  'B.32',
#  'B.1.551',
#  'B.1.1.404',
#  'B.1.564',
#  'AM.3',
#  'B.1.201',
#  'AY.34.2',
#  'B.1.243.2',
#  'C.10',
#  'AY.65',
#  'B.1.1.7',
#  'P.1.9',
#  'AY.112',
#  'B.1.5.13',
#  'B.44',
#  'AA.7',
#  'B.1.1.214',
#  'B.1.479',
#  'C.8',
#  'C.36',
#  'B.1.252',
#  'B.1.383',
#  'B.1.318',
#  'A.26',
#  'B.1.177.33',
#  'B.1.115',
#  'B.1.258.12',
#  'C.28',
#  'B.1.495',
#  'B.46',
#  'B.1.1.303',
#  'B.1.404',
#  'B.1.360',
#  'B.1.1.333',
#  'AY.21',
#  'B.1.1.246',
#  'C.39',
#  'B.1.1.425',
#  'AY.19',
#  'B.1.5.17',
#  'B.1.117',
#  'B.1.1.277',
#  'B.1.25',
#  'B.1.177.44',
#  'AY.120.2',
#  'B.1.362.1',
#  'B.1.631',
#  'B.1.1.40',
#  'M.1',
#  'AY.91',
#  'AY.4.1',
#  'B.1.602',
#  'B.1.336',
#  'B.1.1.122',
#  'B.1.1.198',
#  'B.1.351.5',
#  'B.1.428.2',
#  'N.1',
#  'B.1.225',
#  'B.1.160.32',
#  'B.1.1.38',
#  'B.1.1.414',
#  'B.1.258.22',
#  'B.1.475',
#  'B.1.420',
#  'B.1.1.261',
#  'AU.2',
#  'AY.48',
#  'B.1.160.19',
#  'B.1.242',
#  'B.1.1.14',
#  'B.1.1.379',
#  'AY.60',
#  'AY.95',
#  'B.1.177.30',
#  'B.1.1.516',
#  'B.1.2',
#  'B.1.82',
#  'AG.1',
#  'C.36.2',
#  'C.31',
#  'B.1.488',
#  'AE.6',
#  'B.1.232',
#  'B.1.177.85',
#  'B.1.1.426',
#  'A.9',
#  'B.1.36.35',
#  'B.1.1.517',
#  'B.1.5.21',
#  'B.1.372',
#  'B.1.1.67',
#  'Q.5',
#  'B.6.3',
#  'B.1.160.9',
#  'B.1.1.461',
#  'B.1.355',
#  'B.1.1.30',
#  'B.1.600',
#  'B.1.240.1',
#  'B.1.109',
#  'B.1.1.85',
#  'AY.40',
#  'B.1.1.210',
#  'B.1.637',
#  'C.22',
#  'B.1.1.382',
#  'AY.86',
#  'B.1.160.31',
#  'AY.4.10',
#  'M.3',
#  'B.1.1.529',
#  'B.1.177.17',
#  'AH.3',
#  'B.1.1.32',
#  'B.1.177.45',
#  'A.24',
#  'B.1.581',
#  'AE.1',
#  'AD.2.1',
#  'B.1.1.447',
#  'A.5',
#  'A.15',
#  'D.4',
#  'B.1.240.2',
#  'AY.109',
#  'AE.5',
#  'B.1.369.1',
#  'B.60',
#  'B.1.441',
#  'C.37',
#  'B.1.126',
#  'AY.37',
#  'B.1.5.18',
#  'AY.90',
#  'AY.43.6',
#  'B.1.239',
#  'B.1.560',
#  'B.1.170',
#  'B.1.369',
#  'B.1.5.28',
#  'B.1.1.235',
#  'B.1.1.397',
#  'B.1.1.287',
#  'B.1.1.384',
#  'B.1.190',
#  'B.1.1.193',
#  'B.1.1.130',
#  'B.1.1.151',
#  'B.1.160.18',
#  'B.1.1.500',
#  'B.1.356',
#  'B.1.604',
#  'B.1.1.318',
#  'B.1.270',
#  'B.1.1.265',
#  'B.1.1.521',
#  'B.1.1.403',
#  'B.1.245',
#  'B.1.330',
#  'AY.43.7',
#  'B.1.603',
#  'P.1.14',
#  'B.1.309',
#  'C.7',
#  'B.1.177.40',
#  'AY.4',
#  'B.1.438.3',
#  'B.1.503',
#  'B.1.580',
#  'AY.55',
#  'AY.102.2',
#  'B.1.112',
#  'AY.73',
#  'B.1.1.102',
#  'B.1.160.16',
#  'B.1.1.429',
#  'B.1.177.11',
#  'B.1.1.119',
#  'P.1.7.1',
#  'B.1.5.30',
#  'B.1.177.3',
#  'B.1.147',
#  'B.1.238',
#  'B.1.426',
#  'B.1.1.244',
#  'N.9',
#  'B.30',
#  'AY.58',
#  'C.17',
#  'B.1.1.190',
#  'B.1.76',
#  'AY.120',
#  'B.1.1.4',
#  'B.1.1.330',
#  'B.1.595.2',
#  'B.1.177.80',
#  'B.1.5.2',
#  'P.1.6',
#  'B.1.640',
#  'B.1.150',
#  'B.1.1.301',
#  'B.1.617.3',
#  'P.1.10.2',
#  'B.34',
#  'B.1.36.20',
#  'B.1.1.257',
#  'B.1.160.11',
#  'AY.4.4',
#  'B.1.1.114',
#  'AE.8',
#  'B.1.1.12',
#  'B.1.1.332',
#  'B.1.1.165',
#  'B.1.177.9',
#  'B.26',
#  'B.1.1.271',
#  'B.1.444',
#  'AY.4.8',
#  'Q.4',
#  'B.1.1.170',
#  'B.1.1.327',
#  'B.1.177.7',
#  'AY.30',
#  'B.1.1.185',
#  'B.1.1.329',
#  'B.1.595.1',
#  'B.1.1.291',
#  'B.1.480',
#  'B.1.1.355',
#  'B.1.623',
#  'AC.1',
#  'B.1.1.408',
#  'B.1.1.199',
#  'C.29',
#  'B.1.507',
#  'B.1.258.18',
#  'B.1.526',
#  'B.1.1.409',
#  'B.1.177.26',
#  'B.1.195',
#  'B.19',
#  'B.1.37',
#  'A.6',
#  'B.1.1.237',
#  'B.1.1',
#  'B.1.585',
#  'B.1.1.140',
#  'B.1.1.172',
#  'B.1.1.353',
#  'B.1.482',
#  'B.1.177.43',
#  'B.1.1.407',
#  'B.1.1.427',
#  'B.1.1.161',
#  'B.1.517',
#  'B.1.538',
#  'B.1.525',
#  'B.45',
#  'B.1.515',
#  'B.1.1.160',
#  'B.1.36.16',
#  'AY.52',
#  'B.1.177.13',
#  ...}

# %%
set2
# Out:
# {'19A',
#  '19B',
#  '20A',
#  '20B',
#  '20C',
#  '20D',
#  '20E (EU1)',
#  '20F',
#  '20G',
#  '20H (Beta, V2)',
#  '20I (Alpha, V1)',
#  '20J (Gamma, V3)',
#  '21A (Delta)',
#  '21B (Kappa)',
#  '21C (Epsilon)',
#  '21D (Eta)',
#  '21E (Theta)',
#  '21F (Iota)',
#  '21G (Lambda)',
#  '21H (Mu)',
#  '21I (Delta)',
#  '21J (Delta)',
#  '21K (Omicron)',
#  '21L (Omicron)',
#  '21M (Omicron)'}

# %%
set3 = set(["S", "L", "V", "G", "GK", "GH","GR", "GV","GRY"])

# %%
set_main = set.union(set1, set2)
set_main
# Out:
# {'B.1.369',
#  'B.1.5.28',
#  'B.1.1.319',
#  'B.1.1.143',
#  'B.1.1.235',
#  'B.1.1.29',
#  'B.1.1.375',
#  'B.1.1.397',
#  'B.1.1.287',
#  'B.1.502',
#  'B.1.13',
#  'B.1.1.384',
#  'AB.1',
#  'B.1.188',
#  'B.1.478',
#  'AY.46.1',
#  'B.1.190',
#  'B.1.1.451',
#  'B.1.1.193',
#  'B.1.1.130',
#  '21K (Omicron)',
#  'B.1.1.151',
#  'B.1.160.18',
#  'B.1.1.463',
#  'B.1.320',
#  'B.1.1.500',
#  'A.29',
#  'B.1.1.27',
#  'B.1.356',
#  'B.1.571',
#  'B.1.604',
#  'B.1.1.318',
#  'AV.1',
#  'AY.16',
#  'B.1.270',
#  'P.1.3',
#  'B.1.1.272',
#  'B.1.1.265',
#  'B.1.335',
#  'B.1.1.521',
#  'B.1.1.403',
#  'B.1.245',
#  'B.1.161',
#  'AK.1',
#  'B.1.95',
#  'B.1.177.89',
#  'B.1.1.289',
#  'B.1.330',
#  'AY.116',
#  'AY.43.7',
#  'B.1.361',
#  'B.1.273',
#  'B.1.603',
#  'P.1.14',
#  'B.1.231',
#  'B.1.277',
#  'B.1.309',
#  'B.1.177.21',
#  'C.7',
#  'B.1.177.40',
#  'AY.47',
#  'B.1.1.61',
#  'AY.4',
#  'B.1.438.3',
#  'B.1.503',
#  'B.1.580',
#  'B.1.265',
#  'C.27',
#  'B.1.1.285',
#  'AY.55',
#  'AY.102.2',
#  'B.1.139',
#  'B.1.112',
#  'B.1.348',
#  'C.13',
#  'B.1.1.108',
#  'AY.73',
#  'B.1.1.102',
#  'B.1.160.16',
#  '21A (Delta)',
#  'B.1.1.429',
#  'B.1.177.11',
#  'B.1.1.119',
#  'P.1.7.1',
#  'B.1.5.30',
#  'B.1.1.13',
#  'B.1.1.485',
#  'B.1.177.3',
#  'B.1.147',
#  'B.29',
#  'B.1.598',
#  'B.1.459',
#  'A.18',
#  'B.1.238',
#  'B.1.107',
#  'C.2',
#  'BA.1.1',
#  'B.51',
#  'B.1.426',
#  'B.1.1.244',
#  'P.5',
#  'D.3',
#  'B.1.177.60',
#  'N.9',
#  'AY.124.1',
#  'B.30',
#  'AY.58',
#  'K.3',
#  'B.1.326',
#  '20I (Alpha, V1)',
#  'C.17',
#  'A.16',
#  'B.1.1.190',
#  'B.1.76',
#  'AY.120',
#  'B.1.358',
#  'B.1.614',
#  'AY.114',
#  'B.1.1.4',
#  'B.1.177.71',
#  'B.1.329',
#  'B.1.1.330',
#  'B.1.595.2',
#  'B.1.12',
#  'B.1.367',
#  'A.7',
#  'B.1.1.47',
#  'B.1.177.80',
#  'B.1.1.410',
#  'B.1.5.2',
#  'P.1.6',
#  'B.1.640',
#  'B.1.150',
#  'B.1.177.48',
#  'B.1.569',
#  'B.1.1.301',
#  'B.1.617.3',
#  'P.1.10.2',
#  'B.34',
#  'B.1.36.20',
#  'B.1.1.257',
#  'B.1.1.282',
#  'B.1.166',
#  'B.1.160.11',
#  'AY.4.4',
#  'B.1.549',
#  'B.1.1.114',
#  'AE.8',
#  'AY.43.5',
#  'B.1.1.12',
#  'B.1.1.332',
#  'B.1.36.21',
#  'B.1.1.165',
#  'B.1.177.9',
#  'B.26',
#  'AY.120.2.1',
#  'AY.7.1',
#  'Q.2',
#  'B.1.1.271',
#  'B.1.1.36',
#  'B.1.444',
#  'AY.4.8',
#  'B.1.509',
#  'Q.4',
#  'B.1.1.179',
#  'B.1.151',
#  'B.1.1.170',
#  'B.1.1.327',
#  'B.1.177.7',
#  'B.1.36.31',
#  'AY.30',
#  'B.1.1.185',
#  'B.1.177.81',
#  'B.1.1.329',
#  'B.1.595.1',
#  'B.1.1.90',
#  'B.1.1.291',
#  'B.1.480',
#  'B.1.1.355',
#  'B.1.623',
#  'B.1.1.89',
#  'AC.1',
#  'B.1.1.408',
#  'B.1.1.50',
#  'AY.44',
#  'B.1.1.70',
#  'AY.4.3',
#  'B.1.1.199',
#  'B.1.160.6',
#  'C.29',
#  'B.38',
#  'B.1.507',
#  'B.1.1.275',
#  'P.2',
#  'B.1.1.418',
#  'B.1.258.18',
#  'AY.42',
#  'AY.99',
#  'B.1.1.95',
#  'B.1.526',
#  'B.1.1.409',
#  'B.1.177.26',
#  'B.1.195',
#  'B.1.192',
#  'B.19',
#  'B.1.37',
#  'B.1.177.37',
#  'A.6',
#  'B.1.1.237',
#  'B.1.1',
#  'B.1.1.147',
#  'B.1.362',
#  'B.1.585',
#  'B.1.1.140',
#  'B.1.1.172',
#  'B.1.520',
#  'B.1.1.353',
#  'B.1.1.385',
#  'B.1.482',
#  'C.3',
#  'B.1.177.43',
#  'B.1.1.407',
#  'AY.94',
#  'B.1.1.427',
#  'B.1.1.161',
#  'B.1.517',
#  'B.1.538',
#  'B.1.1.269',
#  'AY.29',
#  'B.1.177.86',
#  'N.4',
#  'B.1.525',
#  'B.1.205',
#  'B.1.1.528',
#  'B.45',
#  '20D',
#  'AY.119.1',
#  'B.1.515',
#  'B.1.36.17',
#  'A.2.3',
#  'B.1.177.46',
#  'XC',
#  'B.1.1.160',
#  'B.1.36.16',
#  'B.1.258.17',
#  'AY.52',
#  'B.1.177.13',
#  'AY.14',
#  'B.39',
#  'B.1.1.401',
#  'B.1.1.449',
#  'B.1.19',
#  'AY.43',
#  'B.1.591',
#  'B.1.1.522',
#  'B.1.36.27',
#  'A.17',
#  'B.1.1.234',
#  'P.1.15',
#  'B.1.1.448',
#  'B.1.566',
#  'AY.5',
#  'B.1.36.15',
#  'B.1.630',
#  'B.1.116',
#  'B.1.1.423',
#  'AZ.6',
#  'B.1.302',
#  'B.1.576',
#  'B.1.120',
#  '20E (EU1)',
#  'B.1.1.348',
#  'B.1.1.204',
#  'B.1.258.15',
#  'AY.4.2',
#  'B.1.431',
#  'B.53',
#  'B.1.1.142',
#  'B.1.1.345',
#  'B.1.380',
#  'B.1.1.105',
#  'B.13',
#  'B.41',
#  'B.1.1.351',
#  'B.1.177.63',
#  'B.1.1.25',
#  'B.1.1.444',
#  'B.1.384',
#  'BA.3',
#  'B.1.1.220',
#  'B.1.341',
#  'P.1.2',
#  'B.1.1.334',
#  'AY.36',
#  'B.1.36',
#  'B.1.1.482',
#  'B.1.1.159',
#  'B.1.1.432',
#  'B.1.593',
#  'B',
#  'B.1.1.526',
#  'AY.39.1',
#  'AZ.4',
#  'B.1.36.29',
#  'B.1.1.313',
#  'U.2',
#  'B.1.203',
#  'B.1.1.200',
#  'B.1.177.69',
#  'B.1.1.141',
#  'AY.110',
#  'C.33',
#  'B.1.1.216',
#  'AY.23',
#  'B.1.460',
#  'AY.34.1.1',
#  'AY.80',
#  'B.1.113',
#  'B.27',
#  'A.27',
#  'B.1.5.31',
#  'B.1.1.309',
#  'B.1.165',
#  'B.1.627',
#  'B.1.287',
#  'B.1.206',
#  'B.1.1.117',
#  'B.1.1.109',
#  'W.4',
#  'B.1.160.23',
#  'B.1.1.357',
#  'B.1.177.70',
#  'B.1.436',
#  'B.1.407',
#  'B.1.1.416',
#  'AY.122.2',
#  'B.1.1.53',
#  'B.1.214',
#  'AY.59',
#  'B.1.1.107',
#  'B.1.433',
#  'B.1.124',
#  'B.1.429.1',
#  'C.20',
#  'B.42',
#  'B.1.258.14',
#  'AY.102.1',
#  'B.1.1.361',
#  'B.1.94',
#  'B.1.177.62',
#  'B.1.1.431',
#  'B.1.1.52',
#  'B.1.177.2',
#  'B.1.577',
#  'B.1.1.72',
#  'B.1.351.1',
#  'B.1.1.39',
#  'B.1.1.316',
#  'B.1.1.97',
#  'AH.1',
#  'B.1.110.1',
#  'U.3',
#  'B.1.212',
#  'B.1.556',
#  'B.1.1.371',
#  'B.1.177.66',
#  'B.1.1.507',
#  'B.1.1.278',
#  'B.1.8.2',
#  'B.1.177.39',
#  'B.1.282',
#  'B.1.1.57',
#  'B.1.1.343',
#  'B.1.1.51',
#  'B.1.559',
#  'B.1.9',
#  'P.1.10',
#  'AY.1',
#  'AY.42.1',
#  'B.1.621.1',
#  'B.35',
#  'P.1.10.1',
#  'B.1.619',
#  'B.1.1.413',
#  'AY.5.4',
#  'B.1.615',
#  'AY.127.1',
#  'B.1.160.7',
#  'AY.39',
#  'XB',
#  'B.1.1.16',
#  'AY.23.1',
#  'AY.131',
#  'B.1.1.400',
#  'AY.79',
#  'AE.2',
#  'B.1.443',
#  'P.1.5',
#  'B.1.1.279',
#  'B.1.258.16',
#  '21J (Delta)',
#  'C.6',
#  'B.1.1.145',
#  'B.1.1.481',
#  'N.6',
#  'B.1.1.466',
#  'B.1.160.4',
#  'B.1.1.362',
#  'AW.1',
#  'B.1.342',
#  'B.1.160.13',
#  'B.1.1.450',
#  'B.1.258.23',
#  'B.1.308',
#  'B.1.521',
#  'B.1.415',
#  'AY.102',
#  'B.1.1.41',
#  'B.1.1.346',
#  'A.14',
#  'B.1.258.4',
#  'B.1.640.2',
#  'P.1.12.1',
#  'B.1.1.364',
#  'B.1.451',
#  'B.1.36.38',
#  'B.1.548',
#  'B.1.77',
#  'AY.84',
#  'B.1.473',
#  'B.1.1.527',
#  'B.1.467',
#  'A.2.2',
#  'B.1.160.10',
#  'B.1.1.417',
#  'W.1',
#  'AY.123',
#  'B.1.395',
#  'B.1.1.224',
#  'B.1.298',
#  'AY.122.1',
#  'B.1.1.113',
#  'B.1.1.340',
#  'B.1.400',
#  'B.1.377',
#  'B.1.505',
#  'B.1.1.465',
#  'B.1.1.182',
#  'B.1.363',
#  'C.5',
#  'N.2',
#  'B.1.36.25',
#  'B.1.248',
#  'Q.7',
#  'B.1.70',
#  'B.1.3.1',
#  'B.1.177.64',
#  'AY.23.2',
#  'B.10',
#  'B.1.160.1',
#  'B.1.462',
#  'P.4',
#  'B.1.136',
#  'B.1.1.171',
#  'B.1.1.349',
#  'B.1.344',
#  'B.1.160.2',
#  'AA.5',
#  'B.1.1.1',
#  'B.1.221.3',
#  'AY.22',
#  'B.1.134',
#  'B.1.1.484',
#  'B.1.1.515',
#  'B.1.1.55',
#  'AY.88',
#  'B.1.177.24',
#  'B.1.168',
#  'B.1.554',
#  'B.1.375',
#  'B.1.632',
#  'B.1.1.391',
#  'B.1.36.24',
#  'AY.13',
#  'V.1',
#  'B.1.1.354',
#  'B.1.211',
#  '19A',
#  'AY.75.3',
#  'B.1.3.4',
#  'B.1.1.177',
#  'AA.4',
#  'B.1.106',
#  'B.1.97',
#  'B.1.332',
#  'B.1.160.20',
#  'A.21',
#  'B.1.371',
#  'B.1.1.406',
#  'B.1.617.1',
#  'B.1.1.56',
#  'B.1.622',
#  'B.56',
#  'B.40',
#  'B.1.1.295',
#  'B.1.258.3',
#  'B.1.22.1',
#  'AY.122',
#  'B.1.6',
#  'AY.18',
#  'B.1.1.374',
#  'AY.4.6',
#  'B.1.89',
#  'B.1.1.136',
#  'AY.9',
#  'BB.2',
#  'B.1.160.29',
#  'AY.43.3',
#  'B.1.1.325',
#  'B.1.1.186',
#  'AY.9.2.2',
#  'B.1.274',
#  'B.1.563',
#  'L.3',
#  'B.1.1.173',
#  'B.1.194',
#  'B.1.5.36',
#  'B.1.1.337',
#  'B.1.279',
#  'B.1.492',
#  'B.1.533',
#  'B.1.36.12',
#  'AY.5.3',
#  'B.1.177.19',
#  'B.1.223',
#  'B.1.177.18',
#  'B.1.1.232',
#  'AY.127',
#  'B.1.567',
#  'B.1.1.458',
#  'B.1.5.25',
#  'B.1.605',
#  'B.1.90',
#  'B.1.160.24',
#  'B.1.301',
#  'B.1.1.221',
#  'B.1.67',
#  'AY.27',
#  'B.1.264.1',
#  'B.1.285',
#  'B.1.1.82',
#  'AY.7',
#  'C.12',
#  'B.1.177.27',
#  'B.1.1.464',
#  'AY.75.2',
#  'BA.1',
#  '20G',
#  'B.1.1.251',
#  'B.1.626',
#  'AY.74',
#  'N.7',
#  'B.1.463',
#  'A.1',
#  'B.1.1.10',
#  'B.1.406',
#  'B.1.639',
#  'B.1.75',
#  'B.1.1.100',
#  'AY.121.1',
#  'B.1.81',
#  'C.30.1',
#  'B.1.575',
#  'B.1.428.3',
#  'B.6.4',
#  'B.1.213',
#  'B.1.493',
#  'B.1.199',
#  'B.1.1.437',
#  'B.1.1.459',
#  'B.1.1.238',
#  'B.1.177.61',
#  'B.1.594',
#  'B.1.606',
#  'B.4.4',
#  'B.1.36.7',
#  'B.1.264',
#  'C.18',
#  'B.1.1.93',
#  'B.1.1.207',
#  'B.1.5.26',
#  'B.1.5.35',
#  'B.1.157',
#  'B.1.1.5',
#  'B.1.177.25',
#  'B.1.439',
#  'B.1.609',
#  'B.1.289',
#  'B.1.240',
#  'B.1.1.402',
#  'B.1.421',
#  'B.1.466',
#  'B.1.1.203',
#  'B.4.8',
#  'B.1.1.209',
#  'B.1.620',
#  'B.1.1.135',
#  'B.1.221.1',
#  'B.1.1.218',
#  'B.1.214.3',
#  'B.1.524',
#  'B.1.1.137',
#  'AY.4.5',
#  'B.1.1.294',
#  'AY.39.2',
#  'B.1.417',
#  'B.1.354',
#  'B.1.1.194',
#  'AY.15',
#  'B.1.1.523',
#  'B.1.281',
#  'C.36.3.1',
#  'B.1.597',
#  'B.1.1.377',
#  'B.1.1.118',
#  'B.1.1.63',
#  'B.1.1.378',
#  'B.1.513',
#  'B.1.5.34',
#  'B.1.1.446',
#  'B.1.1.175',
#  'B.1.83',
#  'B.1.36.22',
#  'B.1.1.315',
#  'B.1.543',
#  'A.12',
#  'AY.46.3',
#  'AY.129',
#  'B.1.400.1',
#  'B.1.1.254',
#  'B.1.487',
#  'B.1.504',
#  'B.1.1.129',
#  'B.1.1.196',
#  'B.1.5.27',
#  'B.1.160.22',
#  'L.1',
#  'B.1.1.96',
#  'B.1.189',
#  'B.1.177.52',
#  'B.1.500',
#  'A.2.1',
#  'B.1.36.2',
#  '19B',
#  'B.1.350.1',
#  'B.1.1.103',
#  'B.1.1.284',
#  'B.1.1.298',
#  'B.1.351.3',
#  'B.1.496',
#  'Q.6',
#  'B.1.1.428',
#  'B.1.1.3',
#  'P.3',
#  'AY.45',
#  'B.1.177.29',
#  'B.1.1.163',
#  'B.1.1.314',
#  'B.1.1.297',
#  'B.1.418',
#  'AY.24',
#  'B.1.177.73',
#  'AY.99.2',
#  'AY.119.2',
#  'A.19',
#  'B.1.1.368',
#  'B.1.1.514',
#  'B.1.399',
#  'B.1.177.41',
#  'B.1.3',
#  'B.1.458',
#  'AY.34.1',
#  'B.1.276',
#  'B.1.398',
#  'B.1.587',
#  'B.1.36.6',
#  'B.36',
#  'C.19',
#  'B.1.5.12',
#  'B.1.1.123',
#  'B.1.160.28',
#  'P.1.8',
#  'B.1.39',
#  'BA.2',
#  'AL.1',
#  'B.1.182',
#  'B.1.1.255',
#  'B.1.1.372',
#  'B.1.1.126',
#  'C.2.1',
#  'B.1.160.15',
#  'B.1.550',
#  'AY.20',
#  'AY.46.6',
#  'B.1.84',
#  'B.1.546',
#  'B.1.1.48',
#  'B.1.1.215',
#  'B.1.1.352',
#  'AY.105',
#  'C.37.1',
#  'B.18',
#  'B.1.1.164',
#  'B.1.466.2',
#  'B.1.105',
#  'B.1.465',
#  'AY.25',
#  'V.2',
#  'B.1.38',
#  'B.1.573',
#  'B.1.445',
#  'B.1.1.124',
#  'B.1.1.59',
#  'B.1.1.26',
#  'B.1.177.12',
#  'AY.96',
#  'B.1.1.94',
#  'B.1.258.20',
#  'B.1.152',
#  'A.30',
#  'B.1.9.3',
#  'B.1.154',
#  'B.1.23',
#  'AZ.2.1',
#  'B.1.589',
#  'AA.2',
#  'B.1.446',
#  'B.1.114',
#  'B.1.1.462',
#  'B.1.1.191',
#  'AY.63',
#  'B.1.215',
#  'B.1.36.13',
#  'AY.113',
#  'AY.9.2.1',
#  'Q.3',
#  'B.1.619.1',
#  'B.1.1.438',
#  'B.1.1.83',
#  '21B (Kappa)',
#  'B.1.511',
#  'B.1.434',
#  'AU.3',
#  'B.1.351.2',
#  'B.1.1.217',
#  'C.35',
#  'B.1.291',
#  'B.1.616',
#  'B.1.156',
#  'B.1.586',
#  'AY.103',
#  'B.1.558',
#  'B.1.378',
#  'B.1.1.195',
#  'B.1.408',
#  'B.1.1.386',
#  'Q.8',
#  'B.1.1.270',
#  'B.1.177',
#  'B.1.638',
#  'B.1.1.6',
#  'B.1.428',
#  'B.1.243',
#  'L.2',
#  'AY.64',
#  'B.1.177.23',
#  'B.1.470',
#  'B.1.319',
#  'B.1.397',
#  'B.5',
#  'B.1.588',
#  'N.8',
#  'B.1.1.290',
#  'B.1.229',
#  'B.1.284',
#  'B.1.177.87',
#  'B.1.35',
#  'B.1.1.166',
#  'AY.25.1.1',
#  'B.6.8',
#  'B.1.425',
#  'B.1.530',
#  'B.1.104',
#  'B.1.177.75',
#  'AY.29.1',
#  'AY.82',
#  '21C (Epsilon)',
#  'B.1.1.363',
#  'B.1.1.31',
#  'AY.128',
#  'B.1.450',
#  'AY.43.2',
#  'B.1.141',
#  'B.1.1.197',
#  'B.1.160.8',
#  'AY.41',
#  'B.1.1.133',
#  'B.1.310',
#  'B.1.169',
#  'B.52',
#  'B.1.1.134',
#  'B.1.260',
#  'AM.1',
#  'B.61',
#  'AY.93',
#  'B.1.1.106',
#  'B.4',
#  'B.1.1.149',
#  'B.1.5.11',
#  'B.1.340',
#  'B.1.612',
#  'B.1.1.37',
#  'B.1.1.395',
#  'AZ.2',
#  'D.5',
#  'AY.33.1',
#  'AY.39.1.2',
#  'B.1.640.1',
#  'A.2',
#  'B.1.1.87',
#  'B.1.36.39',
#  'B.3.1',
#  'B.1.177.28',
#  'AA.8',
#  'B.1.564.1',
#  'B.1.1.360',
#  'B.1.1.441',
#  'B.1.144',
#  'B.1.1.256',
#  'B.1.1.146',
#  'B.1.1.525',
#  'B.1.102',
#  'B.1.88',
#  'B.1.476',
#  'AY.85',
#  'B.1.36.37',
#  'AY.50',
#  '21E (Theta)',
#  'AY.53',
#  'B.1.227',
#  'B.1.1.434',
#  'AY.54',
#  'C.21',
#  'B.1.1.258',
#  'B.1.280',
#  'C.1.2',
#  'B.1.256',
#  'B.1.1.156',
#  'AY.112.1',
#  'B.1.1.452',
#  'AY.4.2.2',
#  'A.8',
#  'A.4',
#  'AK.2',
#  'AS.2',
#  'B.1.453',
#  'B.1.498',
#  'B.1.9.2',
#  'B.1.177.51',
#  'B.1.293',
#  'B.1.448',
#  'B.1.1.227',
#  'AY.3.1',
#  'B.1.258.11',
#  'B.1.555',
#  'B.1.177.47',
#  'AZ.3',
#  'AS.1',
#  'AY.3.2',
#  'B.1.1.162',
#  'B.1.325',
#  'B.1.34',
#  'B.1.177.35',
#  'B.1.1.148',
#  'B.1.250',
#  'AY.108',
#  'B.1.160',
#  'B.1.177.53',
#  'AY.66',
#  'B.1.1.421',
#  'B.1.1.296',
#  'B.1.529',
#  'AY.35',
#  'B.1.1.180',
#  'B.1.1.276',
#  'A.2.4',
#  'B.1.177.49',
#  'B.1.177.65',
#  'B.1.160.21',
#  'AY.100',
#  'B.1.1.347',
#  'B.1.110',
#  'B.1.1.422',
#  'B.1.381',
#  'B.6',
#  'A.22',
#  'B.1.1.435',
#  'B.1.343',
#  'P.1.11',
#  'B.1.1.260',
#  'B.1.1.121',
#  'B.1.1.223',
#  'B.1.8',
#  'B.1.222',
#  'B.6.2',
#  'B.1.108',
#  'B.1.595.4',
#  'B.1.1.77',
#  'B.1.1.358',
#  'B.1.1.380',
#  'B.1.508',
#  'B.4.6',
#  'P.7',
#  'B.1.634',
#  'B.6.1',
#  'B.1.243.1',
#  'B.1.177.76',
#  'B.1.1.365',
#  'AY.26',
#  'B.1.1.518',
#  'A.2.5',
#  'B.1.258.5',
#  'B.1.36.23',
#  'AJ.1',
#  'B.1.490',
#  'AY.98.1',
#  'B.1.1.181',
#  'AP.1',
#  'Q.1',
#  'B.1.396',
#  'B.1.1.225',
#  'A.2.5.1',
#  'AY.5.1',
#  'B.1.468',
#  'AY.99.1',
#  'B.1.534',
#  'B.1.1.144',
#  'B.1.9.5',
#  'B.1.160.5',
#  'AY.39.1.1',
#  'B.1.1.323',
#  'B.1.1.66',
#  'B.1.162',
#  'AY.31',
#  'B.1.1.367',
#  'B.1.1.157',
#  'B.1.158',
#  'B.1.489',
#  'B.1.1.356',
#  'B.1.160.12',
#  'B.1.1.415',
#  'B.1.1.412',
#  'B.1.402',
#  'AY.43.1',
#  'B.1.258.2',
#  'B.1.403',
#  'B.1.167',
#  'B.1.305',
#  'B.1.177.72',
#  'AY.133',
#  'B.1.391',
#  'A.3',
#  'B.1.1.125',
#  'B.1.562',
#  'B.1.1.436',
#  'A.10',
#  'B.1.145',
#  'AY.46.5',
#  'B.1.1.338',
#  'B.1.611',
#  'B.1.1.274',
#  'B.1.315',
#  'B.1.438.2',
#  'AY.32',
#  'AY.5.5',
#  '21H (Mu)',
#  'B.1.221',
#  'B.1.247',
#  'B.1.1.45',
#  'B.1.1.524',
#  'B.1.1.513',
#  'B.1.160.26',
#  'B.1.149',
#  'AY.124',
#  'B.1.572',
#  'B.1.1.236',
#  'B.1.36.4',
#  'B.1.1.411',
#  'B.1.1.253',
#  'B.47',
#  ...}

# %%
len(set1), len(set2), len(set_main)
# Out:
# (1728, 25, 1753)

# %%
filename = "../results/variants_all_processed.txt"
with open(filename, "w") as f:
    for term in sorted(set_main):
        f.write(term + "\n")
