# %%
import numpy as np
import pandas as pd
import nltk
from pattern.text.en import singularize

# %% [markdown]
# #### The singularize command from the pattern library is enough to convert the scripts

# %%
singularize("Diseases, viruses, covid patients")
# Out:
# 'Diseases, viruses, covid patient'

# %%
infile = "../data/processed_terms/ncbi_mergedterms_disease_covid_grm_lex.xlsx"

# %%
df = pd.read_excel(infile)
df
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 4                   presymptomatic COVID-19 infections       n
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [289 rows x 2 columns]

# %%
df2 = df[df["INCLUDE"]=="y"]
df2
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 7                       virus-2 (SARS-CoV-2) infection       y
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [229 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\nlp_gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\nlp_gpu\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\nlp_gpu\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'INLCUDE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[df["INCLUDE"]=="y"]
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 7                       virus-2 (SARS-CoV-2) infection       y
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [229 rows x 2 columns]

# %%
df
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 4                   presymptomatic COVID-19 infections       y
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [289 rows x 2 columns]
