# %% [markdown]
# # This initial script is written by salma to create disease term variants out of curated dictionaries. This was further improved
#
# ### pointers:
# *	interchanging corona virus and coronavirus
# *	interchanging the virus name with any of its synonyms, the term 'Wuhan' or 'Hubei'
# *	interchanging the terms disease, disorder, syndrome, pneumonia, infection
# *	adding the adjectives acute, severe, and respiratory alone or in combination
# *	removing disease names containing the same word twice or containing both 'new' and 'novel'

# %%
import pandas as pd
import re
import itertools

# %%
infile_disease = "../data/processed_terms/ncbi_mergedterms_disease_covid_grm_lex.xlsx"
df_disease = pd.read_excel(infile_disease)
df_disease
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 4                   presymptomatic COVID-19 infections       n
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [289 rows x 2 columns]

# %%
df_disease = df_disease[df_disease["INCLUDE"]=="y"]
df_disease
# Out:
#                                                   TERM INCLUDE
# 0                   disease caused by SARS-CoV-2 virus       y
# 1    infectious respiratory disease caused by sever...       y
# 2                    Wuhan Novel Coronavirus Infection       y
# 3                Coronavirus 2019 (COVID-19) Infection       y
# 7                       virus-2 (SARS-CoV-2) infection       y
# ..                                                 ...     ...
# 284  acute respiratory syndrome coronavirus 2 (SARS...       y
# 285              Disease due to 2019 Novel Coronavirus       y
# 286  infections caused by severe acute respiratory ...       y
# 287  severe acute respiratory syndrome coronavirus ...       y
# 288  disease caused by severe acute respiratory syn...       y
#
# [229 rows x 2 columns]

# %%
disease_terms = df_disease["TERM"].tolist()
disease_terms
# Out:
# ['disease caused by SARS-CoV-2 virus',
#  'infectious respiratory disease caused by severe acute respiratory syndrome coronavirus 2',
#  'Wuhan Novel Coronavirus Infection',
#  'Coronavirus 2019 (COVID-19) Infection',
#  'virus-2 (SARS-CoV-2) infection',
#  'COVID-19 virus infections',
#  'CoVs disease',
#  'infections due to SARS-CoV-2',
#  'CoV illness',
#  'coronavirus disease (COVID-19) caused by SARS coronavirus-2',
#  'new coronavirus (SARS-CoV-2) infection',
#  'SARS-Cov-2-associated acute respiratory distress syndrome',
#  'Severe acute respiratory syndrome coronavirus-2 (SARS-CoV-2)-associated infection',
#  '2019 coronavirus (COVID-19) infection',
#  'acute respiratory syndrome (SARS) caused by SARS-CoV-2',
#  'CoV disease',
#  'Coronavirus Disease 19 Infection',
#  'novel coronavirus disease 2019 (COVID-19) pneumonia',
#  'SARS-Cov2 related illness',
#  'novel coronavirus disease (COVID-19) caused by severe acute respiratory syndrome coronavirus 2',
# ...

# %%
new_terms = ['new coronavirus',
'novel coronavirus',
'chinese virus',
'china virus',
'chinese coronavirus',
'china coronavirus',
'kung flu' 
]
print(len(disease_terms))
disease_terms.extend(new_terms)
print(len(disease_terms))
# Out:
# 229
# 236

# %%
virus_term_cv_file = "../data/cv_terms.md"
cv_disease_list = set()
cv_virus_list = set()
with open(virus_term_cv_file) as f:
    for line in f.readlines():
        print(line)
# Out:
# # disease names
#
# covid19
#
# covid 19
#
# NCP
#
# coronavirus disease 2019
#
# corona virus disease 2019
#
# coronavirus disease-19
#
# corona virus disease-19
#
# 2019 novel coronavirus respiratory syndrome
#
# 2019 novel corona virus respiratory syndrome
#
# WuRS
#
# seafood market pneumonia
#
# severe acute respiratory syndrome type 2
#
# SARS 2
#
# SARS2
#
# SARS 2019
#
# 2019 SARS
#
# severe acute respiratory syndrome 2019
#
#
#
#
#
#
#
# [virus name or Wuhan or Hubei] infection
#
# [virus name or Wuhan or Hubei] illness
#
# [virus name or Wuhan or Hubei] disease
#
# [virus name or Wuhan or Hubei] syndrome
#
# [virus name or Wuhan or Hubei] disorder
#
# [virus name or Wuhan or Hubei] pneumonia
#
# [virus name or Wuhan or Hubei] acute infection
#
# [virus name or Wuhan or Hubei] acute illness
#
# [virus name or Wuhan or Hubei] acute disease
#
# [virus name or Wuhan or Hubei] acute syndrome
#
# [virus name or Wuhan or Hubei] acute disorder
#
# ...

# %%
disease_names_cv = '''covid19

covid 19

NCP

coronavirus disease 2019

corona virus disease 2019

coronavirus disease-19

corona virus disease-19

2019 novel coronavirus respiratory syndrome

2019 novel corona virus respiratory syndrome

WuRS

seafood market pneumonia

severe acute respiratory syndrome type 2

SARS 2

SARS2

SARS 2019

2019 SARS

severe acute respiratory syndrome 2019'''

disease_names_cv=disease_names_cv.split("\n\n")
disease_names_cv
# Out:
# ['covid19',
#  'covid 19',
#  'NCP',
#  'coronavirus disease 2019',
#  'corona virus disease 2019',
#  'coronavirus disease-19',
#  'corona virus disease-19',
#  '2019 novel coronavirus respiratory syndrome',
#  '2019 novel corona virus respiratory syndrome',
#  'WuRS',
#  'seafood market pneumonia',
#  'severe acute respiratory syndrome type 2',
#  'SARS 2',
#  'SARS2',
#  'SARS 2019',
#  '2019 SARS',
#  'severe acute respiratory syndrome 2019']

# %%
virus_wuhan_hubei_cv = '''[virus name or Wuhan or Hubei] infection

[virus name or Wuhan or Hubei] illness

[virus name or Wuhan or Hubei] disease

[virus name or Wuhan or Hubei] syndrome

[virus name or Wuhan or Hubei] disorder

[virus name or Wuhan or Hubei] pneumonia

[virus name or Wuhan or Hubei] acute infection

[virus name or Wuhan or Hubei] acute illness

[virus name or Wuhan or Hubei] acute disease

[virus name or Wuhan or Hubei] acute syndrome

[virus name or Wuhan or Hubei] acute disorder

[virus name or Wuhan or Hubei] acute pneumonia

[virus name or Wuhan or Hubei] severe infection

[virus name or Wuhan or Hubei] severe illness

[virus name or Wuhan or Hubei] severe disease

[virus name or Wuhan or Hubei] severe syndrome

[virus name or Wuhan or Hubei] severe disorder

[virus name or Wuhan or Hubei] severe pneumonia

[virus name or Wuhan or Hubei] respiratory infection

[virus name or Wuhan or Hubei] respiratory illness

[virus name or Wuhan or Hubei] respiratory disease

[virus name or Wuhan or Hubei] respiratory syndrome

[virus name or Wuhan or Hubei] respiratory disorder

[virus name or Wuhan or Hubei] acute respiratory infection

[virus name or Wuhan or Hubei] acute respiratory illness

[virus name or Wuhan or Hubei] acute respiratory disease

[virus name or Wuhan or Hubei] acute respiratory syndrome

[virus name or Wuhan or Hubei] acute respiratory disorder

[virus name or Wuhan or Hubei] severe respiratory infection

[virus name or Wuhan or Hubei] severe respiratory illness

[virus name or Wuhan or Hubei] severe respiratory disease

[virus name or Wuhan or Hubei] severe respiratory syndrome

[virus name or Wuhan or Hubei] severe respiratory disorder

[virus name or Wuhan or Hubei] acute severe infection

[virus name or Wuhan or Hubei] acute severe illness

[virus name or Wuhan or Hubei] acute severe disease

[virus name or Wuhan or Hubei] acute severe syndrome

[virus name or Wuhan or Hubei] acute severe disorder

[virus name or Wuhan or Hubei] acute severe pneumonia

[virus name or Wuhan or Hubei] severe acute infection

[virus name or Wuhan or Hubei] severe acute illness

[virus name or Wuhan or Hubei] severe acute disease

[virus name or Wuhan or Hubei] severe acute syndrome

[virus name or Wuhan or Hubei] severe acute disorder

[virus name or Wuhan or Hubei] severe acute pneumonia

[virus name or Wuhan or Hubei] acute severe respiratory infection

[virus name or Wuhan or Hubei] acute severe respiratory illness

[virus name or Wuhan or Hubei] acute severe respiratory disease

[virus name or Wuhan or Hubei] acute severe respiratory syndrome

[virus name or Wuhan or Hubei] acute severe respiratory disorder

[virus name or Wuhan or Hubei] severe acute respiratory infection

[virus name or Wuhan or Hubei] severe acute respiratory illness

[virus name or Wuhan or Hubei] asevere acute respiratory disease

[virus name or Wuhan or Hubei] severe acute respiratory syndrome

[virus name or Wuhan or Hubei] severe acute respiratory disorder'''
virus_wuhan_hubei_cv = virus_wuhan_hubei_cv.split("\n\n")
virus_wuhan_hubei_cv
# Out:
# ['[virus name or Wuhan or Hubei] infection',
#  '[virus name or Wuhan or Hubei] illness',
#  '[virus name or Wuhan or Hubei] disease',
#  '[virus name or Wuhan or Hubei] syndrome',
#  '[virus name or Wuhan or Hubei] disorder',
#  '[virus name or Wuhan or Hubei] pneumonia',
#  '[virus name or Wuhan or Hubei] acute infection',
#  '[virus name or Wuhan or Hubei] acute illness',
#  '[virus name or Wuhan or Hubei] acute disease',
#  '[virus name or Wuhan or Hubei] acute syndrome',
#  '[virus name or Wuhan or Hubei] acute disorder',
#  '[virus name or Wuhan or Hubei] acute pneumonia',
#  '[virus name or Wuhan or Hubei] severe infection',
#  '[virus name or Wuhan or Hubei] severe illness',
#  '[virus name or Wuhan or Hubei] severe disease',
#  '[virus name or Wuhan or Hubei] severe syndrome',
#  '[virus name or Wuhan or Hubei] severe disorder',
#  '[virus name or Wuhan or Hubei] severe pneumonia',
#  '[virus name or Wuhan or Hubei] respiratory infection',
# ...

# %%
virus_added_terms_cv = '''infection caused by [virus name]

illness caused by [virus name]

disease caused by [virus name]

syndrome caused by [virus name]

disorder caused by [virus name]

pneumonia caused by [virus name]

infection due to [virus name]

illness due to [virus name]

disease due to [virus name]

syndrome due to [virus name]

disorder due to [virus name]

pneumonia due to [virus name]

infection from [virus name]

illness from [virus name]

disease from [virus name]

syndrome from [virus name]

disorder from [virus name]

pneumonia from [virus name]'''

virus_added_terms_cv = virus_added_terms_cv.split("\n\n")
virus_added_terms_cv
# Out:
# ['infection caused by [virus name]',
#  'illness caused by [virus name]',
#  'disease caused by [virus name]',
#  'syndrome caused by [virus name]',
#  'disorder caused by [virus name]',
#  'pneumonia caused by [virus name]',
#  'infection due to [virus name]',
#  'illness due to [virus name]',
#  'disease due to [virus name]',
#  'syndrome due to [virus name]',
#  'disorder due to [virus name]',
#  'pneumonia due to [virus name]',
#  'infection from [virus name]',
#  'illness from [virus name]',
#  'disease from [virus name]',
#  'syndrome from [virus name]',
#  'disorder from [virus name]',
#  'pneumonia from [virus name]']

# %%
virus_names_cv = '''COVID-19 virus

sarscov2

sars cov 2

new coronavirus

new corona virus

novel coronavirus

novel corona virus

Wuhan virus

Wuhan pneumonia virus

Wuhan coronavirus

Wuhan corona virus

Wuhancoronavirus

Wuhancorona virus

Wuhan seafood market pneumonia virus

Wuhan seafood market virus

seafood market virus

seafood market coronavirus

seafood market corona virus

Chinese coronavirus

Chinese corona virus

2019 novel coronavirus

2019 novel corona virus

2019 new coronavirus

2019 new corona virus

2019 coronavirus

2019 corona virus

2019ncov

2019 ncov

SARS coronavirus 2

SARS corona virus 2

SARS coronavirus2

SARS coronavirus 2

virus responsible for covid19

virus causing covid19

severe acute respiratory syndrome coronavirus 2

severe acute respiratory syndrome corona virus 2

severe acute respiratory syndrome coronavirus2

severe acute respiratory syndrome corona virus2

Severe acute respiratory syndrome-related coronavirus 2

Severe acute respiratory syndrome-related corona virus 2

Severe acute respiratory syndrome-related coronavirus2

Severe acute respiratory syndrome-related corona virus2'''

virus_names_cv = virus_names_cv.split('\n\n')
virus_names_cv
# Out:
# ['COVID-19 virus',
#  'sarscov2',
#  'sars cov 2',
#  'new coronavirus',
#  'new corona virus',
#  'novel coronavirus',
#  'novel corona virus',
#  'Wuhan virus',
#  'Wuhan pneumonia virus',
#  'Wuhan coronavirus',
#  'Wuhan corona virus',
#  'Wuhancoronavirus',
#  'Wuhancorona virus',
#  'Wuhan seafood market pneumonia virus',
#  'Wuhan seafood market virus',
#  'seafood market virus',
#  'seafood market coronavirus',
#  'seafood market corona virus',
#  'Chinese coronavirus',
#  'Chinese corona virus',
#  '2019 novel coronavirus',
#  '2019 novel corona virus',
#  '2019 new coronavirus',
#  '2019 new corona virus',
#  '2019 coronavirus',
#  '2019 corona virus',
#  '2019ncov',
#  '2019 ncov',
#  'SARS coronavirus 2',
#  'SARS corona virus 2',
#  'SARS coronavirus2',
#  'SARS coronavirus 2',
#  'virus responsible for covid19',
#  'virus causing covid19',
#  'severe acute respiratory syndrome coronavirus 2',
#  'severe acute respiratory syndrome corona virus 2',
# ...

# %%
processed_virus_file = "../results/20220321_ra_additionally_processed_dictionaries/20220321_ra_virus_merged.txt"
virus_from_processed_file = set()
with open(processed_virus_file) as f:
    for line in f.readlines():
        virus_from_processed_file.update([line.strip()])
virus_from_processed_file
# Out:
# {'19 corona',
#  '19 coronavirus',
#  '19 cov',
#  '19 ncov',
#  '2019 acute respiratory syndrome coronavirus 2',
#  '2019 china cov',
#  '2019 china virus',
#  '2019 chinese corona',
#  '2019 chinese corona virus',
#  '2019 chinese coronavirus',
#  '2019 corona',
#  '2019 corona disease cov',
#  '2019 corona infectious disease cov',
#  '2019 corona virus',
#  '2019 coronaes',
#  '2019 coronavirus',
#  '2019 coronavirus disease cov',
#  '2019 coronavirus infectious disease cov',
#  '2019 coronaviruses',
#  '2019 cov',
#  '2019 cov 2 virus',
#  '2019 cov2',
#  '2019 cov2 corona',
#  '2019 cov2 coronavirus',
#  '2019 hcov 2',
#  '2019 hubei cov',
#  '2019 hubei novel corona',
#  '2019 hubei novel coronavirus',
#  '2019 hubei pneumonia virus',
#  '2019 hubei seafood market pneumonia virus',
#  '2019 hubei virus',
#  '2019 human corona 2',
#  '2019 human corona virus',
#  '2019 human coronaes (hcovs) 2',
#  '2019 human coronavirus',
#  '2019 human coronavirus 2',
# ...

# %% [markdown]
# ## Now that we have all the terms we have to
# 1. Merge all terms together create wuhan/hubei + virus variants
# 2. process terms
# 3. merge everything with original

# %%
def remove_hyphens_lowercase(list_):
    new_set = set()
    for term in list_:
        new_set.update([term.lower().replace("-"," ")])
    return sorted(list(new_set))

def create_variant_terms_dis(list_):
    '''
    used to create a new variant list if keyword exists in the term
    '''
    
    new_set = set()
    variants = ["disease", "disorder", "syndrome", "pneumonia", "infection"]
    for term in list_:
        term = term.lower()
        new_set.update([term])
        
        main_var = ""
        keyword_in_term = False
        new_var_list = []
        
        for var in variants:
            if var in term:
                keyword_in_term = True
                main_var = var
                new_var_list = [v for v in variants if v!=var]
                break
        
        if keyword_in_term == True:
            for var2 in new_var_list:
                new_set.update([term.replace(main_var, var2)])
                
    return sorted(new_set)

            
def interchange_corona(list_):
    '''
    interchange corona and coronavirus terms 
    '''
    new_set = set()
    for term in list_:
        term = term.lower()
        new_set.update([term])
        if "corona virus" in term:
            continue
        elif "coronavirus" in term:
            if not "syndrome coronavirus" in term:
                new_set.update([term.replace("coronavirus", "corona")])
        else:
            new_set.update([re.sub("\bcorona\b", "coronavirus", term)])
            
    return sorted(new_set)

# def add_adjectives(list_):
#     '''
#     add adjectives to terms
#     acute
#     severe
#     respiratory
#     and their combinations
    
#     Q: how do we determine where to put the adj?
#     '''
    
#     adj_list = ["acute", "severe", "respiratory"]
#     comb = []
#     for i in range(1,len(adj_list)+1):
#         comb.extend(list(itertools.combinations(adj_list,i)))
    
#     if not any(x in term for x in adj_list):
        
def interchance_wuhan_hubei(list_):
    '''
    interchanging wuhan and hubei
    '''
    new_set = set()
    
    for term in list_:
        term = term.lower()
        
        new_set.update([term])
        
        if "wuhan" in term:
            new_set.update([term.replace("wuhan", "hubei")])
        elif "hubei" in term:
            new_set.update([term.replace("hubei", "wuhan")])
            
    return sorted(new_set)

def check_duplicate_words_from_single_term(term):
    words = term.split()
    return len(words) > len(set(words))

def check_if_both_new_novel(term):
    return "new" in term and "novel" in term

def remove_duplicates(list_):
    '''
    remove duplicate terms and remove "new"/"novel" multiple occurances
    '''
    new_set = set()
    
    for term in list_:
        if check_duplicate_words_from_single_term(term):
            continue
        elif check_if_both_new_novel(term):
            continue
        else:
            new_set.update([term])
    
    return sorted(new_set)

# %%
disease_terms_added = set(disease_names_cv).union(set(disease_terms))
disease_terms_added
# Out:
# {'19 coronavirus infection',
#  '2019 SARS',
#  '2019 coronavirus (COVID-19) infection',
#  '2019 novel corona virus (2019-nCoV) disease',
#  '2019 novel corona virus respiratory syndrome',
#  '2019 novel coronavirus (SARS-CoV2) infection',
#  '2019 novel coronavirus respiratory syndrome',
#  '2019, novel coronavirus pneumonia',
#  '2019-nCoV acute respiratory disease',
#  '2019-nCoV acute respiratory diseases',
#  '2019-nCoV-associated infectious diseases',
#  'ACUTE RESPIRATORY INFECTIONS FROM SARS-COV-2',
#  'ARDS caused by SARS-CoV2',
#  'ARDS due to SARS-CoV-2',
#  'Acute Respiratory Infections Caused by 2019-nCoV',
#  'Acute respiratory disease caused by 2019 novel coronavirus',
#  'Acute respiratory distress syndrome (ARDS) caused by SARS-CoV-2',
#  'COVID illness',
#  'COVID related illness',
#  'COVID-19 (Coronavirus) infection',
#  'COVID-19 (SARS-CoV-2)-associated ARDS',
#  'COVID-19 associated pneumonia',
#  'COVID-19 illness',
#  'COVID-19 illnesses',
# ...

# %%
disease_from_virus = set()
for virus in virus_from_processed_file:
    for term in virus_wuhan_hubei_cv:
        if "[virus name or Wuhan or Hubei]" in term:
            disease_from_virus.update([term.replace("[virus name or Wuhan or Hubei]",virus)])
            disease_from_virus.update([term.replace("[virus name or Wuhan or Hubei]","wuhan")])
            disease_from_virus.update([term.replace("[virus name or Wuhan or Hubei]","hubei")])
            
    for term in virus_added_terms_cv:
        if "[virus name]" in term:
            disease_from_virus.update([term.replace("[virus name]",virus)])
            
disease_from_virus_lower = remove_hyphens_lowercase(disease_from_virus)
disease_from_virus_lower_nodup = remove_duplicates(disease_from_virus_lower)
print(len(disease_from_virus), len(disease_from_virus_lower), len(disease_from_virus_lower_nodup))
# Out:
# 58656 58510 48028

# %%
disease_from_virus_lower_nodup
# Out:
# ['19 corona acute disease',
#  '19 corona acute disorder',
#  '19 corona acute illness',
#  '19 corona acute infection',
#  '19 corona acute pneumonia',
#  '19 corona acute respiratory disease',
#  '19 corona acute respiratory disorder',
#  '19 corona acute respiratory illness',
#  '19 corona acute respiratory infection',
#  '19 corona acute respiratory syndrome',
#  '19 corona acute severe disease',
#  '19 corona acute severe disorder',
#  '19 corona acute severe illness',
#  '19 corona acute severe infection',
#  '19 corona acute severe pneumonia',
#  '19 corona acute severe respiratory disease',
#  '19 corona acute severe respiratory disorder',
#  '19 corona acute severe respiratory illness',
#  '19 corona acute severe respiratory infection',
#  '19 corona acute severe respiratory syndrome',
#  '19 corona acute severe syndrome',
#  '19 corona acute syndrome',
#  '19 corona asevere acute respiratory disease',
#  '19 corona disease',
#  '19 corona disorder',
#  '19 corona illness',
# ...

# %%
list_lowercase = remove_hyphens_lowercase(disease_terms_added)
list_lowercase
# Out:
# ['19 coronavirus infection',
#  '2019 coronavirus (covid 19) infection',
#  '2019 ncov acute respiratory disease',
#  '2019 ncov acute respiratory diseases',
#  '2019 ncov associated infectious diseases',
#  '2019 novel corona virus (2019 ncov) disease',
#  '2019 novel corona virus respiratory syndrome',
#  '2019 novel coronavirus (sars cov2) infection',
#  '2019 novel coronavirus respiratory syndrome',
#  '2019 sars',
#  '2019, novel coronavirus pneumonia',
#  'acute respiratory disease caused by 2019 novel coronavirus',
#  'acute respiratory disease caused by sars cov 2',
#  'acute respiratory disease caused by severe acute respiratory syndrome coronavirus 2',
#  'acute respiratory distress syndrome (ards) caused by sars cov 2',
#  'acute respiratory distress syndrome (sars) due to sars cov 2',
#  'acute respiratory distress syndrome due to sars cov 2',
#  'acute respiratory infection caused by severe acute respiratory syndrome coronavirus 2',
# ...

# %%
merged_virus_disease = set.union(set(disease_from_virus_lower_nodup), set(list_lowercase))
len(merged_virus_disease), merged_virus_disease
# Out:
# (48232,
#  {'2019 new corona infections cov illness',
#   'disorder due to wuhan virus 2019',
#   'sars corona virus 2 2019 acute infection',
#   'virus responsible for covid19 respiratory syndrome',
#   'disease due to 2019novel sars cov 2 coronaviruses',
#   '2019 novel seafood market virus severe disease',
#   '2019 new seafood market corona virus respiratory disease',
#   '2019 coronaviruses syndrome',
#   'sars coronavirus2 severe acute disorder',
#   'sars cov 2019 severe acute respiratory infection',
#   'novel sars corona 2 2019 acute disease',
#   '2019 novel sars cov 2 (cov 2) corona disorder',
#   '2019 novel human coronavirus 2 acute respiratory syndrome',
#   'corona disease 2019 cov acute pneumonia',
#   'new cov 2019 severe acute illness',
#   '2019 new coronavirus disease cov acute pneumonia',
#   'illness due to 2019 hubei seafood market pneumonia virus',
#   'wuhan pneumonia virus 2019 acute respiratory illness',
#   'pneumonia due to coronavirus disease 2019 cov',
# ...

# %%
list_merged_virus_disease_corona = interchange_corona(merged_virus_disease)
len(list_merged_virus_disease_corona), list_merged_virus_disease_corona
# Out:
# (51496,
#  ['19 corona acute disease',
#   '19 corona acute disorder',
#   '19 corona acute illness',
#   '19 corona acute infection',
#   '19 corona acute pneumonia',
#   '19 corona acute respiratory disease',
#   '19 corona acute respiratory disorder',
#   '19 corona acute respiratory illness',
#   '19 corona acute respiratory infection',
#   '19 corona acute respiratory syndrome',
#   '19 corona acute severe disease',
#   '19 corona acute severe disorder',
#   '19 corona acute severe illness',
#   '19 corona acute severe infection',
#   '19 corona acute severe pneumonia',
#   '19 corona acute severe respiratory disease',
#   '19 corona acute severe respiratory disorder',
#   '19 corona acute severe respiratory illness',
#   '19 corona acute severe respiratory infection',
#   '19 corona acute severe respiratory syndrome',
#   '19 corona acute severe syndrome',
#   '19 corona acute syndrome',
#   '19 corona asevere acute respiratory disease',
#   '19 corona disease',
# ...

# %%
list_merged_virus_disease_corona_wuhan = interchance_wuhan_hubei(list_merged_virus_disease_corona)
len(list_merged_virus_disease_corona_wuhan), list_merged_virus_disease_corona_wuhan
# Out:
# (55073,
#  ['19 corona acute disease',
#   '19 corona acute disorder',
#   '19 corona acute illness',
#   '19 corona acute infection',
#   '19 corona acute pneumonia',
#   '19 corona acute respiratory disease',
#   '19 corona acute respiratory disorder',
#   '19 corona acute respiratory illness',
#   '19 corona acute respiratory infection',
#   '19 corona acute respiratory syndrome',
#   '19 corona acute severe disease',
#   '19 corona acute severe disorder',
#   '19 corona acute severe illness',
#   '19 corona acute severe infection',
#   '19 corona acute severe pneumonia',
#   '19 corona acute severe respiratory disease',
#   '19 corona acute severe respiratory disorder',
#   '19 corona acute severe respiratory illness',
#   '19 corona acute severe respiratory infection',
#   '19 corona acute severe respiratory syndrome',
#   '19 corona acute severe syndrome',
#   '19 corona acute syndrome',
#   '19 corona asevere acute respiratory disease',
#   '19 corona disease',
# ...

# %%
list_merged_virus_disease_corona_wuhan_var = create_variant_terms_dis(list_merged_virus_disease_corona_wuhan)
len(list_merged_virus_disease_corona_wuhan_var), list_merged_virus_disease_corona_wuhan_var
# Out:
# (96765,
#  ['19 corona acute disease',
#   '19 corona acute disorder',
#   '19 corona acute illness',
#   '19 corona acute infection',
#   '19 corona acute pneumonia',
#   '19 corona acute respiratory disease',
#   '19 corona acute respiratory disorder',
#   '19 corona acute respiratory illness',
#   '19 corona acute respiratory infection',
#   '19 corona acute respiratory pneumonia',
#   '19 corona acute respiratory syndrome',
#   '19 corona acute severe disease',
#   '19 corona acute severe disorder',
#   '19 corona acute severe illness',
#   '19 corona acute severe infection',
#   '19 corona acute severe pneumonia',
#   '19 corona acute severe respiratory disease',
#   '19 corona acute severe respiratory disorder',
#   '19 corona acute severe respiratory illness',
#   '19 corona acute severe respiratory infection',
#   '19 corona acute severe respiratory pneumonia',
#   '19 corona acute severe respiratory syndrome',
#   '19 corona acute severe syndrome',
# ...

# %%
list_merged_virus_disease_corona_wuhan_var_nodup = remove_duplicates(list_merged_virus_disease_corona_wuhan_var)
len(list_merged_virus_disease_corona_wuhan_var_nodup), list_merged_virus_disease_corona_wuhan_var_nodup
# Out:
# (89729,
#  ['19 corona acute disease',
#   '19 corona acute disorder',
#   '19 corona acute illness',
#   '19 corona acute infection',
#   '19 corona acute pneumonia',
#   '19 corona acute respiratory disease',
#   '19 corona acute respiratory disorder',
#   '19 corona acute respiratory illness',
#   '19 corona acute respiratory infection',
#   '19 corona acute respiratory pneumonia',
#   '19 corona acute respiratory syndrome',
#   '19 corona acute severe disease',
#   '19 corona acute severe disorder',
#   '19 corona acute severe illness',
#   '19 corona acute severe infection',
#   '19 corona acute severe pneumonia',
#   '19 corona acute severe respiratory disease',
#   '19 corona acute severe respiratory disorder',
#   '19 corona acute severe respiratory illness',
#   '19 corona acute severe respiratory infection',
#   '19 corona acute severe respiratory pneumonia',
#   '19 corona acute severe respiratory syndrome',
#   '19 corona acute severe syndrome',
# ...

# %%
outfile_processed = "../results/20220321_ra_additionally_processed_dictionaries/20220321_ra_disease_processed.txt"
with open(outfile_processed, 'w') as f:
    for term in sorted(list_merged_virus_disease_corona_wuhan_var_nodup):
        f.write(term + "\n")

# %% [markdown]
# ## Merge with orig file (version 1)

# %%
orig_dis_file = "../data/AITSLAB_dictionaries/Disease_COVID-19.txt"
orig_dis_set = set()
with open(orig_dis_file) as f:
    for line in f.readlines()[:-9]:
        line=line.strip()
        orig_dis_set.update([line])
sorted(orig_dis_set)
# Out:
# ['2019 chinese corona virus acute disease',
#  '2019 chinese corona virus acute disorder',
#  '2019 chinese corona virus acute illness',
#  '2019 chinese corona virus acute infection',
#  '2019 chinese corona virus acute pneumonia',
#  '2019 chinese corona virus acute respiratory disease',
#  '2019 chinese corona virus acute respiratory disorder',
#  '2019 chinese corona virus acute respiratory illness',
#  '2019 chinese corona virus acute respiratory infection',
#  '2019 chinese corona virus acute respiratory syndrome',
#  '2019 chinese corona virus acute severe disease',
#  '2019 chinese corona virus acute severe disorder',
#  '2019 chinese corona virus acute severe illness',
#  '2019 chinese corona virus acute severe infection',
#  '2019 chinese corona virus acute severe pneumonia',
#  '2019 chinese corona virus acute severe respiratory disease',
#  '2019 chinese corona virus acute severe respiratory disorder',
#  '2019 chinese corona virus acute severe respiratory illness',
# ...

# %%
len(orig_dis_set)
# Out:
# 12906

# %%
final_dis_set = set.union(orig_dis_set, set(list_merged_virus_disease_corona_wuhan_var_nodup))
len(final_dis_set), sorted(final_dis_set)
# Out:
# (89893,
#  ['19 corona acute disease',
#   '19 corona acute disorder',
#   '19 corona acute illness',
#   '19 corona acute infection',
#   '19 corona acute pneumonia',
#   '19 corona acute respiratory disease',
#   '19 corona acute respiratory disorder',
#   '19 corona acute respiratory illness',
#   '19 corona acute respiratory infection',
#   '19 corona acute respiratory pneumonia',
#   '19 corona acute respiratory syndrome',
#   '19 corona acute severe disease',
#   '19 corona acute severe disorder',
#   '19 corona acute severe illness',
#   '19 corona acute severe infection',
#   '19 corona acute severe pneumonia',
#   '19 corona acute severe respiratory disease',
#   '19 corona acute severe respiratory disorder',
#   '19 corona acute severe respiratory illness',
#   '19 corona acute severe respiratory infection',
#   '19 corona acute severe respiratory pneumonia',
#   '19 corona acute severe respiratory syndrome',
#   '19 corona acute severe syndrome',
# ...

# %%
outfile_merged = "../results/20220321_ra_additionally_processed_dictionaries/20220321_ra_disease_merged.txt"
with open(outfile_merged, 'w') as f:
    for term in sorted(final_dis_set):
        f.write(term + "\n")

# %%
# Out:
# (89728, 103665)

# %%
sorted(final_dis_set)
# Out:
# ['19 corona acute disease',
#  '19 corona acute disorder',
#  '19 corona acute illness',
#  '19 corona acute infection',
#  '19 corona acute pneumonia',
#  '19 corona acute respiratory disease',
#  '19 corona acute respiratory disorder',
#  '19 corona acute respiratory illness',
#  '19 corona acute respiratory infection',
#  '19 corona acute respiratory pneumonia',
#  '19 corona acute respiratory syndrome',
#  '19 corona acute severe disease',
#  '19 corona acute severe disorder',
#  '19 corona acute severe illness',
#  '19 corona acute severe infection',
#  '19 corona acute severe pneumonia',
#  '19 corona acute severe respiratory disease',
#  '19 corona acute severe respiratory disorder',
#  '19 corona acute severe respiratory illness',
#  '19 corona acute severe respiratory infection',
#  '19 corona acute severe respiratory pneumonia',
#  '19 corona acute severe respiratory syndrome',
#  '19 corona acute severe syndrome',
#  '19 corona acute syndrome',
# ...

# %%
len(final_dis_set)
# Out:
# 89893
