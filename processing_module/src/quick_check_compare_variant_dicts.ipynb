# %%
sonjas_file  = "../github_repo/corona/manuscript_v2/Supplemental_file3.txt"

set_orig = set()
count = 0
with open(sonjas_file) as f:
    for line in f.readlines():
        count+=1
        set_orig.update([line])
        
print(count)
# Out:
# 5330

# %%
len(set_orig), set_orig
# Out:
# (5330,
#  {'L.1\n',
#   'BA.1 variant\n',
#   'B.1.1.59 variant\n',
#   'AY.15 variant\n',
#   'AA.2 variant\n',
#   'B.1.36.38\n',
#   'C.31\n',
#   'C.16 variant\n',
#   'B.1.466.1 lineage\n',
#   'B.1.397 lineage\n',
#   'B.1.1.512 lineage\n',
#   'B.1.44\n',
#   'B.1.177.58 lineage\n',
#   'B.1.177.25\n',
#   'AK.2\n',
#   'B.1.1.525\n',
#   'B.1.623 lineage\n',
#   'AY.5.2\n',
#   'B.1.177.19 lineage\n',
#   'B.1.375 variant\n',
#   'AZ.1 lineage\n',
#   'A.2.3\n',
#   'B.1.5.25\n',
#   'B.4.1 lineage\n',
#   'B.1.166 variant\n',
#   'B.1.1.172\n',
#   'AY.4\n',
#   'B.1.1.167 lineage\n',
#   'B.1.36.4\n',
#   'B.1.1.126\n',
#   'B.18 lineage\n',
#   'AY.132 variant\n',
#   'B.1.79 lineage\n',
#   'AY.7.1 lineage\n',
#   'B.1.621.1 lineage\n',
#   'B.1.165\n',
#   'B.1.3.1\n',
#   'B.1.1.354\n',
#   'B.1.177.67\n',
#   'clade GV\n',
#   'B.1.516 variant\n',
#   'B.12 lineage\n',
#   'AB.1 variant\n',
#   'B.1.206 variant\n',
#   '20G\n',
#   'W.2\n',
#   'B.1.1.424\n',
# ...

# %%
file_me = "../results/variants_all_processed.txt"

set_me = set()
count2 = 0
with open(file_me) as f:
    for line in f.readlines():
        count2+=1
        set_me.update([line])
        
print(count2)
# Out:
# 1762

# %%
print(len(set_me)),set_me
# Out:
# 1762
# (None,
#  {'L.1\n',
#   'AY.125\n',
#   'B.1.36.38\n',
#   'C.31\n',
#   'B.1.1.79\n',
#   'B.1.1.67\n',
#   'B.1.1.395\n',
#   'B.1.177.27\n',
#   'AA.4\n',
#   'AY.102\n',
#   'B.1.442\n',
#   'B.1.1.440\n',
#   'B.1.44\n',
#   'B.1.1.157\n',
#   'B.1.177.25\n',
#   'B.1.546\n',
#   'B.1.1.60\n',
#   'B.1.177.76\n',
#   'AY.79\n',
#   'AA.1\n',
#   'AK.2\n',
#   'B.1.1.525\n',
#   'AY.5.2\n',
#   'C.36.3\n',
#   'B.1.154\n',
#   'B.1.496\n',
#   'B.1.1.158\n',
#   'AY.85\n',
#   'B.1.403\n',
#   'AU.3\n',
#   'A.2.3\n',
#   'B.1.1.280\n',
#   'B.1.5.25\n',
#   'B.1.389\n',
#   'B.27\n',
#   'B.1.1.417\n',
#   'B.1.1.172\n',
#   'AY.39.1.1\n',
#   'B.1.1.26\n',
#   'AY.4\n',
#   'B.1.1.189\n',
#   'B.1.238\n',
#   'B.1.67\n',
#   'B.1.1.432\n',
#   'B.1.511\n',
#   'B.1.89\n',
#   'B.1.465\n',
#   'B.1.575\n',
#   'B.1.575.2\n',
#   'AY.126\n',
#   'B.1.111\n',
#   'B.1.36.4\n',
#   'B.1.1.126\n',
#   'B.1.1.526\n',
#   'B.1.337\n',
#   'B.1.577\n',
#   'B.1.80\n',
# ...

# %%
set_proc = set_orig.union(set_me)
print(len(set_proc))
# Out:
# 5347

# %%
set_me - set_orig
# Out:
# {'20E (EU1)\n',
#  '20H (Beta, V2)\n',
#  '20I (Alpha, V1)\n',
#  '20J (Gamma, V3)\n',
#  '21A (Delta)\n',
#  '21B (Kappa)\n',
#  '21C (Epsilon)\n',
#  '21D (Eta)\n',
#  '21E (Theta)\n',
#  '21F (Iota)\n',
#  '21G (Lambda)\n',
#  '21H (Mu)\n',
#  '21I (Delta)\n',
#  '21J (Delta)\n',
#  '21K (Omicron)\n',
#  '21L (Omicron)\n',
#  '21M (Omicron)\n'}
